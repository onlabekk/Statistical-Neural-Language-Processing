# %% [markdown]
# # 1. Information about the submission

# %% [markdown]
# ## 1.1 Name and number of the assignment

# %% [markdown]
# **Assignment 1: Morphological Analysis, CoNLL–SIGMORPHON 2018 Shared Task**

# %% [markdown]
# ## 1.2 Student name

# %% [markdown]
# **Kundyz Onlabek**

# %% [markdown]
# # 2. Technical Report

# %% [markdown]
# ## 2.1 Methodology

# %% [markdown]
# To assess the system’s ability to generalize in different resource settings, three varying amounts of labeled training data (low, medium, high) were given. The systems were evaluated separately for each language and the three data quantity conditions. Accuracy and the average Levenshtein distance between the prediction and the truth across all predictions were used as metrics. An aggregated performance measure separate for each of the resource setting was obtained by averaging the results for individual languages

# %% [markdown]
# The system is based on attention based encoderdecoder models. The lemma and the tags are encoded using two separate encoders. While decoding, the decoder reads relevant parts of the lemma and the tags using attention mechanism. As most of the characters in
# the inflected form are copied from the lemma, it is necessary to design a system with strong tendency to copy. Pointer-Generator Network is used which facilitates copying of characters of lemma and tackles the problem of out-ofvocabulary tokens during prediction.

# %% [markdown]
# The neural network architecture is based on
# Pointer-Generator Network with
# some subtle differences.
# Characters of the lemma $c_i$ along with the additional start and stop characters are fed one by one into a bidirectional LSTM encoder producing a sequence of hidden states $h_{l_i}$. Similarly, using a separate bidirectional LSTM encoder, the tags $tg_i$ are encoded and another sequence of hidden states
# $h_{tg_i}$ is obtained.

# %% [markdown]
# Unidirectional LSTM is used as the decoder.
# The decoder’s hidden state $s_i$ is initialised by applying an affine transformation on the concatenation of the last hidden states of the lemma and the tag encoders. As the input and output sequences have different semantics, this affine transformation gives the model the ability to learn transformation of semantics from input to output:
# $$s_{0}=W_{\text {initial }}\left[h_{l_{N}} ; h_{t g_{N}}\right]+b.$$

# %% [markdown]
# While decoding, at each time step t, the decoder
# computes an attention distribution over the lemma and the tag separately denoted as $a^t_l$
# and $a^t_tg$:
# $$ \begin{gathered}
# e_{l_{i}}^{t}=v^{T} \tanh \left(W_{h_{l}} h_{l_{i}}+W_{s_{l}} s_{t-1}+b_{l}\right) \\
# e_{t g_{i}}^{t}=v^{T} \tanh \left(W_{h_{t g}} h_{t g_{i}}+W_{s_{t g}} s_{t-1}+b_{t g}\right) \\
# a_{l}^{t}=\operatorname{softmax}\left(e_{l}^{t}\right) \\
# a_{t g}^{t}=\operatorname{softmax}\left(e_{t g}^{t}\right).
# \end{gathered}$$

# %% [markdown]
# The context vectors:
# $$\begin{gathered}
# h_{l_{t}}^{*}=\sum_{i} a_{l_{i}}^{t} h_{l_{i}} \\
# h_{t g_{t}}^{*}=\sum_{i} a_{t g_{i}}^{t} h_{t g_{i}}
# \end{gathered}.$$

# %% [markdown]
# The combined context vector:
# $$ h_{t}^{*}=\left[h_{l_{t}}^{*} ; h_{t g_{t}}^{*}\right].$$

# %% [markdown]
# At the first time step, start
# character is given as input in place of $y_{t-1}$.
# $$ s_{t}=f\left(s_{t-1}, h_{t}^{*}, y_{t-1}\right), $$
# where $f$ is a nonlinear function.

# %% [markdown]
# A probability distribution over the characters in the vocabulary is calculated which corresponds to how likely will a particular character be generated:
# $$ P_{\text {vocab }}=\operatorname{softmax}\left(V\left[s_{t} ; h^{*}\right]+b\right).$$

# %% [markdown]
# The probability of predicting a character c is
# computed as the sum of probability of generating
# $c$ weighted by the generation probability $p_{\text {gen }}$ and the total attention distribution over $c$ weighted by the probability of copying it $(1 − p_{\text {gen }})$:
# $$P(c)=p_{\text {gen }} P_{\text {vocab }}(c)+\left(1-p_{\text {gen }}\right) \sum_{i: c_{i}=c} a_{l_{i}}^{t}.$$

# %% [markdown]
# The negative log likelihood is used to compute the loss. The loss for time step $t$, where $c^∗_t$ is the target character is given by  $loss_t = − log P(c^∗_t)$.

# %% [markdown]
# The loss for the overall sequence is $$
# \text { loss }=\frac{1}{T} \sum_{t=0}^{T} \text { loss }_{t}
# .$$

# %% [markdown]
# Adam Optimiser is used with initial learning rate 0.001 and batch
# size 32 to train the neural network. To deal with exploding gradient problem, the norm is clipped and computed over all the gradients together to 3. Dropout is applied with probability $p$ over embeddings and the encoder hidden states.

# %% [markdown]
# Early stopping is used to prevent overfitting. A
# portion of the development set is used as the validation set.
# Single layer LSTMs were used as encoders and
# decoders to reduce number of parameters.

# %% [markdown]
# ## 2.2 Discussion of results

# %% [markdown]
# The experiment 1 works (with simpled batched encoder decoder with characters and tags as input), while other 3 implementations (Simple attention over characters and tags; Pointer generator over characters and tags; simple attention over characters and tags with attention layer trained) did not show good results.

# %% [markdown]
# # 3. Code

# %% [markdown]
# ## 3.1 Requirements

# %%
! pip install python-levenshtein
# Out:
# Requirement already satisfied: python-levenshtein in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-levenshtein) (57.4.0)
# fatal: destination path 'conll2018' already exists and is not an empty directory.

# %% [markdown]
# ## 3.2 Download the data

# %%
! git clone https://github.com/sigmorphon/conll2018
# Out:
# Requirement already satisfied: python-levenshtein in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-levenshtein) (57.4.0)
# fatal: destination path 'conll2018' already exists and is not an empty directory.

# %% [markdown]
# ## 3.3 Experiment 1

# %% [markdown]
# ### Simple Batched Encoder Decoder with characters and tags as input

# %%
START_CHAR = '⏵'
STOP_CHAR = '⏹'
UNKNOWN_CHAR = '⊗'
UNKNOWN_TAG = '⊤'
PAD_CHAR = '₮'
PAD_TAG = '<PAD>'

# %%
from itertools import zip_longest
import os
import pickle

import Levenshtein
import numpy as np
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
def load_data(file_name):
    """Loads data.

    Args:
        file_name: path to file containing the data

    Returns:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form
    """

    with open(file_name, 'r', encoding='utf') as file:
        text = file.read()

    lemmas = []
    tags = []
    inflected_forms = []

    for line in text.split('\n')[:-1]:
        lemma, inflected_form, tag = line.split('\t')
        lemmas.append(lemma)
        inflected_forms.append(inflected_form)
        tags.append(tag) 

    return lemmas, tags, inflected_forms

def get_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char, tag2index

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps character to index
        index2char: a dictionary which maps index to character
        tag2index: a ditionary which maps morphological tag to index 
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR) # special start and end symbols
    unique_chars.update(UNKNOWN_CHAR) # special charcter for unknown word
    char2index = {}
    index2char = {}

    char2index[PAD_CHAR] = 0
    index2char[0] = PAD_CHAR
    
    for index, char in enumerate(unique_chars):
        char2index[char] = index + 1
        index2char[index + 1] = char

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.update(UNKNOWN_TAG)
    tag2index = {tag:index+1 for index, tag in enumerate(unique_tags)}
    tag2index[PAD_TAG] = 0

    return char2index, index2char, tag2index

def get_combined_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps inputs and  to index
        index2char: a dictionary which maps index to inputs
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR, UNKNOWN_CHAR) # special start and end symbols  
    
    input2index = {}
    index2input = {}
    
    input2index[PAD_CHAR] = 0
    index2input[0] = PAD_CHAR
        
    for index, char in enumerate(unique_chars, start=1):
        input2index[char] = index
        index2input[index] = char
        
    char_vocab_length = len(input2index.keys())

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.add(UNKNOWN_TAG) # special character for unknown tags
    
    for index, char in enumerate(unique_tags, start=char_vocab_length):
        input2index[char] = index
        index2input[index] = char

    return input2index, index2input, char_vocab_length

def words_to_indices(words, char2index, tensor=False, start_char=False, stop_char=False):
    """Converts list of words to a list with list containing indices

    Args:
        words: list of words
        char2index: dictionary which maps character to index
        tensor: if to return a list of tensor  

    Returns:
        tensor: list of list/tensor containing indices for a sequence of characters
    """

    list_indices = []
    for word in words:
        word_indices = []
        if start_char:
            word_indices.append(char2index[START_CHAR])
        for char in word:
            if char in char2index.keys():
                word_indices.append(char2index[char])
            else:
                word_indices.append(char2index[UNKNOWN_CHAR])
        if stop_char:
            word_indices.append(char2index[STOP_CHAR])
        if tensor:
            word_indices = torch.Tensor(word_indices)
        list_indices.append(word_indices)

    return list_indices

def tag_to_vector(tags, tag2index):
    """Returns one hot representation of tags given a tag.

    Args:
        tags: list of string representation of tag (eg, V;IND;PRS;2;PL)

    Returns:
        tag_vectors: list of 1D tensors with one hot representation of tags 
    """

    tag_vectors = []
    for tag in tags:
        tag_vector = torch.zeros(len(tag2index))
        for tag_feature in tag.split(';'):
            if tag_feature in tag2index:
                tag_vector[tag2index[tag_feature]] = 1
            else:
                tag_vector[tag2index[UNKNOWN_TAG]] = 1
        tag_vectors.append(tag_vector)
    return tag_vectors

def tag_to_indices(tags, tag2index):
    """Converts list of tags to a list of lists containing indices

    Args:
        words: list of tags

    Returns:
        tensor: list of list containing indices of sub_tags
    """
    
    list_indices = []
    for tag in tags:
        tag_indices = []
        for sub_tag in tag.split(';'):
            if sub_tag in tag2index.keys():
                tag_indices.append(tag2index[sub_tag])
            else:
                tag_indices.append(tag2index[UNKNOWN_TAG])
        list_indices.append(tag_indices)

    return list_indices
    

def indices_to_word(indices, index2char):
    """Returns a word given list contaning indices of words

    Args:
        indices: list containing indices

    Returns:
        word: a string
    """

    return ''.join([index2char[index] for index in indices])[:-1]

def pad_lists(lists, pad_int, pad_len=None):
    """Pads lists in a list to make them of equal size"""
    
    if pad_len is None:
        pad_len = max([len(lst) for lst in lists])
    new_list = []
    for lst in lists:
        if len(lst) < pad_len:
            new_list.append(torch.tensor(lst + [pad_int] * (pad_len-len(lst))))
        else:
            new_list.append(torch.tensor(lst[:pad_len]))
    return torch.stack(new_list)

def merge_lists(lists1, lists2):
    """Add two list of lists."""
    
    merged_lists = []
    for list1, list2 in zip(lists1, lists2):
        merged_lists.append(list1 + list2)
    return merged_lists

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def accuracy(predictions, targets):
    correct_count = 0
    for prediction, target in zip(predictions, targets):
        if prediction == target:
            correct_count += 1
    return correct_count / len(predictions)

def average_distance(predictions, targets):
    total_distance = 0
    for prediction, target in zip(predictions, targets):
        total_distance += Levenshtein.distance(prediction, target)
    return total_distance / len(predictions)

def evaluate(predictions, targets):
    return accuracy(predictions, targets), average_distance(predictions, targets)

# %%
lemmas, tags, inflected_forms = load_data('./conll2018/task1/all/middle-french-train-high')

# %%
lemmas_train, lemmas_val, tags_train, tags_val, inflected_forms_train, inflected_forms_val = train_test_split(lemmas, tags, inflected_forms, test_size=0.2, random_state=42)

# %%
input2index, index2input, char_vocab_size = get_combined_index_dictionaries(lemmas_train, tags_train, inflected_forms_train)

# %% [markdown]
# ### Train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32
embedding_size = 300
hidden_size = 100
input_vocab_size = len(index2input.keys())

# %%
Embedder = nn.Embedding(input_vocab_size, embedding_size, padding_idx=input2index[PAD_CHAR]).to(device)
Encoder = nn.LSTM(embedding_size, hidden_size, batch_first=True, bidirectional=True).to(device)
Decoder = nn.LSTM(embedding_size, hidden_size, batch_first=True).to(device)
linear1 = nn.Linear(hidden_size, char_vocab_size).to(device)
log_softmax = nn.LogSoftmax(dim=2).to(device)
criterion = nn.NLLLoss(ignore_index=0)
params = list(Embedder.parameters()) + list(Encoder.parameters()) + list(Decoder.parameters()) + list(linear1.parameters())

# %%
def test(lemmas_val, tags_val, inflected_forms_val, batch_size=32):

    inflected_predicted = []
    inflected_forms_true = []

    for batch in grouper(zip(lemmas_val, tags_val, inflected_forms_val), batch_size):
        batch = list(filter(lambda x: x is not None, batch))
        lemmas, tags, inflected_forms = zip(*batch)

        lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
        tags_indices = tag_to_indices(tags, input2index)    
        input_indices = merge_lists(lemmas_indices, tags_indices)

        # Sort by length of input sequence
        input_indices, inflected_forms = zip(*sorted(zip(input_indices, inflected_forms), key=lambda x: len(x[0]), reverse=True))
        input_indices = [torch.tensor(lst) for lst in input_indices]


        input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
        embedding = Embedder(input_tensor)
        lengths = [Tensor.shape[0] for Tensor in input_indices]
        packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
        encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
        encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]


        # Decode
        hidden_state = hidden[0,:,:] + hidden[1,:,:]
        hidden_state = hidden_state.unsqueeze(0)
        cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

        decoder_input = torch.tensor([input2index[START_CHAR]] * len(lengths)).to(device)
        decoder_input = Embedder(decoder_input).unsqueeze(1)

        outputs = []
        for seq in range(0, 25):
            output, (hidden_state, cell_state) = Decoder(decoder_input, (hidden_state, cell_state))
            output = F.relu(linear1(hidden_state))
            decoder_input = Embedder(output.argmax(dim=2)).transpose(0, 1)
            outputs.append(output.squeeze())

        batch_indices = torch.stack(outputs).argmax(dim=2).transpose(0, 1).cpu().numpy()
        for indices in batch_indices:
            inflected_predicted.append(''.join([index2input[index] for index in indices]).split(STOP_CHAR)[0])
        inflected_forms_true += inflected_forms
        
    return inflected_predicted, inflected_forms_true

# %%
optimiser = optim.Adagrad(params)

# %%
def train(lemmas_train, tags_train, inflected_forms_train, epochs=1):
    for epoch in range(epochs):

        epoch_loss = 0

        for batch in grouper(zip(lemmas_train, tags_train, inflected_forms_train), batch_size):
            batch = list(filter(lambda x: x is not None, batch))
            lemmas, tags, inflected_forms = zip(*batch)


            lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
            tags_indices = tag_to_indices(tags, input2index)    
            inflected_forms_indices = words_to_indices(inflected_forms, input2index)
            input_indices = merge_lists(lemmas_indices, tags_indices)

            # Sort by length of input sequence
            input_indices, inflected_forms_indices = zip(*sorted(zip(input_indices, inflected_forms_indices), key=lambda x: len(x[0]), reverse=True))
            input_indices = [torch.tensor(lst) for lst in input_indices]

            optimiser.zero_grad()

            input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
            embedding = Embedder(input_tensor)
            lengths = [Tensor.shape[0] for Tensor in input_indices]
            packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
            encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
            encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]


            # Decode
            hidden_state = hidden[0,:,:] + hidden[1,:,:]
            hidden_state = hidden_state.unsqueeze(0)
            cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

            target = pad_lists([lst + [input2index[STOP_CHAR]] for lst in inflected_forms_indices], input2index[PAD_CHAR]).to(device)    

            decoder_input = pad_lists(inflected_forms_indices, input2index[PAD_CHAR]).to(device)
            decoder_input = torch.cat([torch.tensor([input2index[START_CHAR]] * len(lengths)).unsqueeze(1).to(device), decoder_input], dim=1)
            decoder_input = Embedder(decoder_input)


            loss = 0

            max_length = target.shape[1]
            for seq in range(0, max_length):
                output, (hidden_state, cell_state) = Decoder(decoder_input[:,seq,:].unsqueeze(1), (hidden_state, cell_state))
                output = F.relu(linear1(hidden_state))
                output = log_softmax(output).squeeze()
                loss += criterion(output, target[:,seq])

            epoch_loss += loss.item()
            loss.backward()
            optimiser.step()

        print("Epoch: {}/{}\tLoss: {:.4f}\tAccuracy: {:4f}\tDistance: {:.4f} ".format(epoch, epochs, epoch_loss / len(lemmas_train), *evaluate(*test(lemmas_val, tags_val, inflected_forms_val))))

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=150)
# Out:
# Epoch: 0/150	Loss: 0.7956	Accuracy: 0.000500	Distance: 6.2360
# Epoch: 1/150	Loss: 0.5525	Accuracy: 0.000500	Distance: 5.8865
# Epoch: 2/150	Loss: 0.4720	Accuracy: 0.006000	Distance: 5.3875
# Epoch: 3/150	Loss: 0.4212	Accuracy: 0.014000	Distance: 5.2285
# Epoch: 4/150	Loss: 0.3786	Accuracy: 0.019500	Distance: 4.9650
# Epoch: 5/150	Loss: 0.3401	Accuracy: 0.045000	Distance: 4.5215
# Epoch: 6/150	Loss: 0.3127	Accuracy: 0.057000	Distance: 4.3700
# Epoch: 7/150	Loss: 0.2901	Accuracy: 0.076000	Distance: 4.1155
# Epoch: 8/150	Loss: 0.2712	Accuracy: 0.100000	Distance: 3.8910
# Epoch: 9/150	Loss: 0.2542	Accuracy: 0.119000	Distance: 3.7620
# Epoch: 10/150	Loss: 0.2380	Accuracy: 0.150000	Distance: 3.6075
# Epoch: 11/150	Loss: 0.2257	Accuracy: 0.177000	Distance: 3.4765
# Epoch: 12/150	Loss: 0.2199	Accuracy: 0.186000	Distance: 3.4030
# Epoch: 13/150	Loss: 0.2073	Accuracy: 0.224000	Distance: 3.2465
# Epoch: 14/150	Loss: 0.1895	Accuracy: 0.222000	Distance: 3.1990
# Epoch: 15/150	Loss: 0.1824	Accuracy: 0.252500	Distance: 3.0600
# Epoch: 16/150	Loss: 0.1715	Accuracy: 0.257000	Distance: 3.0930
# Epoch: 17/150	Loss: 0.1677	Accuracy: 0.312500	Distance: 2.7405
# Epoch: 18/150	Loss: 0.1600	Accuracy: 0.306000	Distance: 2.7830
# Epoch: 19/150	Loss: 0.1532	Accuracy: 0.331000	Distance: 2.6735
# Epoch: 20/150	Loss: 0.1452	Accuracy: 0.293500	Distance: 2.7050
# Epoch: 21/150	Loss: 0.1400	Accuracy: 0.368000	Distance: 2.4760
# Epoch: 22/150	Loss: 0.1315	Accuracy: 0.322000	Distance: 2.6240
# Epoch: 23/150	Loss: 0.1264	Accuracy: 0.394000	Distance: 2.3290
# Epoch: 24/150	Loss: 0.1218	Accuracy: 0.405000	Distance: 2.2665
# Epoch: 25/150	Loss: 0.1208	Accuracy: 0.354000	Distance: 2.5020
# Epoch: 26/150	Loss: 0.1179	Accuracy: 0.420000	Distance: 2.2125
# Epoch: 27/150	Loss: 0.1095	Accuracy: 0.454500	Distance: 2.0715
# Epoch: 28/150	Loss: 0.1048	Accuracy: 0.446500	Distance: 2.0705
# Epoch: 29/150	Loss: 0.1066	Accuracy: 0.379500	Distance: 2.3095
# Epoch: 30/150	Loss: 0.1138	Accuracy: 0.452500	Distance: 2.0975
# Epoch: 31/150	Loss: 0.1003	Accuracy: 0.471500	Distance: 1.9540
# Epoch: 32/150	Loss: 0.0920	Accuracy: 0.489000	Distance: 1.8785
# Epoch: 33/150	Loss: 0.0885	Accuracy: 0.503000	Distance: 1.8435
# Epoch: 34/150	Loss: 0.0850	Accuracy: 0.513500	Distance: 1.7975
# Epoch: 35/150	Loss: 0.0821	Accuracy: 0.521500	Distance: 1.7400
# Epoch: 36/150	Loss: 0.0800	Accuracy: 0.510500	Distance: 1.8190
# Epoch: 37/150	Loss: 0.0825	Accuracy: 0.504500	Distance: 1.8055
# Epoch: 38/150	Loss: 0.0983	Accuracy: 0.501000	Distance: 1.8555
# Epoch: 39/150	Loss: 0.0809	Accuracy: 0.533500	Distance: 1.7070
# Epoch: 40/150	Loss: 0.0810	Accuracy: 0.529000	Distance: 1.7350
# Epoch: 41/150	Loss: 0.0810	Accuracy: 0.514500	Distance: 1.7780
# Epoch: 42/150	Loss: 0.0742	Accuracy: 0.564500	Distance: 1.6110
# Epoch: 43/150	Loss: 0.0695	Accuracy: 0.564000	Distance: 1.5980
# Epoch: 44/150	Loss: 0.0659	Accuracy: 0.582500	Distance: 1.5285
# Epoch: 45/150	Loss: 0.0681	Accuracy: 0.525000	Distance: 1.6740
# Epoch: 46/150	Loss: 0.0664	Accuracy: 0.581500	Distance: 1.5110
# Epoch: 47/150	Loss: 0.0617	Accuracy: 0.604500	Distance: 1.4510
# Epoch: 48/150	Loss: 0.0598	Accuracy: 0.605500	Distance: 1.4220
# Epoch: 49/150	Loss: 0.0587	Accuracy: 0.607500	Distance: 1.4075
# Epoch: 50/150	Loss: 0.0572	Accuracy: 0.616500	Distance: 1.3845
# Epoch: 51/150	Loss: 0.0632	Accuracy: 0.571000	Distance: 1.5620
# Epoch: 52/150	Loss: 0.0783	Accuracy: 0.513500	Distance: 1.7210
# Epoch: 53/150	Loss: 0.0625	Accuracy: 0.613000	Distance: 1.4095
# Epoch: 54/150	Loss: 0.0588	Accuracy: 0.622000	Distance: 1.3700
# Epoch: 55/150	Loss: 0.0556	Accuracy: 0.638500	Distance: 1.2830
# Epoch: 56/150	Loss: 0.0528	Accuracy: 0.639000	Distance: 1.3035
# Epoch: 57/150	Loss: 0.0508	Accuracy: 0.643500	Distance: 1.2855
# Epoch: 58/150	Loss: 0.0494	Accuracy: 0.646500	Distance: 1.2445
# Epoch: 59/150	Loss: 0.0482	Accuracy: 0.654500	Distance: 1.2230
# Epoch: 60/150	Loss: 0.0474	Accuracy: 0.653500	Distance: 1.2150
# Epoch: 61/150	Loss: 0.0466	Accuracy: 0.657500	Distance: 1.1785
# Epoch: 62/150	Loss: 0.0807	Accuracy: 0.568000	Distance: 1.5645
# Epoch: 63/150	Loss: 0.0649	Accuracy: 0.635500	Distance: 1.3415
# Epoch: 64/150	Loss: 0.0521	Accuracy: 0.665000	Distance: 1.2390
# Epoch: 65/150	Loss: 0.0467	Accuracy: 0.670000	Distance: 1.1740
# Epoch: 66/150	Loss: 0.0446	Accuracy: 0.674000	Distance: 1.1560
# Epoch: 67/150	Loss: 0.0433	Accuracy: 0.676500	Distance: 1.1245
# Epoch: 68/150	Loss: 0.0424	Accuracy: 0.685500	Distance: 1.0910
# Epoch: 69/150	Loss: 0.0416	Accuracy: 0.686500	Distance: 1.0920
# Epoch: 70/150	Loss: 0.0408	Accuracy: 0.686000	Distance: 1.0995
# Epoch: 71/150	Loss: 0.0403	Accuracy: 0.691000	Distance: 1.0810
# Epoch: 72/150	Loss: 0.0395	Accuracy: 0.689000	Distance: 1.0840
# Epoch: 73/150	Loss: 0.0389	Accuracy: 0.691500	Distance: 1.0780
# Epoch: 74/150	Loss: 0.0383	Accuracy: 0.695500	Distance: 1.0515
# Epoch: 75/150	Loss: 0.0839	Accuracy: 0.485000	Distance: 1.9245
# Epoch: 76/150	Loss: 0.0714	Accuracy: 0.640000	Distance: 1.3385
# Epoch: 77/150	Loss: 0.0476	Accuracy: 0.681000	Distance: 1.1840
# Epoch: 78/150	Loss: 0.0405	Accuracy: 0.694000	Distance: 1.0890
# Epoch: 79/150	Loss: 0.0385	Accuracy: 0.701500	Distance: 1.0640
# Epoch: 80/150	Loss: 0.0373	Accuracy: 0.706500	Distance: 1.0380
# Epoch: 81/150	Loss: 0.0364	Accuracy: 0.709000	Distance: 1.0240
# Epoch: 82/150	Loss: 0.0357	Accuracy: 0.709500	Distance: 1.0210
# Epoch: 83/150	Loss: 0.0342	Accuracy: 0.715000	Distance: 0.9760
# Epoch: 84/150	Loss: 0.0331	Accuracy: 0.720500	Distance: 0.9495
# Epoch: 85/150	Loss: 0.0323	Accuracy: 0.721000	Distance: 0.9345
# Epoch: 86/150	Loss: 0.0318	Accuracy: 0.724000	Distance: 0.9170
# Epoch: 87/150	Loss: 0.0312	Accuracy: 0.724500	Distance: 0.9135
# Epoch: 88/150	Loss: 0.0307	Accuracy: 0.726500	Distance: 0.8990
# Epoch: 89/150	Loss: 0.0303	Accuracy: 0.725500	Distance: 0.9050
# Epoch: 90/150	Loss: 0.0300	Accuracy: 0.727500	Distance: 0.8965
# Epoch: 91/150	Loss: 0.0296	Accuracy: 0.728000	Distance: 0.8915
# Epoch: 92/150	Loss: 0.0294	Accuracy: 0.732500	Distance: 0.8865
# Epoch: 93/150	Loss: 0.0289	Accuracy: 0.730000	Distance: 0.8775
# Epoch: 94/150	Loss: 0.0284	Accuracy: 0.733000	Distance: 0.8720
# Epoch: 95/150	Loss: 0.0280	Accuracy: 0.735000	Distance: 0.8560
# Epoch: 96/150	Loss: 0.0277	Accuracy: 0.737500	Distance: 0.8520
# Epoch: 97/150	Loss: 0.0274	Accuracy: 0.739500	Distance: 0.8375
# Epoch: 98/150	Loss: 0.0599	Accuracy: 0.524000	Distance: 1.6195
# Epoch: 99/150	Loss: 0.0660	Accuracy: 0.687000	Distance: 1.1340
# Epoch: 100/150	Loss: 0.0388	Accuracy: 0.632500	Distance: 1.1835
# Epoch: 101/150	Loss: 0.0331	Accuracy: 0.736500	Distance: 0.9090
# Epoch: 102/150	Loss: 0.0288	Accuracy: 0.740500	Distance: 0.8895
# Epoch: 103/150	Loss: 0.0275	Accuracy: 0.752000	Distance: 0.8390
# Epoch: 104/150	Loss: 0.0267	Accuracy: 0.752000	Distance: 0.8340
# Epoch: 105/150	Loss: 0.0262	Accuracy: 0.753000	Distance: 0.8260
# Epoch: 106/150	Loss: 0.0257	Accuracy: 0.753000	Distance: 0.8120
# Epoch: 107/150	Loss: 0.0253	Accuracy: 0.754000	Distance: 0.8035
# Epoch: 108/150	Loss: 0.0250	Accuracy: 0.754000	Distance: 0.7985
# Epoch: 109/150	Loss: 0.0246	Accuracy: 0.753500	Distance: 0.7950
# Epoch: 110/150	Loss: 0.0243	Accuracy: 0.755500	Distance: 0.7905
# Epoch: 111/150	Loss: 0.0240	Accuracy: 0.754500	Distance: 0.7975
# Epoch: 112/150	Loss: 0.0238	Accuracy: 0.754500	Distance: 0.7995
# Epoch: 113/150	Loss: 0.0235	Accuracy: 0.753000	Distance: 0.7895
# Epoch: 114/150	Loss: 0.0233	Accuracy: 0.752000	Distance: 0.7925
# Epoch: 115/150	Loss: 0.0230	Accuracy: 0.753500	Distance: 0.7870
# Epoch: 116/150	Loss: 0.0228	Accuracy: 0.754000	Distance: 0.7730
# Epoch: 117/150	Loss: 0.0226	Accuracy: 0.755000	Distance: 0.7720
# Epoch: 118/150	Loss: 0.0223	Accuracy: 0.754000	Distance: 0.7650
# Epoch: 119/150	Loss: 0.0221	Accuracy: 0.753000	Distance: 0.7740
# Epoch: 120/150	Loss: 0.0219	Accuracy: 0.755500	Distance: 0.7585
# Epoch: 121/150	Loss: 0.0217	Accuracy: 0.752000	Distance: 0.7730
# Epoch: 122/150	Loss: 0.0207	Accuracy: 0.754500	Distance: 0.7645
# Epoch: 123/150	Loss: 0.0962	Accuracy: 0.655000	Distance: 1.1690
# Epoch: 124/150	Loss: 0.0674	Accuracy: 0.698500	Distance: 1.0680
# Epoch: 125/150	Loss: 0.0332	Accuracy: 0.743500	Distance: 0.8785
# Epoch: 126/150	Loss: 0.0262	Accuracy: 0.754000	Distance: 0.8345
# Epoch: 127/150	Loss: 0.0233	Accuracy: 0.764500	Distance: 0.7805
# Epoch: 128/150	Loss: 0.0216	Accuracy: 0.761500	Distance: 0.7750
# Epoch: 129/150	Loss: 0.0207	Accuracy: 0.761500	Distance: 0.7730
# Epoch: 130/150	Loss: 0.0200	Accuracy: 0.764000	Distance: 0.7690
# Epoch: 131/150	Loss: 0.0196	Accuracy: 0.764500	Distance: 0.7650
# Epoch: 132/150	Loss: 0.0191	Accuracy: 0.765000	Distance: 0.7580
# Epoch: 133/150	Loss: 0.0188	Accuracy: 0.763000	Distance: 0.7565
# Epoch: 134/150	Loss: 0.0185	Accuracy: 0.763500	Distance: 0.7515
# Epoch: 135/150	Loss: 0.0182	Accuracy: 0.764500	Distance: 0.7485
# Epoch: 136/150	Loss: 0.0180	Accuracy: 0.765500	Distance: 0.7400
# Epoch: 137/150	Loss: 0.0177	Accuracy: 0.767000	Distance: 0.7370
# Epoch: 138/150	Loss: 0.0175	Accuracy: 0.766500	Distance: 0.7315
# Epoch: 139/150	Loss: 0.0173	Accuracy: 0.768000	Distance: 0.7225
# Epoch: 140/150	Loss: 0.0171	Accuracy: 0.766000	Distance: 0.7240
# Epoch: 141/150	Loss: 0.0169	Accuracy: 0.768000	Distance: 0.7185
# Epoch: 142/150	Loss: 0.0167	Accuracy: 0.770000	Distance: 0.7120
# Epoch: 143/150	Loss: 0.0165	Accuracy: 0.771000	Distance: 0.7085
# Epoch: 144/150	Loss: 0.0164	Accuracy: 0.769000	Distance: 0.7150
# Epoch: 145/150	Loss: 0.0162	Accuracy: 0.768000	Distance: 0.7160
# Epoch: 146/150	Loss: 0.0160	Accuracy: 0.770000	Distance: 0.7080
# Epoch: 147/150	Loss: 0.0159	Accuracy: 0.770500	Distance: 0.7025
# Epoch: 148/150	Loss: 0.0157	Accuracy: 0.769500	Distance: 0.7075
# Epoch: 149/150	Loss: 0.0156	Accuracy: 0.770000	Distance: 0.7015

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# Train accuracy: (0.97025, 0.142875) Validation accuracy:  (0.77, 0.7015)

# %%
list(zip(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# [('esmerveille', 'esmerveille'),
#  ('enpoinouera', 'enpoisonna'),
#  ('vous entrenchontrions', 'nous entrehurtons'),
#  ('chevaucherai', 'chevauchieras'),
#  ('tournoyassions', 'tournoyassions'),
#  ('represente', 'represente'),
#  ('delaçasse', 'delacyez'),
#  ('encontreront', 'encontreront'),
#  ('praepareroys', 'praepareroys'),
#  ('esveiglez', 'esveiglez'),
#  ('esbaucheroys', 'esbaucheroys'),
#  ('remercyez', 'remercyes'),
#  ('chargeoys', 'chargeoys'),
#  ('laissoys', 'laissoys'),
#  ('separois', 'separions'),
#  ('depeschez', 'depeschez'),
#  ('apuyoys', 'apuyoys'),
#  ('pastureroyent', 'pastureroyent'),
#  ('devoures', 'devoures'),
#  ('mouschons', 'mouschons'),
#  ('apatissois', 'apatissois'),
#  ('contribueront', 'contribuant'),
#  ('rincera', 'rinçasmes'),
#  ('arroiez', 'arroiez'),
#  ('cuyde', 'cuyde'),
#  ('ieune', 'ieune'),
#  ('quite', 'quite'),
#  ('gaignez', 'gaignez'),
#  ('pillent', 'pillent'),
#  ('leichons', 'leichons'),
#  ('alois', 'aloit'),
#  ('endamyez', 'en dampnant'),
#  ('accoustumassent', 'accoustumassent'),
#  ('provocquoys', 'provocquoys'),
#  ('praesentyez', 'praesentyez'),
#  ('exstirpyez', 'exstirpyez'),
#  ('revenchoys', 'revenchoys'),
#  ('esprouvois', 'esprouvois'),
#  ('desrobboient', 'desrobboient'),
#  ('preferois', 'preferois'),
#  ('escouillerois', 'escouillerois'),
#  ('depeschasses', 'depeschasses'),
#  ('empiegent', 'empiegyons'),
#  ('essilassiez', 'essilassiez'),
#  ('advisoys', 'advisoys'),
#  ('foulloys', 'foulloys'),
#  ('hebergeroys', 'hebergieroys'),
#  ('eschevastes', 'eschevastes'),
#  ('bucherient', 'buchierent'),
#  ('combineryons', 'combineroys'),
#  ('branslons', 'branslons'),
#  ('revenchez', 'revenchez'),
#  ('guerpirez', 'guerpirons'),
#  ('chocquez', 'chocquez'),
#  ('herrierez', 'herrierez'),
#  ('marches', 'marches'),
#  ('cerchois', 'cerchions'),
#  ('rengea', 'rengea'),
#  ('destablant', 'destablant'),
#  ('fluires', 'fluirez'),
#  ('cryent', 'cryent'),
#  ('alois', 'aliez'),
#  ('estirer', 'estirer'),
#  ('aeré', 'aeré'),
#  ('despouillasse', 'despouillasse'),
#  ('courouchassions', 'courouchast'),
#  ('deshonnourerez', 'deshonnourerez'),
#  ('acoustumois', 'acoustumois'),
#  ('remonstrassent', 'remonstrastes'),
#  ('fortifiois', 'fortifiois'),
#  ('prattiquez', 'prattiquent'),
#  ('traveille', 'traveille'),
#  ('estrangles', 'estrangles'),
#  ('deschainerons', 'deschainerons'),
#  ('desancreray', 'desancreray'),
#  ('preferyez', 'preferyez'),
#  ('fortiffies', 'fortiffies'),
#  ('subiecterent', 'subiecterent'),
#  ('cointoiastes', 'cointoieront'),
#  ('esclaireront', 'esclaireroient'),
#  ('besoignez', 'besoignez'),
#  ('monstreroient', 'monstreroient'),
#  ('enyvreriez', 'enyvreriez'),
#  ('deifie', 'deifie'),
#  ('ausions', 'ausions'),
#  ('edifierez', 'edifierez'),
#  ('guarderas', 'guarderas'),
#  ('celyons', 'celyons'),
#  ('mesclez', 'mesclez'),
#  ('residera', 'residera'),
#  ('affieroyent', 'affieray'),
#  ('rinça', 'rinça'),
#  ('cacheroys', 'cacheroys'),
#  ('abboyons', 'abboyons'),
#  ('resve', 'resve'),
#  ('en entranche', 'en entrant'),
#  ('courroucha', 'courroucha'),
#  ('enpoisonnoyent', 'enpoisonnoyent'),
#  ('transportastes', 'transportastes'),
#  ('enchargeoys', 'enchargeoys'),
#  ('acoustumoit', 'acoustumoit'),
#  ('desbarate', 'desbarata'),
#  ('possessoyt', 'possessoyt'),
#  ('interpreteront', 'interpreteront'),
#  ('detranchieront', 'detranchieroit'),
#  ('infourmast', 'infourmasmes'),
#  ('maschyons', 'maschyons'),
#  ('avalloyt', 'avalloyt'),
#  ('subiectonserez', 'subiecteront'),
#  ('confesserions', 'confesserions'),
#  ('effronteront', 'effronteront'),
#  ('desrisieroys', 'desrisieroys'),
#  ('aterminerai', 'atermineroit'),
#  ('celebrasse', 'celebrassiez'),
#  ('reserveryons', 'reserveroyt'),
#  ('singlassent', 'singlastes'),
#  ('invaderent', 'invaderent'),
#  ('heurtas', 'heurtas'),
#  ('desvastes', 'desvastes'),
#  ('edifies', 'edifies'),
#  ('nombrerois', 'nombrerois'),
#  ('empire', 'empire'),
#  ('scelleroit', 'scelleroit'),
#  ('baiseroyent', 'baiseroyent'),
#  ('en deslopyant', 'en desployant'),
#  ('emblerois', 'emblerois'),
#  ('apatirois', 'apatirois'),
#  ('viseryons', 'viseryons'),
#  ('contrepoiseroient', 'contrepoiseroient'),
#  ('sollicitions', 'sollicitions'),
#  ('despencoyt', 'despençoyt'),
#  ('desieunyons', 'desieunyons'),
#  ('deschiroyent', 'deschiroyent'),
#  ('provocqueroys', 'provocqueroys'),
#  ('resignois', 'resignois'),
#  ('merveille', 'merveille'),
#  ('combinoyent', 'combinoyent'),
#  ('sollicitez', 'sollicitez'),
#  ('estonnas', 'estonnas'),
#  ('praesides', 'praesides'),
#  ('appuiois', 'appuiois'),
#  ('estiquiez', 'estiquent'),
#  ('desrouterions', 'desrouterions'),
#  ('seiourne', 'seiourne'),
#  ('aboscheray', 'aboscheray'),
#  ('approuvendenta', 'approuvendant'),
#  ('esmaya', 'esmaya'),
#  ('abhorreriez', 'abhorrerions'),
#  ('demanderois', 'demanderois'),
#  ('explorez', 'explorez'),
#  ('veillons', 'veillons'),
#  ('ronflerois', 'ronflerois'),
#  ('dampneroyent', 'dampneroyent'),
#  ('danceray', 'danceray'),
#  ('touchez', 'touchez'),
#  ('tiriez', 'tiriez'),
#  ('en desmonattes', 'en desmontant'),
#  ('leva', 'leva'),
#  ('apuyé', 'apuyé'),
#  ('emblassions', 'emblé'),
#  ('contregarderay', 'contregarderay'),
#  ('destournois', 'destournois'),
#  ('contregarderoyt', 'contregarderoyent'),
#  ('desmontoys', 'desmontyons'),
#  ('rappellasse', 'rappellasse'),
#  ('effectuasmes', 'effectuasmes'),
#  ('praesenteroys', 'praesenterois'),
#  ('engendrerons', 'engendrerons'),
#  ('encontreroys', 'encontreroys'),
#  ('effectuons', 'effectuons'),
#  ('despenceroyt', 'despenceroyt'),
#  ('desmettes', 'desmettes'),
#  ('prestois', 'prestoit'),
#  ('desborderoyt', 'desborderoyt'),
#  ('reverasses', 'reverassiez'),
#  ('raporterois', 'raporterois'),
#  ('gastiez', 'gastiez'),
#  ('verifieroient', 'verifieroient'),
#  ('reiglassiez', 'reiglassiez'),
#  ('seraineroys', 'seraineroys'),
#  ('estirent', 'estirent'),
#  ('escryera', 'escryera'),
#  ('pillastes', 'pillastes'),
#  ('erigeastes', 'erigeastes'),
#  ('appuieront', 'appuieront'),
#  ('mangent', 'mangent'),
#  ('pisse', 'pisse'),
#  ('intolle', 'aillent'),
#  ('logeras', 'logeras'),
#  ('cerchié', 'cerchié'),
#  ('en advouant', 'en advouant'),
#  ('rincer', 'rincer'),
#  ('deschevauchas', 'deschevauchas'),
#  ('despossessez', 'despossessez'),
#  ('enpoisonnast', 'enpoisonnast'),
#  ('desbaratoys', 'desbaratoys'),
#  ('deschargeyez', 'deschargyez'),
#  ('pourforcera', 'pourforcerai'),
#  ('eschevoys', 'eschevoys'),
#  ('mensonges', 'mensonges'),
#  ('accomplissions', 'accomplissions'),
#  ('abandonnerez', 'abandonnerez'),
#  ('conquesteroys', 'conquesteroys'),
#  ('enseigne', 'enseigne'),
#  ('allaicte', 'allaicte'),
#  ('confessons', 'confessons'),
#  ('enchargeroys', 'enchargeroys'),
#  ('despenceroient', 'despenceroient'),
#  ('couchions', 'couchions'),
#  ('poisoient', 'poisois'),
#  ('renommeroient', 'renommeroient'),
#  ('faschassions', 'faschassions'),
#  ('occurreroient', 'occurreroient'),
#  ('enterreroyent', 'enterreroys'),
#  ('evitoyt', 'evitoyt'),
#  ('supposons', 'supposons'),
#  ('detesteroys', 'detesteroys'),
#  ('leichera', 'leichera'),
#  ('affamer', 'affamerois'),
#  ('plaideroyent', 'plaideroyent'),
#  ('cuydastes', 'cuydasmes'),
#  ('mesla', 'mesla'),
#  ('arroie', 'arroie'),
#  ('pilleront', 'pilleront'),
#  ('endommaigeoyent', 'endommaigeoyent'),
#  ('coniecturyez', 'coniecturyez'),
#  ('pourmenions', 'pourmenions'),
#  ('adouite', 'adioustoyt'),
#  ('espoventastes', 'espoventastes'),
#  ('en desconseilleryez', 'en desconseillant'),
#  ('tourmenterois', 'tourmenterois'),
#  ('despossesassent', 'despossessant'),
#  ('doubtoit', 'doubtoit'),
#  ('croniquions', 'croniquions'),
#  ('esternuerions', 'esternuerions'),
#  ('eschappes', 'eschappes'),
#  ('esternue', 'esternue'),
#  ('assiege', 'assiege'),
#  ('espioit', 'espioit'),
#  ('enterre', 'enterre'),
#  ('esmayeray', 'esmayasmes'),
#  ('invaderay', 'invaderay'),
#  ('brusleray', 'brusleray'),
#  ('entrefrapant', 'entrefrapant'),
#  ('luittassions', 'luittassions'),
#  ('retyrassiez', 'retyrassiez'),
#  ('houoys', 'houyons'),
#  ('luitterois', 'luitterois'),
#  ('plaides', 'plaides'),
#  ('accuseryons', 'accuseryons'),
#  ('hasterions', 'hasterions'),
#  ('iolye', 'iolye'),
#  ('estons', 'soyons'),
#  ('viseroient', 'viseroient'),
#  ('pryez', 'pryez'),
#  ('veigler', 'veigler'),
#  ('enseignassent', 'enseignassent'),
#  ('desroutoyent', 'desroutoyent'),
#  ('soingnyons', 'soingnyez'),
#  ('enseignes', 'enseignes'),
#  ('descouchiez', 'descouchiez'),
#  ('reeryons', 'rejectyons'),
#  ('delivroys', 'delivroys'),
#  ('mercyoys', 'mercyoys'),
#  ('estiquiez', 'estiquierons'),
#  ('bobelinerions', 'bobelinerions'),
#  ('grappoys', 'grappoys'),
#  ('reculleroys', 'reculles'),
#  ('rouille', 'rouilles'),
#  ('esvente', 'esvente'),
#  ('dilatasmes', 'dilatasmes'),
#  ('visiterent', 'visiterent'),
#  ('singlera', 'singlera'),
#  ('invaderons', 'invaderoys'),
#  ('retires', 'retires'),
#  ('essayons', 'essayons'),
#  ('essayons', 'essayons'),
#  ('tourneroys', 'tourneroys'),
#  ('gabions', 'gabions'),
#  ('alongerions', 'alongerions'),
#  ('prattiqua', 'prattiqué'),
#  ('tremperoient', 'tremperoient'),
#  ('mensanchoys', 'mensongeant'),
#  ('apuyasse', 'apuyasse'),
#  ('en outrant', 'en tournoyant'),
#  ('avanchier', 'avanchier'),
#  ('en efroptasment', 'en effrontant'),
#  ('plieryez', 'plieryez'),
#  ('melancholiois', 'melancholiois'),
#  ('entrempinerouant', "s'entredemanderoient"),
#  ('esciellyons', 'esciellyons'),
#  ('esperonnois', 'esperonnions'),
#  ('soubhaittes', 'soubhaittes'),
#  ('appareilleront', 'appareilleront'),
#  ('expuysoys', 'expuysoys'),
#  ('respiryons', 'respiryons'),
#  ('retournassions', 'retournassions'),
#  ('escorcha', 'escorcha'),
#  ('executeray', 'executeray'),
#  ('eschevast', 'eschevast'),
#  ('temproys', 'temproys'),
#  ('eschapperions', 'eschapperions'),
#  ('acoustreroyent', 'acoustreroyent'),
#  ('enconchent', 'enconchent'),
#  ('proffite', 'proffite'),
#  ('excuissons', 'excusions'),
#  ('esquacheroient', 'esquacheroient'),
#  ('reiecteryez', 'reiecteryez'),
#  ('protegeons', 'protegeons'),
#  ('armoiassions', 'armoiassions'),
#  ('fumois', 'fumois'),
#  ('iurions', 'iurions'),
#  ('nouyez', 'nouyez'),
#  ('payas', 'payas'),
#  ('desyre', 'desyre'),
#  ('desancrer', 'desancrer'),
#  ('priasmes', 'priasmes'),
#  ('oza', 'oza'),
#  ('negotiastent', 'negotiant'),
#  ('iouons', 'iouons'),
#  ('melancholiassions', 'melancholiast'),
#  ('melancholies', 'melancholies'),
#  ('repraesentons', 'repraesentons'),
#  ('traveillaides', 'traveillieray'),
#  ('denunchie', 'denunchiyez'),
#  ('desrobbois', 'desrobbois'),
#  ('esparpille', 'esparpille'),
#  ('esloignasses', 'esloignasses'),
#  ('destableray', 'destableray'),
#  ('humilias', 'humiliast'),
#  ('abiurois', 'abiurois'),
#  ('espargneroient', 'espargneroient'),
#  ('evaporassent', 'evaporassent'),
#  ('accomplisse', 'accomplisses'),
#  ('gaimente', 'gaimente'),
#  ('prefereroys', 'prefereroys'),
#  ('baptises', 'baptises'),
#  ('frapoient', 'frapoient'),
#  ('advancez', 'advancez'),
#  ('meslions', 'meslions'),
#  ('roullent', 'roullent'),
#  ('essayerois', 'essayerois'),
#  ('desnouons', 'desnouons'),
#  ('deslyez', 'deslyez'),
#  ('pryoyt', 'pryoyt'),
#  ('guideras', 'guideras'),
#  ('ruyne', 'ruyne'),
#  ('meslerons', 'meslerons'),
#  ('donneriez', 'donneriez'),
#  ('iettez', 'iettez'),
#  ('payeroys', 'payeroys'),
#  ('iureroys', 'iureroys'),
#  ('melancholiez', 'melancholiez'),
#  ('redoubta', 'redoubta'),
#  ('menassiez', 'menassiez'),
#  ('abhorroit', 'abhorroit'),
#  ('tournoyt', 'tournoyt'),
#  ('desmelerent', 'desmelerent'),
#  ('delibere', 'delibere'),
#  ('desancreroient', 'desancrerions'),
#  ('proclame', 'proclame'),
#  ('reguardons', 'reguardons'),
#  ('persuaderions', 'persuaderions'),
#  ('desferoyt', 'desferoyt'),
#  ('explorerois', 'explorerois'),
#  ('amadoue', 'amadoue'),
#  ('enyvar', 'enyvra'),
#  ('esgareray', 'esgareray'),
#  ('armoiastes', 'armoiastes'),
#  ('escapperont', 'escapperont'),
#  ('trousse', 'trousse'),
#  ('rappellons', 'rappellons'),
#  ('retyreroys', 'retyreroys'),
#  ('tromperyez', 'tromperyez'),
#  ('roullons', 'roullons'),
#  ('expose', 'expose'),
#  ('appuieras', 'appuieras'),
#  ('monteroys', 'monteroys'),
#  ('avoient', 'aviez'),
#  ('gangle', 'gangle'),
#  ('allas', 'allois'),
#  ('pisses', 'pisses'),
#  ('escouté', 'escouté'),
#  ('en muclitentes', 'en mulctant'),
#  ('pourchassoyent', 'pourchassoyent'),
#  ('representassiez', 'representassiez'),
#  ('accoustumerions', 'accoustumerions'),
#  ('importunasmes', 'importuneray'),
#  ('merveillerai', 'merveillerai'),
#  ('suffocquera', 'suffocquastes'),
#  ('denunchiasses', 'denunchiassiez'),
#  ('empensiez', 'empensiez'),
#  ('eschaufferont', 'eschaufferont'),
#  ('desadvoueryons', 'desadvoueryons'),
#  ('fortifieroyt', 'fortifieroyt'),
#  ('desrisent', 'desrisent'),
#  ('desfiassois', 'desfaisions'),
#  ('avanches', 'avanches'),
#  ('creancerai', 'creançassent'),
#  ('esveiglerois', 'esveiglerois'),
#  ('empiroyt', 'empiroys'),
#  ('delibereront', 'delibereront'),
#  ('infourme', 'infourme'),
#  ('commenceroit', 'commencerois'),
#  ('explorerois', 'explorerions'),
#  ('tournerent', 'tournerent'),
#  ('empense', 'empense'),
#  ('demoure', 'demoure'),
#  ('iettassent', 'iettasmes'),
#  ('nommassiez', 'nommassiez'),
#  ('urient', 'urine'),
#  ('mucerions', 'mucerions'),
#  ('invaittyez', 'invitant'),
#  ('avois', 'aie'),
#  ('lyerez', 'lyerez'),
#  ('derver', 'derver'),
#  ('repraesentois', 'repraesentois'),
#  ('deshonnourent', 'deshonnourent'),
#  ('recommanderez', 'recommanderez'),
#  ('depeschoyt', 'depeschoyt'),
#  ('engroistasses', 'engroissastes'),
#  ('enchargei', 'enchargiez'),
#  ('enpoisonneras', 'enpoisonneras'),
#  ('accomplisse', 'accomplissoys'),
#  ('eschappois', 'eschappois'),
#  ('enchargions', 'enchargions'),
#  ('praeparas', 'praeparas'),
#  ('estachoient', 'estachoient'),
#  ('courroucent', 'courroucent'),
#  ('oultrageasses', 'oultrageasses'),
#  ('destablerent', 'destablerent'),
#  ('declairent', 'declairent'),
#  ('escielle', 'escielle'),
#  ('raporteras', 'raportasses'),
#  ('racointer', 'racointe'),
#  ('baptisast', 'baptizassiez'),
#  ('affamoient', 'affamoient'),
#  ('acquitassent', 'acquitasmes'),
#  ('seiourneryons', 'seiourneryons'),
#  ('negotient', 'negotient'),
#  ('pissoyt', 'pissoyt'),
#  ('asseigerons', 'assiegerons'),
#  ('entredonner', 'entredonner'),
#  ('rassuverant', "r'asseurant"),
#  ('operassions', 'operassions'),
#  ('arroieryons', 'arroieryez'),
#  ('surnommena', 'surnommant'),
#  ('mectroient', 'mectroient'),
#  ('esgratignassoys', 'esgratignoyent'),
#  ('houssepille', 'houssepille'),
#  ('communcient', 'communicqueront'),
#  ('courrouçasses', 'courrouçasse'),
#  ('conquestez', 'conquestez'),
#  ('affermoient', 'affermoient'),
#  ('allaictassiez', 'allaictasse'),
#  ('remonstrons', 'remonstrons'),
#  ('couchoyt', 'couchoyt'),
#  ('besoigne', 'besoigne'),
#  ('excusois', 'excusois'),
#  ('esvantasse', 'esvantasse'),
#  ('enferrassent', 'enferrassent'),
#  ('employe', 'employe'),
#  ('oublya', 'oublya'),
#  ('possedes', 'possedes'),
#  ('volloient', 'volloient'),
#  ('picquieroys', 'picquieroys'),
#  ('representer', 'representer'),
#  ('affiames', 'affiasmes'),
#  ('doubte', 'doubte'),
#  ('aydois', 'aydois'),
#  ('finoyt', 'finoyt'),
#  ('abiure', 'abiure'),
#  ('operez', 'operez'),
#  ('averois', 'eusses'),
#  ('iolyerons', 'iolyerons'),
#  ('nommeryons', 'nommeryons'),
#  ('subiugue', 'subiugé'),
#  ('rince', 'rince'),
#  ('irons', 'irons'),
#  ('en frapentar', 'en frapant'),
#  ('desinfiectons', 'desinfections'),
#  ('traveillastes', 'traveillastes'),
#  ('courouchassiez', 'courouchassiez'),
#  ('transgloutiront', 'transgloutiront'),
#  ('esclaira', 'esclairoit'),
#  ('courrouceray', 'courrouçastes'),
#  ('exposoys', 'exposoys'),
#  ('alimentes', 'alimentes'),
#  ('resistassiez', 'resistassiez'),
#  ('demonstre', 'demonstre'),
#  ('acoustume', 'acoustume'),
#  ('proffites', 'proffites'),
#  ('faschastes', 'faschastes'),
#  ('vuidois', 'vuidois'),
#  ('apatissoit', 'apatissoient'),
#  ('plaidast', 'plaidast'),
#  ('minora', 'minora'),
#  ('arraions', 'arroiasse'),
#  ('saulverez', 'saulverez'),
#  ('comptent', 'comptent'),
#  ('deffieriez', 'deffieriez'),
#  ('espiassiez', 'espiassiez'),
#  ('alonneras', 'alongent'),
#  ('urinasse', 'urinas'),
#  ('tombassent', 'tombassent'),
#  ('en contiastois', 'en cointoiant'),
#  ('fumasses', 'fumasses'),
#  ('opereryons', 'opereryez'),
#  ('finissent', 'finissent'),
#  ('peserons', 'peserons'),
#  ('pausmé', 'pausmé'),
#  ('en gelant', 'en gellant'),
#  ('contreront', 'contrerolloys'),
#  ('eschauffoit', 'eschauffoit'),
#  ('enseigneroys', 'enseignoyent'),
#  ('gaimonte', 'gaimentoit'),
#  ('reiettyez', 'reiettyez'),
#  ('reservions', 'reservions'),
#  ('mehaigniera', 'mehaigniera'),
#  ('rebarbyons', 'rebarbyons'),
#  ('bobelinas', 'bobelinas'),
#  ('desadvouez', 'desadvouez'),
#  ('reiectoyent', 'reiectoyent'),
#  ('escorcheroyent', 'escorcheroyent'),
#  ('abhorra', 'abhorra'),
#  ('verifia', 'verifia'),
#  ('estudias', 'estudias'),
#  ('desregleroys', 'desregleroys'),
#  ('roullois', 'roullois'),
#  ('guidoient', 'guidoient'),
#  ('dançoys', 'dançoys'),
#  ('asseurez', 'asseures'),
#  ('hachoys', 'hachoys'),
#  ('enterrerois', 'enterrerois'),
#  ('nombrassions', 'nombrassions'),
#  ('exposassiez', 'exposassiez'),
#  ('evaporent', 'evaporent'),
#  ('cercheroient', 'cercheroient'),
#  ('maschez', 'maschez'),
#  ('leicherions', 'leicherions'),
#  ('leschons', 'leschons'),
#  ('traittié', 'traittié'),
#  ('en erseinatt', 'en reiettant'),
#  ('enorter', 'enorter'),
#  ('melancholierent', 'melancholierez'),
#  ('deshonnourerois', 'deshonnourerois'),
#  ('despucelleroys', 'despucelleroys'),
#  ('melancholiez', 'melancholiez'),
#  ('representeroient', 'representeroient'),
#  ('empeschoient', 'empeschoient'),
#  ('contribuerez', 'contribueriez'),
#  ('pourpensent', 'pourpensent'),
#  ('supescere', 'supersedez'),
#  ('deschargeroys', 'deschargeroys'),
#  ('conquestent', 'conquestent'),
#  ('croniquieroient', 'croniquieroient'),
#  ('celebroys', 'celebrois'),
#  ('retiroys', 'retiroys'),
#  ('remerquent', 'remerquent'),
#  ('entornçons', 'en contrerollant'),
#  ('negotieroyt', 'negotieroyt'),
#  ('devourerons', 'devourerons'),
#  ('trempa', 'trempa'),
#  ('desbordons', 'desbordons'),
#  ('humilie', 'humilie'),
#  ('arresteriez', 'arresteriez'),
#  ('lurreras', 'lurrasses'),
#  ('vuidasse', 'vuidassiez'),
#  ('laisseras', 'laisseras'),
#  ('songes', 'songes'),
#  ('mesclons', 'mesclons'),
#  ('iura', 'iura'),
#  ('macte', 'macte'),
#  ('tractié', 'tracté'),
#  ('en riflatte', 'en rifflant'),
#  ('cessé', 'cessé'),
#  ('estincelleroys', 'estincelloyent'),
#  ('condescendies', 'condescendisse'),
#  ('desbaucheray', 'desbaucheray'),
#  ('desployoit', 'desployoit'),
#  ('recommandons', 'recommandons'),
#  ('endommaigerons', 'endommaigerons'),
#  ('respiryez', 'respiryez'),
#  ('amadouoyt', 'amadouoyt'),
#  ('inquieta', 'inquieta'),
#  ('subiuguiez', 'subiuguiez'),
#  ('raportions', 'raportions'),
#  ('provocque', 'provocque'),
#  ('enortoys', 'enortoys'),
#  ('desroberas', 'desroberai'),
#  ('cointoieroyent', 'cointoieroyent'),
#  ('divinas', 'divinas'),
#  ('iolyoyt', 'iolyoyt'),
#  ('cachions', 'cachions'),
#  ('desnoueront', 'desnoueront'),
#  ('estoffons', 'estoffons'),
#  ('demourera', 'demourera'),
#  ('questeriez', 'questeriez'),
#  ('perserez', 'perserent'),
#  ('embleryons', 'embleray'),
#  ('coustez', 'coustez'),
#  ('herrie', 'herrie'),
#  ('hastons', 'hastons'),
#  ('rengera', 'rengera'),
#  ('rottons', 'rottons'),
#  ('iouerois', 'iouerois'),
#  ('amasmes', 'amasmes'),
#  ('aquitter', 'aquitter'),
#  ('appareillast', 'appareillast'),
#  ('desadvouyez', 'desadvouyez'),
#  ('despouliez', 'despouillez'),
#  ('remonstra', 'remonstra'),
#  ('practicqueroient', 'practicqueroient'),
#  ('acoustrassent', 'acoustrassent'),
#  ('desmontassions', 'desmontassions'),
#  ('faschoit', 'faschoit'),
#  ('desieuneroient', 'desieuneroient'),
#  ('questoys', 'questoys'),
#  ('occurreroys', 'occurreroys'),
#  ('laschassiez', 'laschassiez'),
#  ('estouffons', 'estouffons'),
#  ('desrisez', 'desrisiez'),
#  ('quitoyt', 'quitoyt'),
#  ('infourmons', 'infourmons'),
#  ('chocque', 'chocque'),
#  ('advoueriez', 'advoueriez'),
#  ('roulleroient', 'roulleroient'),
#  ('ieusneriez', 'ieusneriez'),
#  ('effreez', 'effreez'),
#  ('frapperiez', 'frapperiez'),
#  ('renfleront', 'renfleront'),
#  ('esperonné', 'esperonné'),
#  ('seellez', 'seellez'),
#  ('aorneriez', 'aorneriez'),
#  ('cacherons', 'cacherons'),
#  ('robberas', 'robberas'),
#  ('cesseroit', 'cesseroit'),
#  ('logeroyent', 'logeroyent'),
#  ('cape', 'cape'),
#  ('finirions', 'finirois'),
#  ('housseillé', 'houssepilliez'),
#  ('coniecturoyent', 'coniecturoyent'),
#  ('netrenouchera', 'nousentrencontrerions'),
#  ('contregarderoys', 'contregarderoys'),
#  ('estourdist', 'estourdissoyy'),
#  ('atermineray', 'atermineray'),
#  ('escouillez', 'escouillons'),
#  ('accointasses', 'accointasses'),
#  ('esciellerez', 'esciellerez'),
#  ('encontreroit', 'encontreroit'),
#  ('fortifieroit', 'fortifieroit'),
#  ('surnomme', 'surnomme'),
#  ('tournasses', 'tournasses'),
#  ('empirassiez', 'empirassiez'),
#  ('arrivasse', 'arrivasse'),
#  ('possedons', 'possedez'),
#  ('fomenteriez', 'fomenteriez'),
#  ('ronflas', 'ronflas'),
#  ('bransleroys', 'bransleroys'),
#  ('houois', 'houois'),
#  ('pensastes', 'pensastes'),
#  ('brusles', 'brusles'),
#  ('heilas', 'heilas'),
#  ('cuyderont', 'cuyderont'),
#  ('lurreroys', 'lurreroys'),
#  ('muspastes', 'muçasses'),
#  ('minorez', 'minorez'),
#  ('en membançant', 'en embausmant'),
#  ('prya', 'prya'),
#  ('souppez', 'souppez'),
#  ('donne', 'donne'),
#  ('en luitant', 'en luittant'),
#  ('deschevauchons', 'deschevauchons'),
#  ('melancholiera', 'melancholiera'),
#  ('bancquetois', 'bancquetois'),
#  ('raenchonnerons', 'raenchonnerons'),
#  ('representes', 'representes'),
#  ('despucelleryons', 'despucelleryons'),
#  ('denunchias', 'denunchia'),
#  ('hebergeasses', 'hebergeasses'),
#  ('rassueryez', "r'asseure"),
#  ('troussoys', 'troussoys'),
#  ('avanchiez', 'avanchiez'),
#  ('intoxiquez', 'intoxiquez'),
#  ('tabusteray', 'tabusteray'),
#  ('soumest', 'soumets'),
#  ('soulaiges', 'soulaiges'),
#  ('enortoys', 'enortoys'),
#  ('espouserent', 'espouserent'),
#  ('desfaste', 'desfet'),
#  ('reguardez', 'reguardez'),
#  ('evaporeray', 'evaporeroyt'),
#  ('ottroyerois', 'ottroyerois'),
#  ('fomente', 'fomente'),
#  ('demeslera', 'demeslera'),
#  ('pacqueray', 'pacqueray'),
#  ('adviserons', 'adviserons'),
#  ('invaderait', 'invaderoient'),
#  ('gousteroit', 'gousteroit'),
#  ('recorde', 'recorde'),
#  ('exstirper', 'exstirper'),
#  ('penserons', 'penserons'),
#  ('iureryez', 'iureryez'),
#  ('bruslé', 'bruslé'),
#  ('desprisonnent', 'desprisonnent'),
#  ('despouillerez', 'despouillerez'),
#  ('descourageroys', 'descourageroys'),
#  ('preasterent', 'praesenterent'),
#  ('pourchassent', 'pourchassent'),
#  ('alimentassions', 'alimentassions'),
#  ('explorois', 'explorois'),
#  ('eschauffez', 'eschauffez'),
#  ('remercyeroyt', 'remercyeroyt'),
#  ('assistasmes', 'assistasmes'),
#  ('esgarions', 'esgarions'),
#  ('oublyasses', 'oublyasses'),
#  ('menasseroys', 'menasseroys'),
#  ('persoient', 'persoient'),
#  ('expellez', 'expellent'),
#  ('passoys', 'passois'),
#  ('bruslasse', 'bruslasse'),
#  ('soingnerois', 'soingnerez'),
#  ('exposerent', 'exposerent'),
#  ('baptise', 'baptise'),
#  ('escria', 'escria'),
#  ('gangleryons', 'gangleryons'),
#  ('esgare', 'esgare'),
#  ('trampes', 'trampes'),
#  ('heurterez', 'heurterez'),
#  ('oublyeroys', 'oublyeroys'),
#  ('cessa', 'cessa'),
#  ('visa', 'visa'),
#  ('porteroys', 'porteroys'),
#  ('revere', 'revere'),
#  ('avois', 'aions'),
#  ('payé', 'payé'),
#  ('desconseille', 'desconseille'),
#  ('rsuasle', "r'asseurions"),
#  ('repraesente', 'repraesente'),
#  ('appareillasses', 'appareillasses'),
#  ('estiquois', 'estiquois'),
#  ('gaspilloyt', 'gaspilloyt'),
#  ('desmettois', 'desmettoient'),
#  ('laidengeassiez', 'laidengeassent'),
#  ('cointoia', 'cointoia'),
#  ('hostoiois', 'hostoiois'),
#  ('esclaire', 'esclaire'),
#  ('rebarbastes', 'rebarbastes'),
#  ('ordonnassiez', 'ordonnassiez'),
#  ('delacerent', 'delacerent'),
#  ('esbauche', 'esbauche'),
#  ('humiliasse', 'humiliassiez'),
#  ('atempterois', 'atempterois'),
#  ('escarteroys', 'escarteroys'),
#  ('gouvernez', 'gouvernez'),
#  ('honnoure', 'honnoure'),
#  ('explicher', 'explicquer'),
#  ('vengerioyt', 'vengieroyent'),
#  ('navreray', 'navreray'),
#  ('couchera', 'couchera'),
#  ('aymasse', 'aymasse'),
#  ('cachent', 'cachent'),
#  ('doubtons', 'doubtons'),
#  ('vuide', 'vuide'),
#  ('preterons', 'preterons'),
#  ('desyrez', 'desyrez'),
#  ('mectent', 'mectent'),
#  ('estoffié', 'estoffé'),
#  ('condescendoient', 'condescendeient'),
#  ('nettornoure', "s'entredonnoient"),
#  ('approuvendez', 'approuvendez'),
#  ('transportassent', 'transportassent'),
#  ('estrangliasse', 'estranglassions'),
#  ('inquietois', 'inquietois'),
#  ('soumissez', 'soumis'),
#  ('escouille', 'escouille'),
#  ('respiroyent', 'respiroyent'),
#  ('pourpense', 'pourpense'),
#  ('praepareras', 'praeparasses'),
#  ('redoubterons', 'redoubterons'),
#  ('desmettent', 'desmettez'),
#  ('empescherions', 'empescherions'),
#  ('chantoyent', 'chantoyent'),
#  ('trouvassions', 'trouvassions'),
#  ('delacera', 'delacera'),
#  ('iettoyent', 'iettoyent'),
#  ('appuiassent', 'appuiassent'),
#  ('ieusnasmes', 'ieusnasmes'),
#  ('evaporeront', 'evaporeront'),
#  ('desistons', 'desistons'),
#  ('coucheras', 'coucheras'),
#  ('laisse', 'laisse'),
#  ('intoxiquerons', 'intoxiquer'),
#  ('trampez', 'trampez'),
#  ('bobleiné', 'bobeliné'),
#  ('navreroys', 'navreroys'),
#  ('gette', 'gette'),
#  ('marieryez', 'marieryez'),
#  ('aerassez', 'aerastes'),
#  ('mangent', 'mangent'),
#  ('desbaratois', 'desbaratois'),
#  ('abandonnier', 'abandonniez'),
#  ('desheritois', 'desheritois'),
#  ('supersions', 'supersedions'),
#  ('cointoioit', 'cointoioit'),
#  ('desinfectes', 'desinfectes'),
#  ('avanchassiez', 'avanchastes'),
#  ('estouffasmes', 'estouffasmes'),
#  ('pasturoyt', 'pasturoyt'),
#  ('presumasse', 'presumasse'),
#  ('hebergieryez', 'hebergieryez'),
#  ('souspireront', 'souspirerons'),
#  ('esventerai', 'esventerai'),
#  ('traittierons', 'traittierons'),
#  ('respirerions', 'respirerions'),
#  ('esguise', 'esguise'),
#  ('arroiasses', 'arroiasses'),
#  ('meslois', 'meslois'),
#  ('ymagineroys', 'ymagineroys'),
#  ('regardez', 'regardez'),
#  ('ostoye', 'ostoyt'),
#  ('exposeront', 'exposeront'),
#  ('foullez', 'foullez'),
#  ('baisleroyent', 'baisleroyent'),
#  ('engroissant', 'engroissant'),
#  ('saurperois', 'sçaurayent'),
#  ('oublyerois', 'oublyerois'),
#  ('doubtera', 'doubtera'),
#  ('amas', 'amas'),
#  ('iroyt', 'yrions'),
#  ('humilié', 'humilié'),
#  ('hua', 'hua'),
#  ('despossessererez', 'despossesserent'),
#  ('accompaigne', 'accompaigne'),
#  ('esgratigne', 'esgratigne'),
#  ('suffocquasses', 'suffocquasses'),
#  ('depeschyons', 'depeschyons'),
#  ('estoffois', 'estoffois'),
#  ('escartoyt', 'escartyons'),
#  ('desbauchez', 'desbauchons'),
#  ('desplaceras', 'desplaceras'),
#  ('desrobasses', 'desrobasses'),
#  ('esloignera', 'esloignera'),
#  ('persuadons', 'persuadons'),
#  ('demanda', 'demanda'),
#  ('buchas', 'buchas'),
#  ('escappe', 'escappe'),
#  ('ymaginasses', 'ymagineras'),
#  ('estachasse', 'estachera'),
#  ('regarderont', 'regarderont'),
#  ('hachoys', 'hachyons'),
#  ('protegerez', 'protegerez'),
#  ('minoras', 'minoras'),
#  ('baptizerois', 'baptizerois'),
#  ('flotte', 'flottes'),
#  ('eviterai', 'eviterai'),
#  ('avoient', 'avoient'),
#  ('advoueryons', 'advoueryons'),
#  ('esgalerons', 'esgalerons'),
#  ('veigle', 'veigle'),
#  ('muçoyent', 'muçoyent'),
#  ('resveroit', 'resveroit'),
#  ('hachera', 'hachera'),
#  ('pryeryez', 'pryeryez'),
#  ('despucellyez', 'despucellyez'),
#  ('croniquiois', 'croniquiois'),
#  ('desadvouoit', 'desadvouoit'),
#  ('melancholieroys', 'melancholieroys'),
#  ('racointoyent', 'racointoyent'),
#  ('despucellent', 'despucellent'),
#  ('despucelleroient', 'despucelleroient'),
#  ('acoustumeroyt', 'acoustumeroyt'),
#  ('reservoyent', 'reservyons'),
#  ('impugnyons', 'impugnyons'),
#  ('eschappa', 'eschappa'),
#  ('estrangleroys', 'estrangleroys'),
#  ('desmonterons', 'desmonterons'),
#  ('tremblast', 'tremblast'),
#  ('retyroys', 'retyroys'),
#  ('regretterons', 'regretterez'),
#  ('aguysassiez', 'aguysassions'),
#  ('questerent', 'questerent'),
#  ('depeschez', 'depeschez'),
#  ('gastois', 'gastois'),
#  ('prestera', 'prestera'),
#  ('deifieras', 'deifieras'),
#  ('hasta', 'hasta'),
#  ('ploya', 'ployas'),
#  ('reiglons', 'reiglons'),
#  ('desyreroyent', 'desyreroyent'),
#  ('pecheroient', 'pecheroient'),
#  ('alosse', 'alose'),
#  ('mectrons', 'menctent'),
#  ('iolyeryons', 'iolyeryons'),
#  ('cuyderois', 'cuyderois'),
#  ('alossez', 'aloses'),
#  ('raenchonniez', 'raenchonniez'),
#  ('fortiffiyez', 'fortiffiyez'),
#  ('desprisonne', 'desprisonne'),
#  ('repraesenterant', 'repraesentent'),
#  ('seiournoys', 'seiournoys'),
#  ('transpornterons', 'transportent'),
#  ('desbaucheryez', 'desbaucheryez'),
#  ('contribuoys', 'contribuons'),
#  ('moustroys', 'moustroys'),
#  ('delibereroyent', 'delibereroyent'),
#  ('residisons', 'residiez'),
#  ('esveiglerions', 'esveiglerions'),
#  ('traittes', 'traittes'),
#  ('quittoyt', 'quittoyt'),
#  ('leschassiez', 'leschassiez'),
#  ('guerpissas', 'guerpisses'),
#  ('soubhaittyons', 'soubhaitté'),
#  ('enterrez', 'enterrez'),
#  ('inviteray', 'invitasse'),
#  ('ausyez', 'ausyez'),
#  ('navrasmes', 'navrasmes'),
#  ('pecha', 'pecha'),
#  ('buches', 'buches'),
#  ('souppez', 'souppez'),
#  ('empiege', 'empiege'),
#  ('tumbe', 'tumbe'),
#  ('houasses', 'houasses'),
#  ('tireroyent', 'tireroyent'),
#  ('pissons', 'pissons'),
#  ('supposse', 'supposé'),
#  ('aymerois', 'aymerois'),
#  ('amer', 'amerez'),
#  ('praesidois', 'praesidois'),
#  ('particiastes', 'participassiez'),
#  ('courouchierois', 'courouchierois'),
#  ('bancqueta', 'bancqueta'),
#  ('esclairasse', 'esclairasse'),
#  ('arrestas', 'arrestyez'),
#  ('gouvernastes', 'gouvernastes'),
#  ('translaterons', 'translaterons'),
#  ('esternues', 'esternues'),
#  ('desbordez', 'desbordez'),
#  ('praeparerions', 'praeparerions'),
#  ('espousas', 'espousas'),
#  ('baptisa', 'baptisa'),
#  ('escapperiez', 'escapperai'),
#  ('gardoyt', 'gardoyt'),
#  ('essayasses', 'essayasses'),
#  ('tremble', 'tremble'),
#  ('esprouvent', 'esprouvez'),
#  ('chanterons', 'chanterons'),
#  ('ymaginons', 'ymaginons'),
#  ('essayeront', 'essayeront'),
#  ('persassez', 'persast'),
#  ('occuperoys', 'occuperoys'),
#  ('renfle', 'renfle'),
#  ('parlasse', 'parlasse'),
#  ('vuiderions', 'vuiderions'),
#  ('abayerasse', 'abayeras'),
#  ('mett', 'mette'),
#  ('reentrade', 'rejectant'),
#  ('aions', 'ayons'),
#  ('logeroit', 'logeroient'),
#  ('resumant', 'resumant'),
#  ('desheritoys', 'desheritoys'),
#  ('esgratignastes', 'esgratignastes'),
#  ('seiournions', 'seiournions'),
#  ('transportez', 'transportez'),
#  ('affermassions', 'affermassions'),
#  ('honnourerois', 'honnourerois'),
#  ('possesserez', 'possesserez'),
#  ('soulaigerai', 'soulaigeroit'),
#  ('recordassent', 'recordassent'),
#  ('enterrasse', 'enterrasse'),
#  ('accepterons', 'accepterons'),
#  ('escapperois', 'escapperois'),
#  ('appuiras', 'appuiasse'),
#  ('amadouerontes', 'amadoueroient'),
#  ('estudiez', 'estudiez'),
#  ('baptisent', 'baptisent'),
#  ('ordonnerions', 'ordonnerions'),
#  ('advançons', 'advançons'),
#  ('assisteras', 'assisteras'),
#  ('mascha', 'mascha'),
#  ('garderoient', 'garderay'),
#  ('disnassions', 'disnassions'),
#  ('tocqueroient', 'tocqueroient'),
#  ('abiurez', 'abiurez'),
#  ('tes', 'fut'),
#  ('pocheront', 'pocheront'),
#  ('achevez', 'achevez'),
#  ('poiseroys', 'poiseroys'),
#  ('fassent', 'faciez'),
#  ('aydez', 'aydez'),
#  ('expuysant', 'expuysant'),
#  ('en pesant', 'en pesant'),
#  ('entrempinoueray', 'entredemandoyent'),
#  ('contrerorons', 'contrerollassent'),
#  ('estrangloyent', 'estrangloyent'),
#  ('engroysiez', 'engroissyons'),
#  ('desregloys', 'desregloys'),
#  ('represente', 'represente'),
#  ('bancquete', 'bancquete'),
#  ('recupereray', 'recupereray'),
#  ...]

# %% [markdown]
# ### Development Dataset

# %%
lemmas_dev, tags_dev, inflected_forms_dev = load_data('./conll2018/task1/all/middle-french-dev')

# %%
evaluate(*test(lemmas_dev, tags_dev, inflected_forms_dev))
# Out:
# (0.795, 0.617)

# %%
for pred, true in list(zip(*test(lemmas_dev, tags_dev, inflected_forms_dev))):
    print(pred, true)
# Out:
# enconvenencierois enconvenencierois
# pourpensiez pourpensiez
# accompaignerez accompaignerez
# allaictois allaictois
# adioustoyt adioustoyent
# menassoys menassoys
# pourforce pourforce
# approuche approuche
# effectuas effectuas
# evaporiez evaporiez
# besoigneroient besoigneroient
# desista desista
# baptisastes baptisastes
# essayoys essayoys
# afferma afferma
# armoias armoia
# essilieroys essilieroys
# exploreriez exploreriez
# aornois aornois
# esperassiez esperassiez
# evitue evityez
# gaigne gaigna
# eslancent eslancent
# baysassions baysassions
# desyrez desyrent
# estimerions estimerions
# affieront affieront
# mesleroient mesleroient
# resveroyt resveroyt
# oublye oublye
# cryes cryes
# en delassions en deslyant
# esgratignasse esgratignasse
# accomplist accomplissoyy
# entitulyez entitulyez
# allaigions allaictyez
# gouvernyons gouvernyons
# enchargeassions enchargeassent
# accointasse accointyez
# eschaufferiez eschaufferiez
# trousseroyt troussois
# inquietons inquietons
# souspirera souspirera
# esbauchons esbauchons
# esquachent esquachent
# esguisa esguisa
# tournoyeryons tournoyeriez
# tournastes tournastes
# supposeroient supposeroit
# cherchez cherchent
# apatisoys apatissoyent
# huchastes huchastes
# empiegeons empiegeons
# desirera desirera
# reiettez reiettez
# leschera leschera
# capa capa
# songent songent
# dancent dancent
# affions affions
# retire retire
# iecteriez iecteriez
# rouille rouiller
# cryeryons cryeryons
# conseilloient conseilloient
# practicquent practicquent
# redoubtoys redoubtoys
# renouvellent renouvellent
# blasphement blasphement
# destablassent destablassent
# intoxiqueroys intoxiqueroys
# souspire souspire
# despencerois despencerois
# prospererez prospererez
# enterrerai enterrerai
# gaimenteroyent gaimenteroyent
# obligerent obligerent
# delacent delacent
# dançoyent dançoyent
# reiecteroys reiecteroys
# desistez desistez
# gousteryons gousteray
# toucherons toucherent
# embouchez embouchez
# vuidyons vuidyons
# habiterons habiterons
# accuserions accuserions
# avois avoyent
# fiancera fiancera
# mascheroit mascheroit
# embausmé embausmé
# aerasmes aerasmes
# fluirois fluirois
# moustrer moustrer
# evitez evitez
# toquer toquer
# descouchierions descouchierions
# esternuoyent esternuoyent
# enpoisonnerois enpoisonnerois
# conseilla conseilla
# enchargeassions enchargeast
# reiectoys reiectoys
# reculliera recullassiez
# penestasser penetrasses
# desheritons desheritons
# quereleriez quereleriez
# quererent quereleras
# declairons declairons
# honnourons honnourons
# toquoyent toquoyent
# coucha coucha
# desploie desploie
# empirasmes empirasmes
# habitassiez habitassiez
# prepareroys prepareroys
# achapterois achapterois
# escorche escorche
# invitas invitas
# nombres nombres
# ausoye ausoyt
# visiterent visiteriez
# aguyserions aguyserions
# apuyons apuyons
# rinceryons rinceryons
# disnons disnons
# retyrez retyrez
# gardons gardons
# dervé dervé
# traveilloit traveilloit
# contregarderois contregarderions
# escouilloit escouilloit
# courouchierons courouchierent
# asseuroys asseuroys
# empescherai empescherai
# resignoit resignoit
# mortifieront mortifieront
# confermeriez confermeriez
# accomplirois accomplirois
# honnoureront honnoureront
# commenconse commençons
# veigla veigla
# exploreroyent exploreroyent
# lurryez lurryez
# aguysassent aguysassent
# cachoys cachoys
# fianceryons fianceryons
# escumez escumez
# mercyent mercyent
# revereriez revereriez
# redrechié redrechié
# temprerons temprerons
# avallons avallons
# urinent urinent
# toques toques
# ruyneryons ruyneryons
# pecherois pecherois
# marions marions
# macterois macterois
# pryent pryent
# branslé branslé
# interpretassions interpretassions
# accompaigneroient accompaigneroient
# desbauchoys desbauchoys
# deschargeas deschargeas
# demonstra demonstra
# esveiglois esveiglois
# regrettoient regrettoyt
# enchargeoys enchargeoys
# detranchent detranchent
# demonstrons demonstrons
# delibererent delibererent
# prefera preferas
# quereleray quereleray
# gaignyons gaignyons
# estimois estimois
# arachoys arachyons
# destachons destachons
# gaignassions gaignassions
# invadasmes invadasse
# doubta doubta
# emblasse emblas
# escrieryons escrieryons
# logerai logeasses
# habite habite
# escouiller escouiller
# evites evites
# aymerai aymerai
# cuyde cuydes
# leve leve
# notons notons
# onseture en troussant
# ale va
# courrouches courrouches
# courrouchiez courrouchiez
# alimentoit alimentoit
# espoventeryez espoventeryez
# ordonnois ordonnoit
# pourforces pourforces
# tranchyons tranchyons
# embausma embausma
# empensoys empensoys
# tesmoigneront tesmoignerons
# racompteroyent racompteroyent
# espousasses espousasses
# edifioys edifioys
# acoustre acoustre
# desployeriez desployeriez
# soumectez soumectez
# seraineront serainerois
# enferrez enferrez
# moustrent moustrent
# deliberons deliberons
# avanchions avanchions
# estiquions estiquions
# enconvenierant en coniecturant
# tramperont tramperont
# estime estime
# affies affies
# fluissa fluisse
# abayons abayons
# alosez alosez
# escappes escapper
# aymez aymez
# cryons cryons
# enconvenençoys enconvenençoys
# netrpousmeras entrefrappyons
# entrefiera entrefismes
# declairoyt declairoyt
# racointa racointa
# remonstreroit remonstreroit
# possesses possesses
# acoustumez acoustumez
# laidengent laidengent
# iniuriera iniuriasses
# racomptent racomptent
# reietterai reietterai
# esleveray esleveray
# pissiez pissiez
# heilyez heilyez
# estudieroit estudieroit
# ployions ployions
# pillyons pillyons
# protegere protegeriez
# levoient levoient
# faisoys faisoys
# ausois ausois
# alterons alterons
# resumes resumes
# quitterant quitteront
# en esverant en esvertuant
# dilatons dilatons
# lurrez lurrez
# ferions faces
# celeroys celeroys
# fluirois fluirions
# ceusle jecter
# despossessa despossessa
# traveilloyt traveilloyt
# abandonnoyent abandonnoyent
# descourage descourage
# embouchois embouchois
# acceptoiez acceptoient
# cauteriez cauterizeroys
# expuysiez expuysiez
# rappellasmes rappelleray
# estonnyez estonnyez
# deschaineryons deschaineryons
# souspirasses souspirassiez
# tremblerai tremblerai
# redoubterez redoubterez
# gaignoyent gaignoyent
# tocquions tocquions
# entitluent entitulent
# gaimente gaimente
# heilyons heilyons
# renommeroys renommeroys
# gastoient gastoient
# renomme renomme
# moderons moderons
# exposons exposons
# estimeroyt estimeroyt
# espierent espierent
# edifieryons edifieryons
# escryeroys escryeroys
# esgale esgale
# lurrons lurrons
# assister assister
# huastes huastes
# contrepoisastes contrepoisasmes
# accompaigneryons accompaigneryons
# presupperoitez presupposerai
# empoizonne empoizonne
# traittoient traittoient
# travaillastes travaillastes
# empoizonnerions empoizonnerions
# desregliez desregliez
# accompliassent accomplirai
# enseigne enseigne
# presentassiez presentassiez
# plaidoyt plaidoyt
# flattoys flattoys
# plaidyons plaidyons
# inquieterois inquieterions
# raportent raportent
# encommencer encommencer
# enterreroyent enterreroys
# protegeroyt protegeryons
# esparplier esparpiller
# frapions frapions
# ottroyeront ottroyeront
# desnoue desnoue
# saultez saultez
# tramperoient tramperoient
# souppes souppes
# toqua toqua
# danceroit danceroit
# ostassent ostassent
# nommeryez nommeryez
# menassant menassant
# empiegant empiegeant
# contregardant contregardas
# desconseille desconseille
# estincellasses estincellasses
# encommences encommences
# detranchez detranchiez
# conquestassiez conquestassiez
# empeschassiez empeschassiez
# courrouces courrouces
# soulaigeasse soulaigeassiez
# hebergeas hebergeas
# cabassasser cabassasses
# amadoua amadoua
# arrengierois arrengierois
# respirasmes respirasmes
# possederiez possederiez
# monstreroyt monstreroyt
# pretiez pretiez
# accorderoient accorderoient
# separerai separerai
# pastures pastures
# couchasses couchasses
# laschasses laschasses
# esventes esventes
# espereroys espereroys
# lasches lasches
# retireryez retireryez
# porta portas
# vollez vollez
# en desitassent en desistant
# tempré tempré
# hachant hachant
# ayez avoyr
# soubhaittasmes soubhaitteray
# redrechois redrechois
# renouvellasse renouvellasse
# entreruyneras vous entreruynerez
# resigniez resigniez
# suffocquerois suffocquerois
# mehaigne mehaigne
# quereloye quereloys
# desroutas desroutas
# praesenteryez praesenteryez
# remonstres remonstres
# desguisast desguisast
# estiquieroient estiquieroient
# subiecteroient subiecteroient
# fleschié fleschissoyy
# chocquassions chocquassions
# encontreras encontreras
# monstrez monstrez
# bransleryez bransleryez
# cuydoys cuydoys
# desloge desloge
# employeroys employeroys
# riffleryons riffleryons
# cryoit cryoit
# arriveryez arriveryez
# pecheroyent pecheront
# espieroient espieroyent
# desplacer desplacer
# tuassent tuastes
# prefleré preferé
# cabassois cabassé
# payeroyt payeroyt
# contrepoisierons contrepoisiez
# entrencontrez entrencontrez vous
# desguisoient desguisoient
# pourpensassent pourpensasmes
# fourageoys fourageoys
# soubhaittyez soubhaitteroys
# exstirpois exstirpois
# encommencerions encommencerions
# praesidyons praesidyons
# enhortois enhortois
# intoxiquerez intoxiquerez
# conquesterions conquesterions
# soucyoyent soucyoyent
# cerchieray cerchieray
# revencheroient revencheroient
# trompyons trompyons
# esvertuera esvertuera
# moderasmes moderasmes
# enclineroyent enclineroyent
# nommyez nommyez
# sicquastes sçavions
# demeslez demeslez
# chargent chargent
# enyvroys enyvrons
# guiderai guiderai
# vengions vengions
# mettons mettrons
# dancera dancera
# hucherois hucherois
# ruyneroys ruyneroyt
# pryeriez pryeriez
# levons levons
# recommanderyons recommandyez
# courrouchiez courrouchent
# eschauffoyent eschauffoyent
# desbauchoyent desbauchoyent
# fortiffiastes fortiffiastes
# presentoys presentoys
# enpoisonne enpoisonne
# representeront representeront
# pourchasse pourchasse
# precedions precedions
# escheviez escheviez
# delibereray delibereray
# regratiasse regratiasse
# enchargeroys enchargeryons
# nombroyt nombroyt
# enconcherasse enconcheras
# iniurierai iniurierai
# expuysassions expuysassions
# presumast presumast
# trouverai trouverai
# possedes possedes
# hachoient hachoient
# trampa trampa
# enclinons enclinons
# quitte quitte
# enyvreroys enyvreroyt
# foettera foettera
# bancqueterons bancqueter
# desbordé desbordé
# finiroys finiroys
# hueriez hueriez
# logeons logeons
# appareilloient appareilloyent
# contregardent contregardent
# chevauchieroys chevauchieroys
# accomplissas accomplissiez
# destournez destournez
# precedois precedois
# embausmeront embausmeront
# racomptes racomptes
# galopoyent galopoyent
# enconches enconches
# veiglois veiglois
# esveillera esveillera
# meritiois meritions
# comptoys comptoys
# affermenter affermerent
# persuaderoient persuaderoient
# oultrageras oultrageras
# delibereroys delibereryons
# obligeasses obligeasses
# huchions huchions
# penetrez penetrent
# cerchesiez cerches
# bancqueté bancqueté
# notoyent notoyent
# separeroys separerois
# assistez assistez
# capoys capyons
# alosasse alosasse
# celois celois
# mulctez mulctez
# esclairant esclairant
# desguisse desguiser
# esmerveilassiez esmerveillasses
# empoizonnoyt empoizonnoyt
# redrechoyent redrechoyent
# estincelleray estincelleray
# remonstrassions remonstrassions
# interpreteriez interpreteriez
# transporteroys transporteroys
# encontrast encontrast
# pourforcez pourforcez
# mehaignieront mehaignieront
# escielles escielles
# soingnoient soingnoyent
# possoyent possedoyt
# fremontryons fromenteryez
# expellastes expellastes
# picquassions picquast
# delaisseroys delaisseroys
# picquoit picquoit
# reculleray reculleray
# ottroyeroyt ottroyeroyt
# rebarbasmes rebarbera
# impugne impugne
# acquitent acquitent
# fomentez fomentez
# tourneroit tournerions
# ieusne ieusne
# deffiera deffiera
# veiglerois veiglerois
# penseront penseront
# iettons iettons
# lyoys lyoys
# gasté gasté
# approuvenderoys approuvenderoys
# desherigions desherityons
# presupposa presupposa
# chocquois chocquois
# monstrois monstrions
# cerchois cerchois
# impugnoys impugnoys
# desroboit desroboit
# avancha avancha
# accepaste acceptasse
# marchoys marchoys
# racointeroyt racointeroyt
# declairera declairera
# delaceryons delaceryons
# demoureroys demoureroys
# atournez atournez
# doubtasmes doubtasmes
# avalitoys avallassions
# en courouchast en courouchant
# estonnons estonnons
# rouilleront rouilleront
# tombois tombois
# advisoys advisons
# alongeons alongeons
# cessons cessons
# rincerois rincerois
# resverez resverez
# tumberoys tumberois
# navrerois navrerois
# parlons parlons
# fouller fouller
# goustant goustant
# transgloutissoys transgloutissoys
# descouragea descourageas
# esparpilleront esparpilleront
# descouchieryons descouchieryons
# esquachoyent esquachoyent
# empiegeyons empiegyez
# deschargeras deschargeras
# particiyera participeryons
# empruntast empruntast
# escorches escorches
# regorgeassions regorgeassions
# embausmons embausmons
# acceptas acceptas
# inquiete inquiete
# regardassent regardastes
# alosois alosois
# moderasse moderasse
# recorderoys recorderoys
# chantez chantez
# alongera alongeront
# couches couches
# luitte luitte
# nombrez nombrez
# ronfleroyent ronfleroyent
# deifieroyt deifieroyt
# iouasses iouasses
# bayseroys bayseroys
# salueroyt salueroyt
# frape frape
# houeroit houeroit
# eslever eslever
# nouer nouer
# deschevauchasmes deschevauchasmes
# enconvenence enconvenences
# esmerveillassions esmerveillassent
# despossesasses despossessasmes
# manouvrois manouvrois
# depeschoit depeschoit
# aterminyons aterminoys
# estranglent estranglent
# travailleroys travailleroys
# protestasses protestasses
# scellois scellois
# soulaigera soulaigera
# separoient separoient
# tremblassions tremblassions
# goustasmes goustasmes
# arrivassent arrivastes
# gaignasse gaignasse
# esguare esguare
# habitastoys habitast
# rengiez rengiez
# touchassions touchassions
# quita quita
# accusons accusons
# deifierons deifierons
# estires estires
# pisserions pisserions
# adaptez adaptez
# esguarant esguarant
# gaberoit gaberoit
# en prapenassentas en preparant
# tombé tombé
# emblant emblant
# raenchonnez raenchonnez
# rappelloyent rappelloyent
# esparpilles esparpilles
# provocquerai provocquerai
# desheritterons desheriteront
# accordast accordoyt
# revencherai revencherai
# desploieroit desploieroit
# esternuerez esternuerez
# desborderoient desborderoient
# esplucheront esplucheront
# laidengerez laidengerez
# honnoureroys honnoureroys
# hebergierions hebergierions
# praesiderai praesideriez
# empruntez empruntez
# esvanteroit esvanteroit
# executes executes
# respirez respirez
# couchastes couchastes
# atemptez atemptez
# desyreriez desyrerions
# veigleras veigleras
# quitast quitast
# divineroys divineroys
# herrieroit herrieroient
# appellez appellez
# confesser confesser
# rotte rotte
# plie plie
# coustast coustant
# tiré tiré
# contrepoisoys contrepoisoys
# interpretoys interpretoys
# entredisserois vous entredesirassiez
# soubhaittasse soubhaittasse
# vous entrederonnyez vous entrehurtez
# esgratignerant esgratigneront
# netprouenteront entredonneryons
# desregloyent desregloyent
# abhorroyt abhorroyt
# contribue contribue
# tournassoys tournoyasse
# besoigna besoigna
# acoustreroit acoustreroit
# acoustreryez acoustreryez
# contregardant contregardant
# alongeis alongiez
# soumectroient soumectroient
# penetter penetrez
# alimentez alimente
# gelloyt gelloyt
# raporteroient raporteroient
# derva derva
# regorgeons regorgeons
# danceaste dançastes
# luitteront luitteront
# navrasent navrerai
# dampnent dampnent
# acquite acquite
# frapent frapent
# houe houe
# cryeras cryeras
# huez huez
# desprisonnoys desprisonnoys
# contrepoise contrepoise
# accompaignes accompaignes
# importunas importunas
# empruntois empruntois
# recuperasses recuperassiez
# denunchieras denunchieras
# recuperasmes recuperasmes
# destachasse destachasse
# renommions renommions
# souspirastes souspirastes
# cointoiassions cointoiassions
# desplaces desplaces
# leichyez leichyez
# regorgeray regorgeray
# mulctois mulctois
# possesseroit possesseroit
# tranchez tranchez
# assistez assistez
# tabusmeriez tabusteryez
# essayassiez essayassiez
# desnouas desnouera
# traittent traittent
# escarteriez escarteriez
# finoyent finoyent
# essayeroyt essayeroit
# coucherois coucherois
# guident guident
# erigeons erigeons
# rottent rottent
# iolyerai iolyeras
# laisser laisser
# courrouche courrouche
# detranchasses detranchasses
# presupposassions presupposassions
# particiaster participerai
# desadvouast desadvouast
# escorchois escorchois
# infourmast infourmast
# cherchois cherchois
# eschevey eschevyez
# deifiyez deifiyez
# estoufferoyt estoufferoyt
# moustrastes moustrastes
# querelerai querelerai
# demande demande
# escuyassent escumassiez
# touchassions touchast
# resignes resignes
# iolyoys iolyoys
# assiegeriez assiegeriez
# reigle reigle
# riffleryez riffleryez
# tempreroyt tempreroyt
# tyroit tyroit
# soucyez soucyez
# bayserois bayserois
# aorne aorne
# ronflons ronflons
# cachent cachent
# ralieryons ralieryons
# houasmes houasmes
# cessez cessez
# pechez pechez
# eschauffois eschauffois
# subiuguois subiuguois
# representes representes
# estincelleroys estincelleroys
# esperonnas esperonnas
# hebergeitera hebergierent
# escouillerois escouillerois
# escapperent escapperent
# bobelinez bobeline
# accepapt accepta
# croniquiez croniquiez
# trousserai trousserai
# offença offença
# ganglois ganglois
# achevoyt achevoyt
# possesse possesse
# separiez separiez
# soingnez soingnez
# menasse menasse
# enclineroys enclineroys
# reserveriez reserveriez
# impugnez impugnes
# escumast escumast
# humilieroys humilieryons
# operoient operoient
# trempe trempe
# soucyeroit soucyeroit
# chargera chargera
# fleschisse fleschis
# appuions appuions
# hachez hachez
# disnas disné
# desadvouions desadvouions
# endommaigez endommaigez
# escielleray escielleray
# resistoyt resistoyt
# explorions explorions
# presentast presentast
# bancqueteront bancqueteront
# espoventerez espoventerez
# advançois advançois
# prospereroys prospereroys
# fomentas fomentas
# esguiserai esguiserai
# tournoye tournoye
# desploies desploies
# evaporerent evaporerent
# seiournes seiournes
# tempra tempra
# protegera protegera
# accusa accusa
# desarmez desarmez
# atemptera atemptera
# enterreryez enterreryez
# menasseroient menasseroient
# pacquasse pacquasse
# aracheroient aracheroient
# pillast pillast
# adviseroit adviseroit
# poisons poisons
# cryent cryent
# pryeryons pryeryons
# leschant leschant
# tirons tirons
# desprisonnastes desprisonnastes
# recommandoyt recommandoyt
# enseignyez enseignyez
# esperonnyez esperonnyez
# croniquioys croniquioys
# rasslyes r'asseura
# remercyons remercyoys
# accordoys accordoys
# assiez assiegeoys
# rebarbois rebarbois
# desadvouerions desadvouerions
# merveillerons merveillerons
# estrangleroit estrangleroit
# empiegentyons empiegeoyent
# humilia humilia
# estachasses estachasses
# oultrage oultrage
# souspireroient souspireroient
# laidengerons laidengerons
# atempterent atempterent
# prospereront prospereront
# advança advança
# marchyez marchyez
# estimerent estimerent
# heurteray heurteray
# blessent blessent
# pensassions pensassions
# abiurerez abiurerez
# aloseroient aloseroient
# finez finez
# souppre soupper
# invitué invité
# houssepilloient houssepilloient
# courourrontas courrouçoyent
# contribuoient contribuoient
# particiast participassions
# transportes transportes
# rappellerez rappellerent
# courrouceras courrouceras
# denunchierons denunchient
# subiectassions subiectassions
# recullois recullois
# remonstre remonstre
# proclamez proclama
# ymaginions ymaginions
# retournasse retournasse
# racomptast racomptast
# desplaisoit desploiassiez
# embausmerois embausmerois
# escouille escouille
# moderois moderois
# esprouveras esprouveras
# delivras delivras
# baysoit baysoit
# enhorterions enhorterions
# advancer advances
# regorges regorges
# penetter penetrez
# escryons escryons
# appuierez appuierez
# seellera seellera
# robbent robbent
# haittastes haittant
# en reverant en reverant
# enconvenençoient enconvenençoient
# esmerveille esmerveille
# contrepoisez contrepoisez
# transgloutiroit transgloutiroyt
# condescendrenyez condescendreient
# desmettois desmettois
# possessois possessois
# gouvernasmes gouvernasmes
# seiournasses seiournasses
# empruntassiez empruntassiez
# racompteray racompteray
# emerges emergyez
# picquois picquois
# nettoyasses nettoyassent
# tournoyez tournoyez
# seelloit seelloit
# prosperez prosperez
# chantassent chantassent
# resignent resignent
# ordonneroyent ordonneroyent
# essilois essilions
# frapyons frapyons
# empira empira
# estacheryons estacheryons
# resveray resvasmes
# muçoit muçoit
# brusle brusle
# resumerions resumerions
# guarderois guarderois
# moderons moderons
# iettasses iettasses
# ieunez ieunez
# communicquyons communicquyons
# estouffions estouffions
# estourdissoyent estourdissoyent
# espargnoyt espargnoyt
# praesentons praesentons
# celebroyt celebroyt
# destable destable
# particié participe
# retourneroys retourneroys
# regarderoys regarderoys
# traitte traitte
# eschappez eschappez
# marcha marcha
# esguisez esguisez
# expuysons expuysons
# evaproentas evaporera
# negotieroys negotieroys
# esmayassiez esmayassiez
# impugneroyent impugneroyent
# estonnons estonnons
# serainerons serainent
# escarte escarte
# vollassions vollassions
# esleverois esleverions
# guida guida
# touchez touchez
# guerpisiez guerpissent
# marieroient marieroient
# opererois opererois
# lyerions lyerai
# tire tire
# pensé pensé
# adioustoit adioustoient
# empeschois empeschois
# blasphemez blasphemez
# desgorgerai desgorgerai
# retournastes retournastes
# cerchyez cerchyez
# pourforceront pourforceront
# estudioyent estudioyent
# desountiez desnouoit
# prospera prospera
# escorcha escorcha
# persuadasse persuadasse
# invitoient invitoient
# arrengeasse arrengiera
# monstrastes monstrastes
# veigloys veigloys
# surnommeroit surnommeroit
# desrisieroyent desrisieroyent
# cerchoit cerchoit
# nettoyasmes nettoyas
# enconcheriez enconcheriez
# assiez assiegeons
# estudierois estudierois
# estiquiez estiquiez
# couchesse couches
# reiettons reiettons
# urines urines
# robbera robbera
# emblerons emblerons
# abosché abosché
# gaigné gaigné
# en ostant en ostant
# courrouchiez courrouchiez
# representerons representerons
# desprisonnez desprisonnez
# empruntoys empruntoyt
# destabloys destabloys
# esbauchastes esbauchastes
# esternuasses esternuasses
# deschargerois deschargerois
# recuperasses recuperasses
# atournois atournois
# besoignerez besoignerez
# gaspilleras gaspilleras
# seiournera seiournera
# desgorgeons desgorgez
# empruntez empruntez
# leichassions leichassions
# mariois mariois
# abhorre abhorre
# impugneroit impugneroit
# ottroyera ottroyera
# obligeastes obligeastes
# resvoyent resvoyent
# amadouez amadouez
# picquere picqueryez
# esguise esguise
# esgalerois esgalerois
# estois estoit
# cryeray cryeray
# pretera pretera
# louez louez
# prions prions
# lye lye
# couchoys couchois
# desplacez desplacez
# assiegnere assiegerent
# picquieront picquieront
# rouillerons rouillerons
# iolyassiez iolyasse
# confesmas confessant
# foullassons foullant

# %% [markdown]
# ## 3.4 Experiment 2

# %% [markdown]
# ### Simple Attention over characters and tags

# %%
# %matplotlib inline

from itertools import zip_longest
import os
import pickle
import time

import Levenshtein
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
def load_data(file_name):
    """Loads data.

    Args:
        file_name: path to file containing the data

    Returns:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form
    """

    with open(file_name, 'r', encoding='utf') as file:
        text = file.read()

    lemmas = []
    tags = []
    inflected_forms = []

    for line in text.split('\n')[:-1]:
        lemma, inflected_form, tag = line.split('\t')
        lemmas.append(lemma)
        inflected_forms.append(inflected_form)
        tags.append(tag) 

    return lemmas, tags, inflected_forms

def get_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char, tag2index

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps character to index
        index2char: a dictionary which maps index to character
        tag2index: a ditionary which maps morphological tag to index 
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR) # special start and end symbols
    unique_chars.update(UNKNOWN_CHAR) # special charcter for unknown word
    char2index = {}
    index2char = {}

    char2index[PAD_CHAR] = 0
    index2char[0] = PAD_CHAR
    
    for index, char in enumerate(unique_chars):
        char2index[char] = index + 1
        index2char[index + 1] = char

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.update(UNKNOWN_TAG)
    tag2index = {tag:index+1 for index, tag in enumerate(unique_tags)}
    tag2index[PAD_TAG] = 0

    return char2index, index2char, tag2index

def get_combined_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps inputs and  to index
        index2char: a dictionary which maps index to inputs
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR, UNKNOWN_CHAR) # special start and end symbols  
    
    input2index = {}
    index2input = {}
    
    input2index[PAD_CHAR] = 0
    index2input[0] = PAD_CHAR
        
    for index, char in enumerate(unique_chars, start=1):
        input2index[char] = index
        index2input[index] = char
        
    char_vocab_length = len(input2index.keys())

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.add(UNKNOWN_TAG) # special character for unknown tags
    
    for index, char in enumerate(unique_tags, start=char_vocab_length):
        input2index[char] = index
        index2input[index] = char

    return input2index, index2input, char_vocab_length

def words_to_indices(words, char2index, tensor=False, start_char=False, stop_char=False):
    """Converts list of words to a list with list containing indices

    Args:
        words: list of words
        char2index: dictionary which maps character to index
        tensor: if to return a list of tensor  

    Returns:
        tensor: list of list/tensor containing indices for a sequence of characters
    """

    list_indices = []
    for word in words:
        word_indices = []
        if start_char:
            word_indices.append(char2index[START_CHAR])
        for char in word:
            if char in char2index.keys():
                word_indices.append(char2index[char])
            else:
                word_indices.append(char2index[UNKNOWN_CHAR])
        if stop_char:
            word_indices.append(char2index[STOP_CHAR])
        if tensor:
            word_indices = torch.Tensor(word_indices)
        list_indices.append(word_indices)

    return list_indices

def tag_to_vector(tags, tag2index):
    """Returns one hot representation of tags given a tag.

    Args:
        tags: list of string representation of tag (eg, V;IND;PRS;2;PL)

    Returns:
        tag_vectors: list of 1D tensors with one hot representation of tags 
    """

    tag_vectors = []
    for tag in tags:
        tag_vector = torch.zeros(len(tag2index))
        for tag_feature in tag.split(';'):
            if tag_feature in tag2index:
                tag_vector[tag2index[tag_feature]] = 1
            else:
                tag_vector[tag2index[UNKNOWN_TAG]] = 1
        tag_vectors.append(tag_vector)
    return tag_vectors

def tag_to_indices(tags, tag2index):
    """Converts list of tags to a list of lists containing indices

    Args:
        words: list of tags

    Returns:
        tensor: list of list containing indices of sub_tags
    """
    
    list_indices = []
    for tag in tags:
        tag_indices = []
        for sub_tag in tag.split(';'):
            if sub_tag in tag2index.keys():
                tag_indices.append(tag2index[sub_tag])
            else:
                tag_indices.append(tag2index[UNKNOWN_TAG])
        list_indices.append(tag_indices)

    return list_indices
    

def indices_to_word(indices, index2char):
    """Returns a word given list contaning indices of words

    Args:
        indices: list containing indices

    Returns:
        word: a string
    """

    return ''.join([index2char[index] for index in indices])[:-1]

def pad_lists(lists, pad_int, pad_len=None):
    """Pads lists in a list to make them of equal size"""
    
    if pad_len is None:
        pad_len = max([len(lst) for lst in lists])
    new_list = []
    for lst in lists:
        if len(lst) < pad_len:
            new_list.append(torch.tensor(lst + [pad_int] * (pad_len-len(lst))))
        else:
            new_list.append(torch.tensor(lst[:pad_len]))
    return torch.stack(new_list)

def merge_lists(lists1, lists2):
    """Add two list of lists."""
    
    merged_lists = []
    for list1, list2 in zip(lists1, lists2):
        merged_lists.append(list1 + list2)
    return merged_lists

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def accuracy(predictions, targets):
    correct_count = 0
    for prediction, target in zip(predictions, targets):
        if prediction == target:
            correct_count += 1
    return correct_count / len(predictions)

def average_distance(predictions, targets):
    total_distance = 0
    for prediction, target in zip(predictions, targets):
        total_distance += Levenshtein.distance(prediction, target)
    return total_distance / len(predictions)

def evaluate(predictions, targets):
    return accuracy(predictions, targets), average_distance(predictions, targets)

# %%
language = 'middle-french'
dataset = 'high'

# %%
lemmas, tags, inflected_forms = load_data('./conll2018/task1/all/{}-train-{}'.format(language, dataset))

# %%
lemmas_train, lemmas_val, tags_train, tags_val, inflected_forms_train, inflected_forms_val = train_test_split(lemmas, tags, inflected_forms, test_size=0.2, random_state=42)

# %%
input2index, index2input, char_vocab_size = get_combined_index_dictionaries(lemmas_train, tags_train, inflected_forms_train)

# %% [markdown]
# ### Train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32
embedding_size = 300
hidden_size = 100
input_vocab_size = len(index2input.keys())

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size, p=0.3):

        super(Attention, self).__init__()
        self.W_a = nn.Linear(2*hidden_size, hidden_size, bias=False)

    def forward(self, encoded_input, hidden_state, input_mask):
        src_len = encoded_input.shape[1]
        attn_weights = torch.bmm(self.W_a(encoded_input), hidden_state.transpose(0, 1).transpose(1, 2)).squeeze()
        attn_weights.data.masked_fill_(input_mask, float('-inf'))
  
        attn_weights = F.softmax(attn_weights, dim=1)
        return attn_weights

# %%
Embedder = nn.Embedding(input_vocab_size, embedding_size, padding_idx=input2index[PAD_CHAR]).to(device)
Encoder = nn.LSTM(embedding_size, hidden_size, batch_first=True, bidirectional=True).to(device)
attention = Attention(hidden_size).to(device)
Decoder = nn.LSTM(embedding_size + 2 * hidden_size, hidden_size, batch_first=True).to(device)
linear1 = nn.Linear(3 * hidden_size, char_vocab_size - 1, ).to(device) # remove pad character option
dropout1 = torch.nn.Dropout(p=0)
log_softmax = nn.LogSoftmax(dim=2).to(device)
criterion = nn.NLLLoss(ignore_index=-1)
params = list(Embedder.parameters()) + list(Encoder.parameters()) + list(Decoder.parameters()) + list(linear1.parameters())+ list(attention.parameters())

# %%
def test(lemmas_val, tags_val, inflected_forms_val, batch_size=32, attn_debug=False, max_pred_len=25):

    inflected_predicted = []
    inflected_forms_true = []
    if attn_debug:
        input_seq = []
        attn_weights_all = []
    output_indices = []

    for batch in grouper(zip(lemmas_val, tags_val, inflected_forms_val), batch_size):
        batch = list(filter(lambda x: x is not None, batch))
        lemmas, tags, inflected_forms = zip(*batch)

        lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
        tags_indices = tag_to_indices(tags, input2index)    
        input_indices = merge_lists(lemmas_indices, tags_indices)

        # Sort by length of input sequence
        input_indices, inflected_forms = zip(*sorted(zip(input_indices, inflected_forms), key=lambda x: len(x[0]), reverse=True))        
        if attn_debug:
            input_seq += [[index2input[index] for index in input_indices1] for input_indices1 in input_indices]
        input_indices = [torch.tensor(lst) for lst in input_indices]

        input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
        embedding = Embedder(input_tensor)
        lengths = [Tensor.shape[0] for Tensor in input_indices]
        packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
        encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
        encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]
        
        input_mask = input_tensor == 0
        # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 


        # Decode
        hidden_state = hidden[0,:,:] + hidden[1,:,:]
        hidden_state = hidden_state.unsqueeze(0)
        cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

        decoder_input = torch.tensor([input2index[START_CHAR]] * len(lengths)).to(device)
        decoder_input = Embedder(decoder_input).unsqueeze(1)


        outputs = []
        attn_weights_sequence = []
        for seq in range(0, max_pred_len):
            attn_weights = attention(encoded_input, hidden_state, input_mask)
            if attn_debug:
                attn_weights_sequence.append(attn_weights)
            context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

            decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input], dim=2)

            output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
            output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))            
            decoder_input = Embedder(output.argmax(dim=2) + 1).transpose(0, 1)
            outputs.append(output.squeeze())

        if attn_debug:
            attn_weights_sequence = torch.stack(attn_weights_sequence, dim=1)
            attn_weights_all.append(attn_weights_sequence)
        output_indices.append(torch.stack(outputs).argmax(dim=2))
        inflected_forms_true += inflected_forms

    output_indices = torch.cat(output_indices, dim=1).transpose(0, 1).cpu().numpy()
    for indices in output_indices:
        inflected_predicted.append(''.join([index2input[index + 1] for index in indices]).split(STOP_CHAR)[0])
            
    if attn_debug:
        max_src_len = max([x.shape[2] for x in attn_weights_all])
        for i in range(len(attn_weights_all)):
            attn_weights = attn_weights_all[i]
            batch_size = attn_weights.shape[0]
            src_len = attn_weights.shape[2]
            attn_weights_all[i] = torch.zeros(batch_size, max_pred_len, max_src_len)
            attn_weights_all[i][:,:,:src_len] = attn_weights
        attn_weights_all = torch.cat(attn_weights_all, dim=0)
        return inflected_predicted, input_seq, attn_weights_all
    else:
        return inflected_predicted, inflected_forms_true

# %%
optimiser = optim.Adagrad(params, lr=0.1)

# %%
def train(lemmas_train, tags_train, inflected_forms_train, epochs=1):
    start_time = time.time()

    for epoch in range(epochs):

        epoch_loss = 0

        for batch in grouper(zip(lemmas_train, tags_train, inflected_forms_train), batch_size):
            batch = list(filter(lambda x: x is not None, batch))
            lemmas, tags, inflected_forms = zip(*batch)


            lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
            tags_indices = tag_to_indices(tags, input2index)    
            inflected_forms_indices = words_to_indices(inflected_forms, input2index)
            input_indices = merge_lists(lemmas_indices, tags_indices)

            # Sort by length of input sequence
            input_indices, inflected_forms_indices = zip(*sorted(zip(input_indices, inflected_forms_indices), key=lambda x: len(x[0]), reverse=True))
            input_indices = [torch.tensor(lst) for lst in input_indices]

            optimiser.zero_grad()

            input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
            embedding = Embedder(input_tensor)
            lengths = [Tensor.shape[0] for Tensor in input_indices]
            packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
            encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
            encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]
            
            input_mask = input_tensor == 0
            # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 

            # Decode
            hidden_state = hidden[0,:,:] + hidden[1,:,:]
            hidden_state = hidden_state.unsqueeze(0)
            cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

            target = pad_lists([lst + [input2index[STOP_CHAR]] for lst in inflected_forms_indices], input2index[PAD_CHAR]).to(device)    
            target = target - 1

            decoder_input = pad_lists(inflected_forms_indices, input2index[PAD_CHAR]).to(device)
            decoder_input = torch.cat([torch.tensor([input2index[START_CHAR]] * len(lengths)).unsqueeze(1).to(device), decoder_input], dim=1)
            decoder_input = Embedder(decoder_input)

            loss = 0

            max_length = target.shape[1]
            for seq in range(0, max_length):
                attn_weights = attention(encoded_input, hidden_state, input_mask)
                context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()
                
                decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input[:,seq,:].unsqueeze(1)], dim=2)
                
                output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
                output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))
                output = dropout1(output)
                output = log_softmax(output).squeeze()
                loss += criterion(output, target[:,seq])

            epoch_loss += loss.item()
            loss.backward()
            optimiser.step()

        print("Epoch: {}/{}\tTime: {:.2f}s\tLoss: {:.4f}\tAccuracy: {:.4f}\tDistance: {:.4f} ".format(epoch+1, epochs, time.time() - start_time, epoch_loss / len(lemmas_train), *evaluate(*test(lemmas_val, tags_val, inflected_forms_val))))

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=70)
# Out:
# Epoch: 1/70	Time: 11.73s	Loss: 1.6367	Accuracy: 0.0000	Distance: 16.6345
# Epoch: 2/70	Time: 25.15s	Loss: 1.4519	Accuracy: 0.0000	Distance: 19.5775
# Epoch: 3/70	Time: 38.63s	Loss: 1.3849	Accuracy: 0.0000	Distance: 16.6520
# Epoch: 4/70	Time: 52.03s	Loss: 1.3729	Accuracy: 0.0000	Distance: 16.1330
# Epoch: 5/70	Time: 65.65s	Loss: 1.3632	Accuracy: 0.0000	Distance: 14.3960
# Epoch: 6/70	Time: 79.01s	Loss: 1.3580	Accuracy: 0.0000	Distance: 14.6755
# Epoch: 7/70	Time: 92.29s	Loss: 1.3412	Accuracy: 0.0000	Distance: 15.3875
# Epoch: 8/70	Time: 105.72s	Loss: 1.3313	Accuracy: 0.0000	Distance: 15.1705
# Epoch: 9/70	Time: 119.14s	Loss: 1.3258	Accuracy: 0.0000	Distance: 14.9580
# Epoch: 10/70	Time: 132.53s	Loss: 1.3227	Accuracy: 0.0000	Distance: 14.6830
# Epoch: 11/70	Time: 145.83s	Loss: 1.3143	Accuracy: 0.0000	Distance: 14.7305
# Epoch: 12/70	Time: 159.10s	Loss: 1.3147	Accuracy: 0.0000	Distance: 13.5515
# Epoch: 13/70	Time: 172.54s	Loss: 1.3143	Accuracy: 0.0000	Distance: 14.5335
# Epoch: 14/70	Time: 186.05s	Loss: 1.3134	Accuracy: 0.0000	Distance: 14.4085
# Epoch: 15/70	Time: 199.60s	Loss: 1.3112	Accuracy: 0.0000	Distance: 15.1305
# Epoch: 16/70	Time: 213.10s	Loss: 1.3231	Accuracy: 0.0000	Distance: 12.4880
# Epoch: 17/70	Time: 226.54s	Loss: 1.3203	Accuracy: 0.0000	Distance: 12.8185
# Epoch: 18/70	Time: 240.06s	Loss: 1.3166	Accuracy: 0.0000	Distance: 13.7930
# Epoch: 19/70	Time: 253.48s	Loss: 1.3151	Accuracy: 0.0000	Distance: 13.9685
# Epoch: 20/70	Time: 267.12s	Loss: 1.3117	Accuracy: 0.0000	Distance: 12.6685
# Epoch: 21/70	Time: 280.61s	Loss: 1.3094	Accuracy: 0.0000	Distance: 12.2045
# Epoch: 22/70	Time: 294.17s	Loss: 1.3117	Accuracy: 0.0000	Distance: 11.8990
# Epoch: 23/70	Time: 307.70s	Loss: 1.3079	Accuracy: 0.0000	Distance: 12.4375
# Epoch: 24/70	Time: 321.26s	Loss: 1.3053	Accuracy: 0.0000	Distance: 13.3545
# Epoch: 25/70	Time: 334.73s	Loss: 1.3030	Accuracy: 0.0000	Distance: 12.4605
# Epoch: 26/70	Time: 348.17s	Loss: 1.3032	Accuracy: 0.0000	Distance: 13.9795
# Epoch: 27/70	Time: 361.80s	Loss: 1.3016	Accuracy: 0.0000	Distance: 12.4550
# Epoch: 28/70	Time: 375.35s	Loss: 1.3015	Accuracy: 0.0000	Distance: 11.8525
# Epoch: 29/70	Time: 388.97s	Loss: 1.3078	Accuracy: 0.0000	Distance: 9.3750
# Epoch: 30/70	Time: 402.53s	Loss: 1.3098	Accuracy: 0.0000	Distance: 8.6080
# Epoch: 31/70	Time: 416.03s	Loss: 1.3082	Accuracy: 0.0000	Distance: 10.7515
# Epoch: 32/70	Time: 429.69s	Loss: 1.3076	Accuracy: 0.0000	Distance: 10.9210
# Epoch: 33/70	Time: 443.32s	Loss: 1.3095	Accuracy: 0.0000	Distance: 11.0375
# Epoch: 34/70	Time: 456.79s	Loss: 1.3104	Accuracy: 0.0000	Distance: 10.4705
# Epoch: 35/70	Time: 470.20s	Loss: 1.3048	Accuracy: 0.0000	Distance: 9.1015
# Epoch: 36/70	Time: 483.72s	Loss: 1.3086	Accuracy: 0.0000	Distance: 9.9735
# Epoch: 37/70	Time: 497.38s	Loss: 1.3058	Accuracy: 0.0000	Distance: 9.6250
# Epoch: 38/70	Time: 510.98s	Loss: 1.3086	Accuracy: 0.0000	Distance: 9.6635
# Epoch: 39/70	Time: 524.52s	Loss: 1.3152	Accuracy: 0.0000	Distance: 11.4935
# Epoch: 40/70	Time: 538.20s	Loss: 1.3148	Accuracy: 0.0000	Distance: 10.1650
# Epoch: 41/70	Time: 551.81s	Loss: 1.3176	Accuracy: 0.0000	Distance: 10.3055
# Epoch: 42/70	Time: 565.29s	Loss: 1.3180	Accuracy: 0.0000	Distance: 10.1505
# Epoch: 43/70	Time: 578.90s	Loss: 1.3138	Accuracy: 0.0000	Distance: 10.5975
# Epoch: 44/70	Time: 592.39s	Loss: 1.3183	Accuracy: 0.0000	Distance: 9.8920
# Epoch: 45/70	Time: 605.90s	Loss: 1.3224	Accuracy: 0.0000	Distance: 10.3675
# Epoch: 46/70	Time: 619.41s	Loss: 1.3216	Accuracy: 0.0000	Distance: 10.8075
# Epoch: 47/70	Time: 632.78s	Loss: 1.3233	Accuracy: 0.0000	Distance: 19.5315
# Epoch: 48/70	Time: 646.23s	Loss: 1.3219	Accuracy: 0.0000	Distance: 16.6615
# Epoch: 49/70	Time: 659.72s	Loss: 1.3227	Accuracy: 0.0000	Distance: 17.2170
# Epoch: 50/70	Time: 673.23s	Loss: 1.3224	Accuracy: 0.0000	Distance: 16.5305
# Epoch: 51/70	Time: 686.73s	Loss: 1.3208	Accuracy: 0.0000	Distance: 15.9995
# Epoch: 52/70	Time: 700.35s	Loss: 1.3180	Accuracy: 0.0000	Distance: 15.2360
# Epoch: 53/70	Time: 713.91s	Loss: 1.3182	Accuracy: 0.0000	Distance: 15.6930
# Epoch: 54/70	Time: 727.57s	Loss: 1.3181	Accuracy: 0.0000	Distance: 16.0520
# Epoch: 55/70	Time: 741.17s	Loss: 1.3170	Accuracy: 0.0000	Distance: 14.3400
# Epoch: 56/70	Time: 754.75s	Loss: 1.3155	Accuracy: 0.0000	Distance: 14.6990
# Epoch: 57/70	Time: 768.33s	Loss: 1.3137	Accuracy: 0.0000	Distance: 15.8055
# Epoch: 58/70	Time: 781.79s	Loss: 1.3144	Accuracy: 0.0000	Distance: 14.5865
# Epoch: 59/70	Time: 795.38s	Loss: 1.3131	Accuracy: 0.0000	Distance: 14.7225
# Epoch: 60/70	Time: 809.02s	Loss: 1.3149	Accuracy: 0.0000	Distance: 14.5385
# Epoch: 61/70	Time: 822.59s	Loss: 1.3141	Accuracy: 0.0000	Distance: 12.8345
# Epoch: 62/70	Time: 836.08s	Loss: 1.3185	Accuracy: 0.0000	Distance: 13.5520
# Epoch: 63/70	Time: 849.79s	Loss: 1.3170	Accuracy: 0.0000	Distance: 13.7195
# Epoch: 64/70	Time: 863.38s	Loss: 1.3154	Accuracy: 0.0000	Distance: 14.2365
# Epoch: 65/70	Time: 876.81s	Loss: 1.3176	Accuracy: 0.0000	Distance: 12.4430
# Epoch: 66/70	Time: 890.35s	Loss: 1.3176	Accuracy: 0.0000	Distance: 11.2460
# Epoch: 67/70	Time: 903.56s	Loss: 1.3147	Accuracy: 0.0000	Distance: 14.0140
# Epoch: 68/70	Time: 916.85s	Loss: 1.3138	Accuracy: 0.0000	Distance: 13.9605
# Epoch: 69/70	Time: 930.04s	Loss: 1.3145	Accuracy: 0.0000	Distance: 13.4025
# Epoch: 70/70	Time: 943.36s	Loss: 1.3144	Accuracy: 0.0000	Distance: 12.9500

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# Train accuracy: (0.0, 12.706375) Validation accuracy:  (0.0, 12.95)

# %%
optimiser = optim.Adagrad(params, lr=0.01)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=30)
# Out:
# Epoch: 1/30	Time: 11.60s	Loss: 1.3157	Accuracy: 0.0000	Distance: 12.3610
# Epoch: 2/30	Time: 24.88s	Loss: 1.3131	Accuracy: 0.0000	Distance: 12.0975
# Epoch: 3/30	Time: 38.17s	Loss: 1.3130	Accuracy: 0.0000	Distance: 11.9540
# Epoch: 4/30	Time: 51.38s	Loss: 1.3123	Accuracy: 0.0000	Distance: 11.8285
# Epoch: 5/30	Time: 64.61s	Loss: 1.3122	Accuracy: 0.0000	Distance: 11.4050
# Epoch: 6/30	Time: 77.90s	Loss: 1.3119	Accuracy: 0.0000	Distance: 12.0620
# Epoch: 7/30	Time: 91.13s	Loss: 1.3119	Accuracy: 0.0000	Distance: 11.9110
# Epoch: 8/30	Time: 104.33s	Loss: 1.3116	Accuracy: 0.0000	Distance: 11.8495
# Epoch: 9/30	Time: 117.57s	Loss: 1.3112	Accuracy: 0.0000	Distance: 11.7805
# Epoch: 10/30	Time: 130.95s	Loss: 1.3110	Accuracy: 0.0000	Distance: 12.1065
# Epoch: 11/30	Time: 144.29s	Loss: 1.3103	Accuracy: 0.0000	Distance: 12.0985
# Epoch: 12/30	Time: 157.57s	Loss: 1.3100	Accuracy: 0.0000	Distance: 12.1470
# Epoch: 13/30	Time: 170.83s	Loss: 1.3097	Accuracy: 0.0000	Distance: 12.1355
# Epoch: 14/30	Time: 184.04s	Loss: 1.3096	Accuracy: 0.0000	Distance: 12.0910
# Epoch: 15/30	Time: 197.30s	Loss: 1.3097	Accuracy: 0.0000	Distance: 12.0520
# Epoch: 16/30	Time: 210.49s	Loss: 1.3094	Accuracy: 0.0000	Distance: 12.0620
# Epoch: 17/30	Time: 223.78s	Loss: 1.3094	Accuracy: 0.0000	Distance: 12.0325
# Epoch: 18/30	Time: 236.97s	Loss: 1.3097	Accuracy: 0.0000	Distance: 12.0460
# Epoch: 19/30	Time: 250.18s	Loss: 1.3101	Accuracy: 0.0000	Distance: 11.9730
# Epoch: 20/30	Time: 263.28s	Loss: 1.3099	Accuracy: 0.0000	Distance: 12.0115
# Epoch: 21/30	Time: 276.43s	Loss: 1.3101	Accuracy: 0.0000	Distance: 11.8895
# Epoch: 22/30	Time: 289.53s	Loss: 1.3100	Accuracy: 0.0000	Distance: 11.9610
# Epoch: 23/30	Time: 302.65s	Loss: 1.3100	Accuracy: 0.0000	Distance: 11.8620
# Epoch: 24/30	Time: 315.82s	Loss: 1.3096	Accuracy: 0.0000	Distance: 11.8305
# Epoch: 25/30	Time: 328.91s	Loss: 1.3094	Accuracy: 0.0000	Distance: 11.8225
# Epoch: 26/30	Time: 342.01s	Loss: 1.3094	Accuracy: 0.0000	Distance: 11.8015
# Epoch: 27/30	Time: 355.17s	Loss: 1.3097	Accuracy: 0.0000	Distance: 11.8330
# Epoch: 28/30	Time: 368.25s	Loss: 1.3096	Accuracy: 0.0000	Distance: 11.7840
# Epoch: 29/30	Time: 381.38s	Loss: 1.3096	Accuracy: 0.0000	Distance: 11.8635
# Epoch: 30/30	Time: 394.46s	Loss: 1.3096	Accuracy: 0.0000	Distance: 11.9275

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# Train accuracy: (0.0, 11.718875) Validation accuracy:  (0.0, 11.9275)

# %% [markdown]
# ### Development Dataset

# %%
lemmas_dev, tags_dev, inflected_forms_dev = load_data('./middle-french-train-high')

# %%
evaluate(*test(lemmas_dev, tags_dev, inflected_forms_dev))
# Out:
# (0.0, 11.7606)

# %%
for prediction, truth in zip(*test(lemmas_dev, tags_dev, inflected_forms_dev)):
    print("Prediction: {}\tTruth: {}".format(prediction, truth))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction: ent	Truth: desrisastes
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: proffiterions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: estoffassiez
# Prediction: ent	Truth: surnommera
# Prediction: enseeses	Truth: subiecteront
# Prediction: en	Truth: impugneront
# Prediction: ent	Truth: branslerions
# Prediction: ent	Truth: deslyast
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pastureryez
# Prediction: ent	Truth: gaboient
# Prediction: eses	Truth: esleves
# Prediction: ent	Truth: enortes
# Prediction: es	Truth: guarde
# Prediction: ent	Truth: meslast
# Prediction: seses	Truth: flatterons
# Prediction: ent	Truth: destablant
# Prediction: ent	Truth: estourdir
# Prediction: eentrares	Truth: en esprouvant
# Prediction: eses	Truth: garde
# Prediction: ent	Truth: aymerent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: ayderont
# Prediction: ent	Truth: guide
# Prediction: ent	Truth: vont
# Prediction: en	Truth: eu
# Prediction: ent	Truth: entredemandoyent
# Prediction: ent	Truth: r'asseurions
# Prediction: ent	Truth: destourneray
# Prediction: ent	Truth: esloignasses
# Prediction: ense	Truth: estudiyez
# Prediction: ent	Truth: engendrast
# Prediction: enenenenenenenenenenenene	Truth: accordoys
# Prediction: ent	Truth: eslevois
# Prediction: ent	Truth: monstrassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desancreroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mortifiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: expellasmes
# Prediction: es	Truth: temprois
# Prediction: es	Truth: desroberois
# Prediction: enseseses	Truth: baptizerons
# Prediction: ent	Truth: ployoys
# Prediction: es	Truth: rouillez
# Prediction: ent	Truth: depesche
# Prediction: sent	Truth: grappa
# Prediction: eises	Truth: en approuchant
# Prediction: entrentrentrentrentrentre	Truth: dançoys
# Prediction: 	Truth: tourmentant
# Prediction: ent	Truth: aguyses
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: guardez
# Prediction: ent	Truth: operassions
# Prediction: ent	Truth: faucerions
# Prediction: eoooooooooooooooooooooooo	Truth: vollerois
# Prediction: ent	Truth: passe
# Prediction: ent	Truth: iolyent
# Prediction: ent	Truth: tyrassions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: iolyent
# Prediction: ent	Truth: oste
# Prediction: ent	Truth: r'asseuriez
# Prediction: eseeses	Truth: souspira
# Prediction: es	Truth: confessasses
# Prediction: ent	Truth: gaspilleray
# Prediction: sent	Truth: eschappa
# Prediction: ent	Truth: esguisions
# Prediction: ent	Truth: declairast
# Prediction: os	Truth: invadois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrouteroyt
# Prediction: enseseses	Truth: regretterons
# Prediction: entseneeneeneeneeneeneene	Truth: infourmons
# Prediction: eo	Truth: tournois
# Prediction: ent	Truth: escartent
# Prediction: ent	Truth: inviterai
# Prediction: ent	Truth: devoureryez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desnoueryez
# Prediction: ent	Truth: deffiassions
# Prediction: ensee	Truth: humilieroient
# Prediction: ent	Truth: urinois
# Prediction: ses	Truth: verifierois
# Prediction: entreeoent	Truth: toquoyt
# Prediction: ent	Truth: estimez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mocques
# Prediction: reeeseseseseseseseseseses	Truth: effreons
# Prediction: eoooooooooooooooooooooooo	Truth: armoierois
# Prediction: ent	Truth: pilla
# Prediction: seeeneeeneeeneeeneeeneeen	Truth: leschons
# Prediction: reeeseseseseseseseseseses	Truth: adaptons
# Prediction: ses	Truth: esbaucher
# Prediction: eoooooooooooooooooooooooo	Truth: ferois
# Prediction: ent	Truth: sois
# Prediction: ent	Truth: lurré
# Prediction: eseeeeeeeeeeeeeeeeeeeeeee	Truth: enpoisonneriez
# Prediction: enseesesesesesesesesesese	Truth: empoizonneryons
# Prediction: ent	Truth: espoventeray
# Prediction: enseent	Truth: accoustument
# Prediction: ent	Truth: cabassoyt
# Prediction: ent	Truth: recupererent
# Prediction: ent	Truth: esventoyent
# Prediction: eo	Truth: desployas
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: eschapperez
# Prediction: ent	Truth: protestez
# Prediction: ent	Truth: baptisa
# Prediction: ent	Truth: deschireriez
# Prediction: ent	Truth: enferrassent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: fromente
# Prediction: nsent	Truth: enconcherois
# Prediction: eient	Truth: ronflyez
# Prediction: ensesese	Truth: buchas
# Prediction: ent	Truth: empenseriez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: reiecte
# Prediction: ent	Truth: iettoyent
# Prediction: es	Truth: gardois
# Prediction: ent	Truth: meritast
# Prediction: ent	Truth: soingneroit
# Prediction: ent	Truth: guidoyent
# Prediction: es	Truth: cachassiez
# Prediction: ent	Truth: nommeray
# Prediction: ent	Truth: heurteryez
# Prediction: ent	Truth: faisoyent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gelleroys
# Prediction: reeeseseseseseseseseseses	Truth: cessons
# Prediction: ent	Truth: alassions
# Prediction: eses	Truth: trompant
# Prediction: ent	Truth: accoustumeray
# Prediction: ent	Truth: conseillassions
# Prediction: enseesesesesesesesesesese	Truth: courouchierez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: praesentez
# Prediction: ent	Truth: surnommassiez
# Prediction: ent	Truth: empensassent
# Prediction: ent	Truth: escoutasmes
# Prediction: eseeeeeeeeeeeeeeeeeeeeeee	Truth: soumecte
# Prediction: entseneeneeneeneeneeneene	Truth: espargnons
# Prediction: eses	Truth: remercye
# Prediction: ent	Truth: baptizerent
# Prediction: ent	Truth: cerchassions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: bobelinerons
# Prediction: ent	Truth: soumectons
# Prediction: ent	Truth: appellasmes
# Prediction: ent	Truth: heiloyent
# Prediction: essssssssssssssssssssssss	Truth: soubhaitté
# Prediction: ent	Truth: nombrassent
# Prediction: ent	Truth: delivre
# Prediction: ent	Truth: tournasses
# Prediction: ent	Truth: resides
# Prediction: ent	Truth: armoieriez
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: soupperiez
# Prediction: eseeeeeeeeeeeeeeeeeeeeeee	Truth: soucyez
# Prediction: ensonspnsenrsrrentrenentr	Truth: en tesmoignant
# Prediction: ent	Truth: luitteras
# Prediction: ent	Truth: nommasse
# Prediction: enseeneeneeneeneeneeneene	Truth: ieuneroyent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: toqueroys
# Prediction: ses	Truth: hacherons
# Prediction: ent	Truth: mortifié
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: aquitter
# Prediction: ent	Truth: contrepoisoit
# Prediction: en	Truth: enconvenence
# Prediction: eenees	Truth: traveilloys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: courouchassiez
# Prediction: ent	Truth: seiournoyt
# Prediction: ent	Truth: destournast
# Prediction: eeeentreerees	Truth: bancqueta
# Prediction: ent	Truth: courrouça
# Prediction: ent	Truth: pourpense
# Prediction: ent	Truth: contribueroys
# Prediction: ent	Truth: reiectassions
# Prediction: entrions	Truth: trouvoys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: destableroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: allaicteroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esprouveroys
# Prediction: ent	Truth: mercyerai
# Prediction: ent	Truth: arriverent
# Prediction: seses	Truth: arresterons
# Prediction: ent	Truth: deifias
# Prediction: eoent	Truth: volloyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: escumassent
# Prediction: nseeois	Truth: estachent
# Prediction: ent	Truth: arroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: arroieryez
# Prediction: ent	Truth: operast
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: retyreroys
# Prediction: ent	Truth: courrouçant
# Prediction: ent	Truth: mesla
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: opereroys
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: meslons
# Prediction: enions	Truth: declairé
# Prediction: enses	Truth: huasses
# Prediction: eseses	Truth: deshonnourasses
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esparpilloient
# Prediction: eseses	Truth: despucellasse
# Prediction: es	Truth: desbaratoys
# Prediction: ent	Truth: contregarderiez
# Prediction: es	Truth: fourageoys
# Prediction: ent	Truth: aboschions
# Prediction: ent	Truth: fourageassent
# Prediction: entrees	Truth: picquoys
# Prediction: ent	Truth: protestassent
# Prediction: ent	Truth: confesseras
# Prediction: ent	Truth: verifia
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: iniurieryons
# Prediction: ent	Truth: navroient
# Prediction: ent	Truth: invaderay
# Prediction: es	Truth: arresterois
# Prediction: ses	Truth: asseures
# Prediction: eneeoent	Truth: recorderont
# Prediction: eneeneeneeneeneeneeneenee	Truth: excusez
# Prediction: eent	Truth: pacques
# Prediction: ent	Truth: veigleroit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: affamez
# Prediction: ses	Truth: lascheras
# Prediction: entseocsseocsssseocsionse	Truth: en sollicitant
# Prediction: ensees	Truth: guerpissent
# Prediction: sent	Truth: maschons
# Prediction: ent	Truth: ieune
# Prediction: ent	Truth: fluismes
# Prediction: eent	Truth: pense
# Prediction: seeneeeneeeneeeneeeneeene	Truth: houons
# Prediction: entsnses	Truth: en supposant
# Prediction: ent	Truth: donner
# Prediction: ent	Truth: contregardoyent
# Prediction: ent	Truth: coniecturoyt
# Prediction: ent	Truth: conseilloys
# Prediction: ent	Truth: contribuasmes
# Prediction: ent	Truth: enclinois
# Prediction: ent	Truth: desmontassions
# Prediction: ent	Truth: esplucha
# Prediction: es	Truth: desistoys
# Prediction: es	Truth: participerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mocquoit
# Prediction: ses	Truth: escappas
# Prediction: ent	Truth: enhortast
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: escriiez
# Prediction: eses	Truth: celebre
# Prediction: ent	Truth: arrestent
# Prediction: ent	Truth: plaiderai
# Prediction: es	Truth: escheverois
# Prediction: eseses	Truth: desbordons
# Prediction: ent	Truth: lurroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: negotieryons
# Prediction: ent	Truth: desmeleriez
# Prediction: ent	Truth: vengiera
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: bancquetant
# Prediction: ent	Truth: desvas
# Prediction: es	Truth: ottroyez
# Prediction: enseese	Truth: buchieriez
# Prediction: ent	Truth: pochasses
# Prediction: ent	Truth: jecte
# Prediction: ent	Truth: perseras
# Prediction: ent	Truth: reside
# Prediction: ent	Truth: tyrast
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: preteryez
# Prediction: ent	Truth: communicquasse
# Prediction: ent	Truth: contrerollera
# Prediction: ent	Truth: contregardes
# Prediction: ess	Truth: enpoisonna
# Prediction: es	Truth: encommenceriez
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: desarmiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desbarateront
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: acceptiez
# Prediction: eeent	Truth: quittoit
# Prediction: ent	Truth: abhorra
# Prediction: ent	Truth: essilieray
# Prediction: es	Truth: destache
# Prediction: ent	Truth: seiourne
# Prediction: seeocsiereocsse	Truth: eschapperoit
# Prediction: seocssierses	Truth: tabustes
# Prediction: ent	Truth: nommiez
# Prediction: es	Truth: detesterois
# Prediction: ent	Truth: chantassions
# Prediction: ensese	Truth: bucha
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: prestassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desmele
# Prediction: ent	Truth: desmelent
# Prediction: eeeeseseseseseseseseseses	Truth: marcherons
# Prediction: ent	Truth: advoueront
# Prediction: ent	Truth: estoffez
# Prediction: ent	Truth: herrie
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: poiseroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: bayseroyent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: poiserons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pasturé
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: plieryez
# Prediction: eneuenncons	Truth: tyrer
# Prediction: ent	Truth: courrouchierent
# Prediction: enseent	Truth: approuvendasses
# Prediction: ent	Truth: endommaige
# Prediction: ent	Truth: pourpensassiez
# Prediction: ent	Truth: persuadast
# Prediction: ent	Truth: desancrassions
# Prediction: ent	Truth: consydereryez
# Prediction: ent	Truth: transporte
# Prediction: enseesesesesesesesesesese	Truth: suffocqueryons
# Prediction: ent	Truth: seiourneray
# Prediction: ent	Truth: escappassent
# Prediction: es	Truth: trempois
# Prediction: enses	Truth: chocquasses
# Prediction: ecccccccccccccccccccccccc	Truth: condescendre
# Prediction: ent	Truth: affermassions
# Prediction: ent	Truth: debaraçons
# Prediction: nseooent	Truth: aboscheray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: bransleroys
# Prediction: eeoieeoieeoieeoieeoieeoie	Truth: mouscheriez
# Prediction: ent	Truth: bruslassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: estirez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: deffierez
# Prediction: s	Truth: gousteras
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mescleroys
# Prediction: ent	Truth: plioyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: parleroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: espieroyt
# Prediction: ent	Truth: passez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: lyoient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: affieryons
# Prediction: ent	Truth: donné
# Prediction: eneocenconponzesconzencon	Truth: faisant
# Prediction: er	Truth: recommanderas
# Prediction: eses	Truth: transportes
# Prediction: ent	Truth: representeriez
# Prediction: enees	Truth: esperonna
# Prediction: ent	Truth: accoustumeroys
# Prediction: ent	Truth: rappellyez
# Prediction: es	Truth: persuaderois
# Prediction: ent	Truth: estoffas
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: praeparerions
# Prediction: eo	Truth: abboyions
# Prediction: ent	Truth: laidengent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tocquassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: renommeroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: acquiteriez
# Prediction: ent	Truth: scellas
# Prediction: ent	Truth: baisa
# Prediction: ent	Truth: enhorte
# Prediction: eoooooooooooooooooooooooo	Truth: adviserois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deifie
# Prediction: ent	Truth: passassent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: deffieroyt
# Prediction: ent	Truth: meslerai
# Prediction: rieeocponsenaeeneeneeneen	Truth: merveillant
# Prediction: ent	Truth: aydyez
# Prediction: s	Truth: aornes
# Prediction: ent	Truth: monteront
# Prediction: ent	Truth: ieunent
# Prediction: ent	Truth: ploye
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gaberoys
# Prediction: ent	Truth: ayderoit
# Prediction: s	Truth: atacher
# Prediction: enses	Truth: alé
# Prediction: ent	Truth: tesmoignois
# Prediction: ent	Truth: communicquerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desprisonnerons
# Prediction: ent	Truth: redrechyez
# Prediction: ent	Truth: representerent
# Prediction: ent	Truth: possessoyent
# Prediction: eneent	Truth: despucelleroys
# Prediction: enees	Truth: esperonnerent
# Prediction: ent	Truth: verifiyez
# Prediction: ent	Truth: deslogeoit
# Prediction: ent	Truth: conseillons
# Prediction: ent	Truth: cabasserai
# Prediction: ent	Truth: alteroyent
# Prediction: ent	Truth: hebergieront
# Prediction: ent	Truth: monstrast
# Prediction: ent	Truth: branslerai
# Prediction: ent	Truth: mangeoient
# Prediction: ent	Truth: escarte
# Prediction: ent	Truth: enferre
# Prediction: ent	Truth: iniuriez
# Prediction: ent	Truth: estacheroient
# Prediction: eeeses	Truth: marcheront
# Prediction: ent	Truth: baysast
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mesclez
# Prediction: ent	Truth: edifiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: affient
# Prediction: ent	Truth: pliassions
# Prediction: ent	Truth: frapent
# Prediction: e	Truth: delivrer
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tyre
# Prediction: eneoceeeeeeeeeeeeeeeeeeee	Truth: moderant
# Prediction: etons	Truth: celer
# Prediction: eses	Truth: descouchoys
# Prediction: ses	Truth: eschappions
# Prediction: seocsie	Truth: tourmentes
# Prediction: entues	Truth: prattiques
# Prediction: ent	Truth: merveillerions
# Prediction: ent	Truth: pourforce
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: rebarbiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tocquoient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: querelasmes
# Prediction: entreeoienteeoienteeoient	Truth: revencheroyent
# Prediction: seeois	Truth: empesche
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: possesseryez
# Prediction: es	Truth: avanches
# Prediction: eses	Truth: creance
# Prediction: seses	Truth: evaporerons
# Prediction: es	Truth: songeois
# Prediction: es	Truth: plaidasse
# Prediction: es	Truth: cachoyent
# Prediction: ent	Truth: esvante
# Prediction: es	Truth: devoure
# Prediction: rt	Truth: rouillons
# Prediction: enseesesesesesesesesesese	Truth: chargeryons
# Prediction: ent	Truth: houyons
# Prediction: ent	Truth: laisses
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: fauçast
# Prediction: ent	Truth: alosa
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enorteroyt
# Prediction: ent	Truth: pacqueront
# Prediction: ent	Truth: erige
# Prediction: ent	Truth: desirez
# Prediction: es	Truth: guiderois
# Prediction: s	Truth: lascher
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: courouchoys
# Prediction: ent	Truth: tesmoignerai
# Prediction: ent	Truth: effrontoys
# Prediction: ent	Truth: acoustume
# Prediction: eoent	Truth: desborda
# Prediction: ent	Truth: esloignast
# Prediction: ent	Truth: desadvoueroient
# Prediction: es	Truth: commencerent
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: cerchiez
# Prediction: entnseentnseses	Truth: expuysoys
# Prediction: eo	Truth: combinois
# Prediction: es	Truth: emboucherois
# Prediction: ent	Truth: raportas
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrobassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: rappelleras
# Prediction: entses	Truth: picquierons
# Prediction: ent	Truth: amadoue
# Prediction: ent	Truth: exposasses
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enferreront
# Prediction: es	Truth: hachoyent
# Prediction: eseses	Truth: marche
# Prediction: esesesesesesesesesesesese	Truth: saulvons
# Prediction: ent	Truth: brusleront
# Prediction: ent	Truth: danceray
# Prediction: enseeeeeeeeeeeeeeeeeeeeee	Truth: vuidasmes
# Prediction: enses	Truth: demande
# Prediction: eoent	Truth: volle
# Prediction: eses	Truth: pisses
# Prediction: seees	Truth: haste
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: ausons
# Prediction: ent	Truth: aeres
# Prediction: ent	Truth: aguysé
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: contrepoisons
# Prediction: ent	Truth: contrerollerions
# Prediction: ent	Truth: desbaucherai
# Prediction: ent	Truth: retournois
# Prediction: entseneeneeneeneeneeneene	Truth: practicquons
# Prediction: ent	Truth: preparyez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: estoffyons
# Prediction: ent	Truth: bransloient
# Prediction: ent	Truth: preparoit
# Prediction: eses	Truth: deschaines
# Prediction: ent	Truth: revenchassent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enterryons
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: gaimentons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: protesterons
# Prediction: ent	Truth: emboucherez
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: desancrerions
# Prediction: ent	Truth: reiectastes
# Prediction: enseseses	Truth: escumoys
# Prediction: ent	Truth: espouserent
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: gastiez
# Prediction: ent	Truth: cabasse
# Prediction: eses	Truth: detestes
# Prediction: rees	Truth: queste
# Prediction: ent	Truth: affamez
# Prediction: ent	Truth: apatissions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pilleroys
# Prediction: ent	Truth: bastent
# Prediction: ent	Truth: gelleroient
# Prediction: ent	Truth: jecteroit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: iecte
# Prediction: ent	Truth: baysez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: fiancer
# Prediction: enses	Truth: houssepille
# Prediction: es	Truth: desbauchoys
# Prediction: ent	Truth: enseignerai
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: chevauchieryons
# Prediction: ent	Truth: allaictyons
# Prediction: es	Truth: estonnions
# Prediction: ent	Truth: possesserent
# Prediction: ent	Truth: avanchasses
# Prediction: es	Truth: esclairasse
# Prediction: ese	Truth: buchyons
# Prediction: ent	Truth: desieune
# Prediction: eneeoent	Truth: recordassent
# Prediction: ent	Truth: arroioyent
# Prediction: ent	Truth: presumerai
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desgorgent
# Prediction: ses	Truth: escappes
# Prediction: ent	Truth: verifient
# Prediction: es	Truth: rouillerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: resisterez
# Prediction: es	Truth: vollasse
# Prediction: enseonseoonseoonseoonseoo	Truth: tumbassions
# Prediction: eses	Truth: advises
# Prediction: seesesesesesesesesesesese	Truth: pechons
# Prediction: ent	Truth: iolyes
# Prediction: ent	Truth: pesas
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: hasteroyt
# Prediction: ent	Truth: aereras
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: nommons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mulctant
# Prediction: ent	Truth: muçons
# Prediction: eisess	Truth: en evitant
# Prediction: e	Truth: en alant
# Prediction: ent	Truth: communicquois
# Prediction: ent	Truth: entreruynyez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: interpreteroys
# Prediction: ent	Truth: entrefaisiez
# Prediction: ent	Truth: estoffois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gaspilleroys
# Prediction: ent	Truth: sollicite
# Prediction: ent	Truth: iniuriast
# Prediction: ent	Truth: arresta
# Prediction: ent	Truth: presenteras
# Prediction: ent	Truth: desploies
# Prediction: es	Truth: cachions
# Prediction: ent	Truth: enchargez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enhorteroys
# Prediction: ent	Truth: trampa
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cerche
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: affermerions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: essilieroyt
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: rebarberions
# Prediction: ent	Truth: cryyez
# Prediction: ent	Truth: notoyt
# Prediction: ent	Truth: empire
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mescleryez
# Prediction: ent	Truth: operes
# Prediction: es	Truth: cache
# Prediction: ent	Truth: eussions
# Prediction: ent	Truth: alloit
# Prediction: ent	Truth: desancrant
# Prediction: ent	Truth: porte
# Prediction: ent	Truth: escorner
# Prediction: enoons	Truth: en esgarant
# Prediction: eniases	Truth: baislé
# Prediction: ent	Truth: s'entredemanderoient
# Prediction: entsesesieroientsesesiero	Truth: revenchoys
# Prediction: ent	Truth: subiugua
# Prediction: ent	Truth: seiournyons
# Prediction: es	Truth: embouchiez
# Prediction: ent	Truth: esclaires
# Prediction: entsnsess	Truth: reculla
# Prediction: ent	Truth: mesclyez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: effronteryons
# Prediction: ent	Truth: praesidez
# Prediction: seeneeeneeeneeeneeeneeene	Truth: gouvernons
# Prediction: es	Truth: leschoys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: deslogent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desferoyt
# Prediction: ent	Truth: pensyez
# Prediction: sent	Truth: esternuons
# Prediction: ent	Truth: galopasmes
# Prediction: ent	Truth: desgorgez
# Prediction: ent	Truth: sceut
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: impugneroyt
# Prediction: ent	Truth: pensoyent
# Prediction: ent	Truth: atournerois
# Prediction: ent	Truth: misses
# Prediction: ent	Truth: ieusneriez
# Prediction: ent	Truth: pensa
# Prediction: ent	Truth: edifierions
# Prediction: sent	Truth: esvantons
# Prediction: 	Truth: proffitant
# Prediction: enseeneeneeneeneeneeneene	Truth: guerpissez
# Prediction: ent	Truth: robbez
# Prediction: enseesesesesesesesesesese	Truth: yrions
# Prediction: enseennl	Truth: operé
# Prediction: o	Truth: contregardasmes
# Prediction: ent	Truth: contregarde
# Prediction: es	Truth: eschappois
# Prediction: ent	Truth: enfelonnasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: chevauchieryez
# Prediction: ent	Truth: translaterai
# Prediction: ent	Truth: desploiiez
# Prediction: es	Truth: suffocquez
# Prediction: es	Truth: possessasse
# Prediction: ensesese	Truth: esternuas
# Prediction: ent	Truth: ottroyast
# Prediction: ent	Truth: estourdiroient
# Prediction: ent	Truth: fiançoyent
# Prediction: es	Truth: fomenterai
# Prediction: es	Truth: infourmeriez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: essilassiez
# Prediction: ent	Truth: desrobbes
# Prediction: ees	Truth: affioys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: arrestent
# Prediction: ent	Truth: urinoys
# Prediction: ent	Truth: amadoueriez
# Prediction: ent	Truth: ymagine
# Prediction: ent	Truth: foetteroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: meriterez
# Prediction: es	Truth: cachassent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: appuieriez
# Prediction: ris	Truth: commençant
# Prediction: seeneeeneeeneeeneeeneeene	Truth: frappez
# Prediction: ensenconsenconsenconsenco	Truth: raporté
# Prediction: s	Truth: aornez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: yroient
# Prediction: ent	Truth: iouant
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: merveillyons
# Prediction: ent	Truth: s'entreruyneront
# Prediction: ent	Truth: supersedassent
# Prediction: ent	Truth: escornoient
# Prediction: ent	Truth: avanchastes
# Prediction: ent	Truth: enchassastes
# Prediction: es	Truth: commençasmes
# Prediction: ent	Truth: atemptoyt
# Prediction: ent	Truth: soulaigeras
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: resignasmes
# Prediction: es	Truth: temprois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: fortifieroys
# Prediction: ent	Truth: flottyons
# Prediction: entsnsees	Truth: supposerent
# Prediction: ees	Truth: seelloys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: monstrerons
# Prediction: seses	Truth: accepterons
# Prediction: rent	Truth: desinfectant
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: precederez
# Prediction: es	Truth: aboscherois
# Prediction: ent	Truth: abayoyent
# Prediction: ent	Truth: ymagineras
# Prediction: ses	Truth: atemptes
# Prediction: entseese	Truth: intoxiquer
# Prediction: ent	Truth: flattent
# Prediction: eoooooooooooooooooooooooo	Truth: effreerois
# Prediction: eses	Truth: excuserois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: trampe
# Prediction: seeneeeneeeneeeneeeneeene	Truth: invitez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: en iniuriant
# Prediction: seoent	Truth: matter
# Prediction: eneocsncont	Truth: tyrant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esmerveille
# Prediction: es	Truth: suffocquoyent
# Prediction: entrentrentrentrentrentre	Truth: sollicitoys
# Prediction: ent	Truth: deschainoyent
# Prediction: ent	Truth: s'entrehurtent
# Prediction: ent	Truth: conseilleryez
# Prediction: ent	Truth: acoustument
# Prediction: ent	Truth: entrempesché
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: atemptyons
# Prediction: eses	Truth: desancre
# Prediction: ess	Truth: en desprisonnant
# Prediction: ent	Truth: honnoureroit
# Prediction: ent	Truth: enchargions
# Prediction: sent	Truth: espoventons
# Prediction: ent	Truth: esvantasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrisierons
# Prediction: ent	Truth: prepareroient
# Prediction: reeeesesesesesesesesesese	Truth: eschevons
# Prediction: ent	Truth: baislasses
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: reiecteryez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: trampent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: veilleroys
# Prediction: ent	Truth: escryeras
# Prediction: es	Truth: oublyerois
# Prediction: eseeeeeeeeeeeeent	Truth: oublyeriez
# Prediction: ensee	Truth: guardent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desancrer
# Prediction: ent	Truth: ruynez
# Prediction: eo	Truth: oziez
# Prediction: eoent	Truth: ayons
# Prediction: ent	Truth: tumbons
# Prediction: enionses	Truth: macté
# Prediction: es	Truth: recommande
# Prediction: eoent	Truth: desbordoit
# Prediction: ent	Truth: executoys
# Prediction: es	Truth: baptisois
# Prediction: es	Truth: desadvouerois
# Prediction: ent	Truth: subiuguions
# Prediction: ent	Truth: goustois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: conquestez
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: estiriez
# Prediction: ent	Truth: desploions
# Prediction: ses	Truth: gaimenterois
# Prediction: ent	Truth: depescheryez
# Prediction: ent	Truth: detestastes
# Prediction: ent	Truth: branslast
# Prediction: ent	Truth: separasses
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: gettiez
# Prediction: ent	Truth: reiecte
# Prediction: ent	Truth: frappassent
# Prediction: ent	Truth: renflastes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: modera
# Prediction: ent	Truth: ottroyeroient
# Prediction: ent	Truth: escriassent
# Prediction: ent	Truth: soingneras
# Prediction: ent	Truth: veiglerai
# Prediction: entrions	Truth: trouva
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tourneroys
# Prediction: ueseseseseseseseseseseses	Truth: fleschissions
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: tiriez
# Prediction: ent	Truth: possede
# Prediction: eent	Truth: oublyera
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enorteryez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: rengeryons
# Prediction: o	Truth: contrepoisa
# Prediction: ent	Truth: communicquerions
# Prediction: ent	Truth: transgloutis
# Prediction: ent	Truth: vous entrehurtassiez
# Prediction: eocsi	Truth: redoubtiez
# Prediction: ent	Truth: supersedassiez
# Prediction: ent	Truth: exploroyt
# Prediction: ent	Truth: galopoyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desyryons
# Prediction: ent	Truth: depescheroit
# Prediction: ent	Truth: coustoys
# Prediction: ent	Truth: blessois
# Prediction: ent	Truth: nettoya
# Prediction: ent	Truth: presentent
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: reguarderions
# Prediction: es	Truth: laschas
# Prediction: ent	Truth: chanterai
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desroberoyt
# Prediction: ent	Truth: coniures
# Prediction: ent	Truth: picque
# Prediction: es	Truth: passois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: hostoieroyent
# Prediction: ent	Truth: pourpensé
# Prediction: eoineeeeeeeeeeeeeeeeeeeee	Truth: nombrez
# Prediction: ent	Truth: pliasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: lyoyent
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: ietterions
# Prediction: ent	Truth: pissons
# Prediction: ent	Truth: cerchié
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tirez
# Prediction: ent	Truth: navrez
# Prediction: enses	Truth: alois
# Prediction: ent	Truth: courrouchoyent
# Prediction: ett	Truth: transgloutirez
# Prediction: ent	Truth: manouvroys
# Prediction: es	Truth: esvertuois
# Prediction: eses	Truth: prattiquasse
# Prediction: ent	Truth: courrouçassions
# Prediction: eneees	Truth: asseurois
# Prediction: ent	Truth: rappellassions
# Prediction: ent	Truth: regardyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: descharge
# Prediction: es	Truth: maschoient
# Prediction: eoi	Truth: nombroyent
# Prediction: eeses	Truth: leichoys
# Prediction: ent	Truth: recuperez
# Prediction: ent	Truth: apuyoient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: separasmes
# Prediction: eses	Truth: enterre
# Prediction: ent	Truth: eslanceriez
# Prediction: es	Truth: tranche
# Prediction: ent	Truth: mettoyent
# Prediction: nseocsse	Truth: lascherois
# Prediction: eiions	Truth: nombres
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: galoperyez
# Prediction: ent	Truth: pausmeront
# Prediction: ent	Truth: portast
# Prediction: ent	Truth: bayserent
# Prediction: eses	Truth: mectes
# Prediction: enses	Truth: venge
# Prediction: ensee	Truth: guideriez
# Prediction: eooocsss	Truth: finirois
# Prediction: eit	Truth: en luittant
# Prediction: eoreoreoreoreoreoreoreore	Truth: saluant
# Prediction: en	Truth: enconvenença
# Prediction: ent	Truth: courrouchoys
# Prediction: eneeoenieeeoneuiis	Truth: raenchonnassions
# Prediction: ecccccccccccccccccccccccc	Truth: condescent
# Prediction: ent	Truth: recouvrois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esgratignerez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: importuneroys
# Prediction: ent	Truth: desployasmes
# Prediction: ent	Truth: enterrassions
# Prediction: ent	Truth: traittions
# Prediction: ent	Truth: exstirpe
# Prediction: seses	Truth: redoubterons
# Prediction: ent	Truth: desancre
# Prediction: es	Truth: tranchas
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: advanceroyent
# Prediction: ses	Truth: grappas
# Prediction: eent	Truth: esprouvez
# Prediction: es	Truth: fomentes
# Prediction: eso	Truth: vuidois
# Prediction: ent	Truth: creance
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: delivreryez
# Prediction: eneeneeneeneeneeneeneenee	Truth: pausmeroys
# Prediction: ent	Truth: dampne
# Prediction: ent	Truth: desyreroient
# Prediction: enseess	Truth: accuseront
# Prediction: ent	Truth: galoperont
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mactassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: revereryez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enortez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: scelle
# Prediction: ent	Truth: baislera
# Prediction: ent	Truth: mectroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: vous entredemandassiez
# Prediction: enses	Truth: houssepilles
# Prediction: ent	Truth: supersedions
# Prediction: esees	Truth: descouchierent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desieunyons
# Prediction: eenees	Truth: esveilloys
# Prediction: es	Truth: empeschoient
# Prediction: ent	Truth: desbauche
# Prediction: ent	Truth: debaracerai
# Prediction: ent	Truth: importunerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esternuast
# Prediction: ent	Truth: consyderes
# Prediction: ent	Truth: desgorgerent
# Prediction: ent	Truth: esquacheroient
# Prediction: eses	Truth: souspirerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esveilleras
# Prediction: ent	Truth: esternuent
# Prediction: ent	Truth: recouvreront
# Prediction: ses	Truth: escapperois
# Prediction: enseese	Truth: escumerent
# Prediction: ent	Truth: alongea
# Prediction: ess	Truth: trompa
# Prediction: ent	Truth: guidyons
# Prediction: ent	Truth: lascheriez
# Prediction: ent	Truth: saluasmes
# Prediction: ent	Truth: muçoyent
# Prediction: ent	Truth: iouoient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: seelleroys
# Prediction: seneenenenenenenenenenene	Truth: assiste
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: preterons
# Prediction: es	Truth: ruynerois
# Prediction: eneueneueneueneueneueneue	Truth: iecter
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: practicqueroient
# Prediction: eions	Truth: depeschiez
# Prediction: ent	Truth: considerasse
# Prediction: ent	Truth: recuperyons
# Prediction: ent	Truth: seiournoys
# Prediction: ent	Truth: mortifiassions
# Prediction: ent	Truth: subiuguieroit
# Prediction: ent	Truth: desheritent
# Prediction: ent	Truth: arrestoyent
# Prediction: ent	Truth: abhorroys
# Prediction: ent	Truth: effronterai
# Prediction: esees	Truth: descouchiez
# Prediction: ent	Truth: arrestastes
# Prediction: ent	Truth: riffloys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: soingneroys
# Prediction: rentseeneeneeneeneeneenee	Truth: espousons
# Prediction: ent	Truth: penetreroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: arresteroyt
# Prediction: ent	Truth: retournez
# Prediction: ent	Truth: foullez
# Prediction: eses	Truth: soucye
# Prediction: ent	Truth: nouoyt
# Prediction: ent	Truth: notois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: porteroys
# Prediction: escoent	Truth: en estouffant
# Prediction: seses	Truth: aloserons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: iolyeroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mangeroys
# Prediction: eit	Truth: en esveiglant
# Prediction: ent	Truth: capasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gaberyez
# Prediction: ent	Truth: loueryez
# Prediction: en	Truth: enconvenencierions
# Prediction: es	Truth: embouchoit
# Prediction: ent	Truth: esguaryez
# Prediction: ent	Truth: eslançois
# Prediction: nseoent	Truth: destacherai
# Prediction: ent	Truth: cauterizerez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: alimenteront
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: accordast
# Prediction: eses	Truth: oublyois
# Prediction: ent	Truth: conferment
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: embausmons
# Prediction: ent	Truth: arrengieriez
# Prediction: ent	Truth: seiournez
# Prediction: ent	Truth: obligeois
# Prediction: esent	Truth: soucyassent
# Prediction: eoooooooooooooooooooooooo	Truth: enhorterois
# Prediction: ees	Truth: estachera
# Prediction: eis	Truth: ronfleray
# Prediction: ent	Truth: obligeassiez
# Prediction: eooent	Truth: achapteront
# Prediction: eso	Truth: vuidois
# Prediction: eoooooooooooooooooooooooo	Truth: divinerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: affamerez
# Prediction: ent	Truth: occurrez
# Prediction: ent	Truth: residera
# Prediction: reeeseseseseseseseseseses	Truth: invadons
# Prediction: eeent	Truth: quittes
# Prediction: ent	Truth: affia
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: sembleroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: armoient
# Prediction: ent	Truth: tournoyer
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: aurez
# Prediction: ent	Truth: contregarderay
# Prediction: ent	Truth: esparpilloys
# Prediction: ent	Truth: remerquyez
# Prediction: enteeoentseeoentseeoentse	Truth: blasphema
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrobbions
# Prediction: ent	Truth: participa
# Prediction: ent	Truth: praesidyez
# Prediction: enseses	Truth: subiugeoys
# Prediction: ent	Truth: cauterizeront
# Prediction: ent	Truth: enchasseroient
# Prediction: enseesesesesesesesesesese	Truth: desrouteryons
# Prediction: ent	Truth: escielle
# Prediction: ent	Truth: laidenge
# Prediction: ent	Truth: haitta
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: cabasseryez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: expellons
# Prediction: ees	Truth: estacheront
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: aornyons
# Prediction: ent	Truth: verifiera
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: raporterions
# Prediction: enses	Truth: entredonner
# Prediction: es	Truth: descouchié
# Prediction: ent	Truth: esguiseroient
# Prediction: ent	Truth: iectoit
# Prediction: ent	Truth: retyrassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: essaye
# Prediction: ent	Truth: accusez
# Prediction: eocssssssssssssssssssssss	Truth: fascheront
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: separeroyent
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: altererions
# Prediction: eo	Truth: ozoyt
# Prediction: ent	Truth: salues
# Prediction: ent	Truth: endommaigeoyt
# Prediction: entreenee	Truth: contrepoiseroyent
# Prediction: ent	Truth: desroutoyt
# Prediction: ent	Truth: fortiffiassent
# Prediction: ent	Truth: importuneray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: provocqua
# Prediction: es	Truth: preparois
# Prediction: ent	Truth: eslançois
# Prediction: entnseent	Truth: expuyserent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: racointeroyent
# Prediction: ent	Truth: rebarbastes
# Prediction: ses	Truth: effectues
# Prediction: ent	Truth: manouvrera
# Prediction: es	Truth: comptions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrobberoyt
# Prediction: ent	Truth: empenserai
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: espouseryons
# Prediction: ent	Truth: haittes
# Prediction: ent	Truth: cerchassent
# Prediction: ent	Truth: bruslent
# Prediction: ent	Truth: hastassions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mocqueryons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: conquester
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mocque
# Prediction: enseseses	Truth: ployerons
# Prediction: ent	Truth: rincez
# Prediction: ent	Truth: guideras
# Prediction: ent	Truth: en honnourant
# Prediction: ent	Truth: ostassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: paye
# Prediction: ent	Truth: ordonner
# Prediction: ent	Truth: note
# Prediction: eent	Truth: approuvendois
# Prediction: eneees	Truth: traveilloys
# Prediction: ess	Truth: enpoisonnoyent
# Prediction: ent	Truth: interpretasses
# Prediction: ent	Truth: transgloutissent
# Prediction: ent	Truth: bobelinoyt
# Prediction: entses	Truth: suffocquasses
# Prediction: ent	Truth: arrengeastes
# Prediction: es	Truth: respiroys
# Prediction: ent	Truth: courroucez
# Prediction: ese	Truth: marchions
# Prediction: ent	Truth: besoigneras
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: racomptez
# Prediction: ent	Truth: enconcheryez
# Prediction: ent	Truth: alongeas
# Prediction: ent	Truth: goustas
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: traitterez
# Prediction: ent	Truth: deifia
# Prediction: ent	Truth: vengeasmes
# Prediction: ent	Truth: cerchieroit
# Prediction: ent	Truth: alterast
# Prediction: eoooooooooooooooooooooooo	Truth: respirerois
# Prediction: ent	Truth: marioient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: seellons
# Prediction: ent	Truth: engroissant
# Prediction: ent	Truth: alosez
# Prediction: 	Truth: allaictant
# Prediction: enseses	Truth: ieune
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: nouons
# Prediction: ent	Truth: ruyne
# Prediction: ent	Truth: poisons
# Prediction: 	Truth: dampnant
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desconseilleroyt
# Prediction: ent	Truth: contregarderont
# Prediction: ent	Truth: consyderast
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: vous entrefrapez
# Prediction: eo	Truth: combinoyent
# Prediction: ent	Truth: importuneras
# Prediction: ent	Truth: escartas
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: acquita
# Prediction: es	Truth: cointoierois
# Prediction: ent	Truth: pastura
# Prediction: entses	Truth: esbaucheryons
# Prediction: ent	Truth: desplaceras
# Prediction: ens	Truth: escumions
# Prediction: entreeeeeeeeeeeeeeeeeeeee	Truth: picquas
# Prediction: eses	Truth: escheves
# Prediction: esesesesesesesesesesesese	Truth: humilions
# Prediction: entreeneeeeeeeeeeeeeeeeee	Truth: demoureroyent
# Prediction: ent	Truth: aguyseray
# Prediction: es	Truth: meslions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: raliyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: visiteroyent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: aerions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: moderent
# Prediction: ent	Truth: scelleriez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pesassiez
# Prediction: ent	Truth: desveroient
# Prediction: ent	Truth: urine
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: resvent
# Prediction: ent	Truth: pochez
# Prediction: enseeeeeeeeeeeeeeeeeeeeee	Truth: huons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: lyeront
# Prediction: ent	Truth: tirez
# Prediction: entrentrentrentrentrentre	Truth: desconseilloys
# Prediction: ent	Truth: contrepoiseront
# Prediction: eo	Truth: depeschyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pourforça
# Prediction: ent	Truth: r'asseureray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gouverneroyent
# Prediction: ent	Truth: remercyes
# Prediction: ent	Truth: desieunerions
# Prediction: ent	Truth: regarda
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: regretteryons
# Prediction: ent	Truth: blessastes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: empiegent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: reiectez
# Prediction: sees	Truth: estachez
# Prediction: ent	Truth: honnoure
# Prediction: eses	Truth: precede
# Prediction: es	Truth: demanderois
# Prediction: eeneeeeeeeeeeeeeeeeeeeeee	Truth: ottroyerez
# Prediction: ent	Truth: employons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: luitteroyt
# Prediction: ent	Truth: atournons
# Prediction: s	Truth: faschent
# Prediction: ent	Truth: arrestez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: picqueroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mesleroyent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: cesseroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: ieuneroyt
# Prediction: esesns	Truth: exstirper
# Prediction: eoent	Truth: aie
# Prediction: enions	Truth: essilié
# Prediction: enions	Truth: preparé
# Prediction: es	Truth: aurois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: melancholieryons
# Prediction: ent	Truth: revenchyez
# Prediction: ent	Truth: pourpensasse
# Prediction: ent	Truth: surnommyez
# Prediction: ent	Truth: enpoisonneras
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desrobboient
# Prediction: ent	Truth: praeparassions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esperonneryons
# Prediction: es	Truth: creançois
# Prediction: ent	Truth: hebergeasses
# Prediction: ent	Truth: prattiquez
# Prediction: es	Truth: desroboient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enclinions
# Prediction: ent	Truth: desroberai
# Prediction: ent	Truth: escorcheroient
# Prediction: es	Truth: tranches
# Prediction: entsnses	Truth: supposes
# Prediction: ent	Truth: monstres
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: escumeroys
# Prediction: ent	Truth: foetteryez
# Prediction: ent	Truth: occupe
# Prediction: ent	Truth: montasse
# Prediction: ent	Truth: gasteray
# Prediction: ent	Truth: hucheroient
# Prediction: ent	Truth: cuydons
# Prediction: ent	Truth: aydasses
# Prediction: ense	Truth: tuyez
# Prediction: ent	Truth: evite
# Prediction: ent	Truth: veiglons
# Prediction: ent	Truth: disnez
# Prediction: rent	Truth: empensant
# Prediction: ent	Truth: gousté
# Prediction: ecccccccccccccccccccccccc	Truth: condescendriez
# Prediction: es	Truth: desancroys
# Prediction: ent	Truth: abhorrois
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: acoustumerions
# Prediction: ent	Truth: tourmente
# Prediction: ent	Truth: deschaineriez
# Prediction: ent	Truth: effrontasmes
# Prediction: ent	Truth: coniurois
# Prediction: ent	Truth: reiettyez
# Prediction: ent	Truth: deslogeoyt
# Prediction: ees	Truth: arrestoys
# Prediction: ent	Truth: remercyeroit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: subiecteryez
# Prediction: es	Truth: estachastes
# Prediction: ent	Truth: atempteray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: evaporeroyt
# Prediction: es	Truth: foullas
# Prediction: ent	Truth: desvyez
# Prediction: ent	Truth: deffiast
# Prediction: s	Truth: coucheras
# Prediction: ent	Truth: aracheroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: nombrons
# Prediction: es	Truth: saultes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: passerez
# Prediction: ent	Truth: prya
# Prediction: enseesesesesesesesesesese	Truth: subiecter
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: apuyeroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pisseryez
# Prediction: ent	Truth: fouragié
# Prediction: eneocenenenenenenenenenen	Truth: delaçant
# Prediction: enions	Truth: mis
# Prediction: e	Truth: embler
# Prediction: ent	Truth: coniecture
# Prediction: enteeeeeeeeeeeeeeeeeeeeee	Truth: r'asseura
# Prediction: ent	Truth: proffityez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: remerquassent
# Prediction: ent	Truth: presentassions
# Prediction: ent	Truth: enchargieras
# Prediction: ses	Truth: redoubteras
# Prediction: ent	Truth: engendrera
# Prediction: ent	Truth: desrobberions
# Prediction: es	Truth: esbauchent
# Prediction: ent	Truth: aguysoys
# Prediction: ent	Truth: deschireront
# Prediction: ent	Truth: esprouverois
# Prediction: ent	Truth: alongeoyent
# Prediction: eses	Truth: persuade
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: presumeroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: ordonneroys
# Prediction: ent	Truth: renflerai
# Prediction: ent	Truth: deffierai
# Prediction: ent	Truth: leichasses
# Prediction: ent	Truth: flotte
# Prediction: nsees	Truth: grappe
# Prediction: ent	Truth: chocquons
# Prediction: senees	Truth: espoventer
# Prediction: es	Truth: pesois
# Prediction: ense	Truth: desploié
# Prediction: ent	Truth: aloses
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gaste
# Prediction: ent	Truth: donneront
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desvez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: peseroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tireryons
# Prediction: ent	Truth: deschevauches
# Prediction: ent	Truth: endommaigeoit
# Prediction: ent	Truth: destournyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: bancquete
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: redrechierons
# Prediction: ent	Truth: exstirperay
# Prediction: s	Truth: raenchonnons
# Prediction: ent	Truth: guerpissois
# Prediction: enseseseseseseseseseseses	Truth: denunchie
# Prediction: ent	Truth: deshonnouré
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: esveillons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: nettoyasmes
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: eschapperions
# Prediction: ent	Truth: celebra
# Prediction: ent	Truth: protegeastes
# Prediction: ent	Truth: advanceriez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: semblasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: expellent
# Prediction: ent	Truth: supposeriez
# Prediction: ent	Truth: esmayasses
# Prediction: eses	Truth: prestes
# Prediction: ent	Truth: adaptes
# Prediction: es	Truth: ployasse
# Prediction: ent	Truth: deschainant
# Prediction: ent	Truth: guarderoit
# Prediction: encont	Truth: exstirpant
# Prediction: ent	Truth: veillons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: meslons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pisseroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: payeroys
# Prediction: ent	Truth: aie
# Prediction: enionses	Truth: baisé
# Prediction: ent	Truth: enconvenencieriez
# Prediction: ent	Truth: deschargeoyt
# Prediction: entseneeneeneeneeneeneene	Truth: communicquons
# Prediction: ess	Truth: soubhaittastes
# Prediction: ent	Truth: recouvryez
# Prediction: enseses	Truth: denunchiast
# Prediction: es	Truth: enterrois
# Prediction: es	Truth: renommois
# Prediction: ent	Truth: esloignassent
# Prediction: ent	Truth: appelliez
# Prediction: ent	Truth: escorchez
# Prediction: ent	Truth: delaissent
# Prediction: ent	Truth: persuadons
# Prediction: eseso	Truth: trousse
# Prediction: seooooooooooooooooooooooo	Truth: haittes
# Prediction: eeneeeeeeeeeeeeeeeeeeeeee	Truth: demeslerois
# Prediction: ent	Truth: aornoys
# Prediction: ent	Truth: emergea
# Prediction: es	Truth: iettoys
# Prediction: ent	Truth: tournoyez
# Prediction: ent	Truth: enhorteroient
# Prediction: ent	Truth: occurreroys
# Prediction: ent	Truth: desferoient
# Prediction: ent	Truth: pesyez
# Prediction: 	Truth: participant
# Prediction: ent	Truth: entrast
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: appuieroys
# Prediction: ent	Truth: finit
# Prediction: eneeerserereesesesesesese	Truth: pacqué
# Prediction: eiaste	Truth: adviser
# Prediction: ent	Truth: lyeroient
# ...
# Prediction: ent	Truth: iniurierois
# Prediction: ent	Truth: amadouons
# Prediction: ses	Truth: soupperay
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: expellez
# Prediction: ent	Truth: tremperoit
# Prediction: reeeseseseseseseseseseses	Truth: singlons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: lurreroys
# Prediction: ent	Truth: revere
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: macte
# Prediction: ent	Truth: noueroient
# Prediction: ent	Truth: loge
# Prediction: eeuuuuuuuuuuuuuuuuuuuuuuu	Truth: en marchant
# Prediction: ent	Truth: finez
# Prediction: en	Truth: enconvenençoit
# Prediction: ent	Truth: estincellassions
# Prediction: ent	Truth: enfelonnyez
# Prediction: ent	Truth: gaspilloit
# Prediction: ent	Truth: enconchoyt
# Prediction: ees	Truth: fromentions
# Prediction: ent	Truth: prattiqua
# Prediction: ent	Truth: effectuois
# Prediction: ent	Truth: bobelinoient
# Prediction: ent	Truth: obligeoys
# Prediction: ent	Truth: mercyoit
# Prediction: ent	Truth: empiegeassions
# Prediction: ent	Truth: gaimentez
# Prediction: ent	Truth: honnourerois
# Prediction: ent	Truth: depesche
# Prediction: ent	Truth: chocquerai
# Prediction: ent	Truth: entitule
# Prediction: sencons	Truth: evapores
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: escumasses
# Prediction: es	Truth: esgalasse
# Prediction: ent	Truth: evaporeroient
# Prediction: esesese	Truth: soucyast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tremble
# Prediction: ent	Truth: jectasses
# Prediction: ent	Truth: entrasses
# Prediction: ent	Truth: pausme
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: adapteryons
# Prediction: ent	Truth: pilles
# Prediction: ent	Truth: fuma
# Prediction: ent	Truth: residons
# Prediction: en	Truth: eussent
# Prediction: enses	Truth: tué
# Prediction: ent	Truth: desconseilleroit
# Prediction: ent	Truth: deschevauche
# Prediction: ent	Truth: blasphemyez
# Prediction: ent	Truth: deliberiez
# Prediction: ent	Truth: desroutyez
# Prediction: seeneeeneeeneeeneeeneeene	Truth: chevauchions
# Prediction: es	Truth: rappellasse
# Prediction: ent	Truth: suffocquera
# Prediction: s	Truth: contribuerions
# Prediction: es	Truth: delaçois
# Prediction: ent	Truth: consideres
# Prediction: ent	Truth: delaissassent
# Prediction: ea	Truth: advouiez
# Prediction: eses	Truth: desregles
# Prediction: ent	Truth: amadouas
# Prediction: eois	Truth: luittois
# Prediction: ent	Truth: raportasses
# Prediction: ent	Truth: heurtiez
# Prediction: ent	Truth: enyvroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: bastyons
# Prediction: seeoineeoineeoineeoineeoi	Truth: revenchez
# Prediction: ent	Truth: occupasse
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: cousteroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tramperoyent
# Prediction: entrions	Truth: trouve
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: abiureroyent
# Prediction: enses	Truth: houa
# Prediction: ent	Truth: besoinger
# Prediction: ent	Truth: mectrions
# Prediction: ent	Truth: monstré
# Prediction: es	Truth: songe
# Prediction: etcntnsnsnsnsnsnsnsnsnsns	Truth: en seellant
# Prediction: ess	Truth: desprisonnoient
# Prediction: ent	Truth: desconseillons
# Prediction: es	Truth: melancholierois
# Prediction: rsentseneeneeneeneeneenee	Truth: nous entredonnons
# Prediction: ent	Truth: engendroit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: racomptoyent
# Prediction: eent	Truth: estourdissoys
# Prediction: es	Truth: arrengeasse
# Prediction: ent	Truth: translateroient
# Prediction: ent	Truth: supposoyent
# Prediction: ent	Truth: empruntassent
# Prediction: es	Truth: desfaisois
# Prediction: eneeoent	Truth: enchargeroys
# Prediction: ent	Truth: tabusta
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: meritoient
# Prediction: ent	Truth: souppoient
# Prediction: nses	Truth: escappasse
# Prediction: ent	Truth: pastureray
# Prediction: ent	Truth: esventeras
# Prediction: ees	Truth: marioys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: essayasmes
# Prediction: ent	Truth: espargnons
# Prediction: ent	Truth: reigla
# Prediction: ent	Truth: delivre
# Prediction: ent	Truth: montois
# Prediction: ent	Truth: portoyt
# Prediction: ses	Truth: atempterois
# Prediction: s	Truth: couste
# Prediction: es	Truth: navrerois
# Prediction: ent	Truth: celeray
# Prediction: seses	Truth: huerons
# Prediction: ent	Truth: fumons
# Prediction: ent	Truth: desinfectyez
# Prediction: ent	Truth: deshonnoureras
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: declairiez
# Prediction: ent	Truth: deschargeassions
# Prediction: ent	Truth: remonstras
# Prediction: ent	Truth: enfelonneray
# Prediction: ent	Truth: encommence
# Prediction: seeneeeneeeneeeneeeneeene	Truth: approuchions
# Prediction: ent	Truth: arrestyez
# Prediction: ense	Truth: accusyez
# Prediction: ent	Truth: adiousteroit
# Prediction: ent	Truth: reveroit
# Prediction: ent	Truth: operoyt
# Prediction: ent	Truth: celebreroit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esguareroyt
# Prediction: ent	Truth: eschevera
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: fiancerent
# Prediction: eses	Truth: picquierois
# Prediction: ent	Truth: empirast
# Prediction: eo	Truth: vollions
# Prediction: ent	Truth: baisleray
# Prediction: ent	Truth: couchasmes
# Prediction: ent	Truth: aboschez
# Prediction: ent	Truth: cessoyent
# Prediction: ent	Truth: esgare
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: invaderoys
# Prediction: es	Truth: avallerois
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: aymyons
# Prediction: ent	Truth: herrieroit
# Prediction: ent	Truth: opereront
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: finissent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: tyreroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: courouchast
# Prediction: eseses	Truth: souspiroys
# Prediction: ent	Truth: mortifiassent
# Prediction: ent	Truth: escoutyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: praesenteront
# Prediction: es	Truth: scellions
# Prediction: ent	Truth: soumectrez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: seiourneryons
# Prediction: ent	Truth: esperoyent
# Prediction: ent	Truth: revenchez
# Prediction: ent	Truth: gaspillent
# Prediction: ent	Truth: atournasse
# Prediction: ent	Truth: effrontes
# Prediction: eneeoent	Truth: estudiassions
# Prediction: eseeneeeneeeneeeneeeneeen	Truth: mensongiez
# Prediction: ent	Truth: advisoient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: estoufferyons
# Prediction: os	Truth: ottroyasmes
# Prediction: ent	Truth: racompterois
# Prediction: entseneeneeneeneeneeneene	Truth: delaçons
# Prediction: ent	Truth: arroiastes
# Prediction: ent	Truth: trempastes
# Prediction: ent	Truth: escrya
# Prediction: ent	Truth: precederoit
# Prediction: es	Truth: entrefait
# Prediction: es	Truth: cachyez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: modereroys
# Prediction: ent	Truth: tourne
# Prediction: ent	Truth: en effrontant
# Prediction: ent	Truth: levez
# Prediction: ent	Truth: ames
# Prediction: ent	Truth: reverant
# Prediction: ent	Truth: enconvenenciez
# Prediction: ens	Truth: raenchonna
# Prediction: enenenenenenenenenenenene	Truth: accointoys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: laidengyons
# Prediction: ent	Truth: represente
# Prediction: ent	Truth: haittoyt
# Prediction: ent	Truth: desieunassent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pourforceroys
# Prediction: eseses	Truth: picquasse
# Prediction: entreenees	Truth: cointoieroyent
# Prediction: ent	Truth: encharge
# Prediction: ent	Truth: provocquons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: traittieroys
# Prediction: ent	Truth: baptiserent
# Prediction: esees	Truth: estacherent
# Prediction: ent	Truth: jectoyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: employeroyt
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: accordez
# Prediction: es	Truth: couchassions
# Prediction: ent	Truth: plaideray
# Prediction: ent	Truth: deslogeroient
# Prediction: entses	Truth: aboscherons
# Prediction: eo	Truth: mascha
# Prediction: ent	Truth: fortiffier
# Prediction: eeoeneeeeeeeeeeeeeeeeeeee	Truth: abboyerez
# Prediction: ent	Truth: erigeroient
# Prediction: ent	Truth: altere
# Prediction: ent	Truth: aorne
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pilleront
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: operons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: quiteryons
# Prediction: enses	Truth: en ruynant
# Prediction: ent	Truth: entrencontroyent
# Prediction: ent	Truth: renouvelliez
# Prediction: ent	Truth: prattiquassions
# Prediction: seses	Truth: cauterizerois
# Prediction: ent	Truth: acoustreray
# Prediction: ent	Truth: respiroyent
# Prediction: enees	Truth: empoizonne
# Prediction: ent	Truth: espoventera
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: creancerent
# Prediction: ent	Truth: coustoyent
# Prediction: ent	Truth: bobelinerois
# Prediction: es	Truth: effreoys
# Prediction: ent	Truth: mortifient
# Prediction: ent	Truth: picquieray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: appellassent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: regretteroys
# Prediction: ent	Truth: soulaigent
# Prediction: reeeseseseseseseseseseses	Truth: esvantons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: baptiserons
# Prediction: ent	Truth: eslevasses
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enterreroyent
# Prediction: ent	Truth: desyra
# Prediction: eneeoent	Truth: fleschiroys
# Prediction: enseeneeneeneeneeneent	Truth: urinerent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: scelleras
# Prediction: es	Truth: coucheroys
# Prediction: ent	Truth: aymoyent
# Prediction: ses	Truth: gasterois
# Prediction: sent	Truth: poches
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mocque
# Prediction: ent	Truth: vuiderions
# Prediction: ent	Truth: executé
# Prediction: ent	Truth: transporterai
# Prediction: entrareres	Truth: renouvellerai
# Prediction: ent	Truth: accoustumerai
# Prediction: ent	Truth: engroissassiez
# Prediction: ent	Truth: esciellastes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esciellez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desreglassiez
# Prediction: entsnses	Truth: supposois
# Prediction: nsees	Truth: eschapperai
# Prediction: sent	Truth: escappa
# Prediction: entrentrentrentrentrentre	Truth: enortoys
# Prediction: enseeneeeneeeneeeneeeneee	Truth: subiugeassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: renfloyent
# Prediction: enses	Truth: chocqua
# Prediction: ent	Truth: remerquez
# Prediction: ent	Truth: iolyois
# Prediction: ent	Truth: tournerai
# Prediction: ent	Truth: mesclast
# Prediction: ent	Truth: foetterai
# Prediction: ent	Truth: subiuge
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pryyons
# Prediction: ent	Truth: muçois
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: frappe
# Prediction: es	Truth: fluis
# Prediction: ent	Truth: resvez
# Prediction: ent	Truth: ayda
# Prediction: ensee	Truth: guidons
# Prediction: ent	Truth: escorché
# Prediction: ent	Truth: achevons
# Prediction: ent	Truth: cryeroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: en armoiant
# Prediction: enions	Truth: payé
# Prediction: ent	Truth: contrepoises
# Prediction: ent	Truth: rappellois
# Prediction: ese	Truth: esquachions
# Prediction: ent	Truth: desinfecteroit
# Prediction: ent	Truth: esvertua
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: estrangleroyt
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: participeryez
# Prediction: ent	Truth: explicqueroit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: delibereroyt
# Prediction: es	Truth: infourment
# Prediction: ent	Truth: desrobbera
# Prediction: enseououououououououououo	Truth: reguardes
# Prediction: ent	Truth: nettoyerions
# Prediction: ent	Truth: delacera
# Prediction: ent	Truth: supposent
# Prediction: ent	Truth: desnoueront
# Prediction: ent	Truth: saulta
# Prediction: es	Truth: humilie
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: temprent
# Prediction: enseeneeneeneeneeneeneene	Truth: sçauront
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: flottons
# Prediction: ent	Truth: brusles
# Prediction: es	Truth: tramperois
# Prediction: ent	Truth: pausmons
# Prediction: ent	Truth: rebarbe
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: picquez
# Prediction: ent	Truth: erigerions
# Prediction: ent	Truth: en proffitant
# Prediction: ent	Truth: houerent
# Prediction: ent	Truth: ployeras
# Prediction: ent	Truth: sera
# Prediction: enses	Truth: aymé
# Prediction: ent	Truth: traveillas
# Prediction: ent	Truth: mehaignoyt
# Prediction: enseseseseseseseseseseses	Truth: courouchieront
# Prediction: ent	Truth: representeroient
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: nous entrehurtons
# Prediction: ent	Truth: embausmyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: entrefraperoyent
# Prediction: ess	Truth: suffocquastes
# Prediction: ent	Truth: accoustumerez
# Prediction: ent	Truth: confermoit
# Prediction: eseese	Truth: buchoyent
# Prediction: ent	Truth: coniurassions
# Prediction: ent	Truth: besoignent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: debarace
# Prediction: eisesieeoisi	Truth: revenchent
# Prediction: ent	Truth: hebergions
# Prediction: eo	Truth: tombiez
# Prediction: ent	Truth: preferera
# Prediction: ent	Truth: exposassiez
# Prediction: ent	Truth: apuyastes
# Prediction: ent	Truth: laissera
# Prediction: ent	Truth: louoyent
# Prediction: ent	Truth: donnassions
# Prediction: ent	Truth: essayeroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: soupperoyent
# Prediction: ent	Truth: herriez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: nombreroys
# Prediction: ees	Truth: en fromentant
# Prediction: es	Truth: fusse
# Prediction: es	Truth: erigerois
# Prediction: ent	Truth: alerent
# Prediction: eneueneueneueneueneueneue	Truth: resister
# Prediction: ent	Truth: communicque
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: desbaratassiez
# Prediction: ense	Truth: raenchonneroient
# Prediction: entsnseseses	Truth: destournerons
# Prediction: ent	Truth: retournast
# Prediction: ent	Truth: manouvreray
# Prediction: es	Truth: destachastes
# Prediction: enseesses	Truth: contribuent
# Prediction: es	Truth: confessast
# Prediction: nseoient	Truth: escorchassions
# Prediction: ent	Truth: seiourna
# Prediction: ent	Truth: cauterizeriez
# Prediction: ent	Truth: presumassions
# Prediction: es	Truth: precedasse
# Prediction: ent	Truth: regratie
# Prediction: ent	Truth: retournera
# Prediction: es	Truth: couchyez
# Prediction: eseseses	Truth: quittasse
# Prediction: ent	Truth: esguareras
# Prediction: ent	Truth: mouscheroys
# Prediction: es	Truth: devoures
# Prediction: ent	Truth: adaptassions
# Prediction: ent	Truth: aboschent
# Prediction: es	Truth: rengeois
# Prediction: ent	Truth: flattas
# Prediction: ent	Truth: accepteroit
# Prediction: ent	Truth: reserveroit
# Prediction: ent	Truth: esgarast
# Prediction: es	Truth: humilie
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: pillent
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: mectiez
# Prediction: eee	Truth: en ozant
# Prediction: ent	Truth: repraesentoit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: endommaigeryez
# Prediction: ent	Truth: s'entreruynent
# Prediction: ensee	Truth: raenchonnons
# Prediction: ent	Truth: possesseray
# Prediction: eo	Truth: recordoys
# Prediction: ent	Truth: persuaderai
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: gouverneroys
# Prediction: enseesesesesesesesesesese	Truth: esternueroyent
# Prediction: es	Truth: besoignerois
# Prediction: es	Truth: enterrasse
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: esgarions
# Prediction: ent	Truth: plaida
# Prediction: seeeeeeeeeeeeeeeeeeeeeeee	Truth: supposerions
# Prediction: ent	Truth: estacheroys
# Prediction: ent	Truth: delaces
# Prediction: ent	Truth: altereray
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enterrez
# Prediction: ent	Truth: abhorres
# Prediction: ent	Truth: protege
# Prediction: ns	Truth: maschasse
# Prediction: ent	Truth: delaceriez
# Prediction: ent	Truth: eviterai
# Prediction: ent	Truth: escryent
# Prediction: ent	Truth: heurteriez
# Prediction: ent	Truth: lurrasses
# Prediction: ent	Truth: armoieras
# Prediction: so	Truth: goustes
# Prediction: enseeoent	Truth: tumbez
# Prediction: ent	Truth: erigera
# Prediction: enseseses	Truth: peserons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: lyons
# Prediction: ent	Truth: presupposois
# Prediction: ent	Truth: destournassent
# Prediction: es	Truth: fouragea
# Prediction: es	Truth: desadvoues
# Prediction: enseess	Truth: contribueroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: galopyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: traittierons
# Prediction: ent	Truth: gastoyt
# Prediction: ent	Truth: cercha
# Prediction: eoent	Truth: toquoient
# Prediction: es	Truth: pissois
# Prediction: enseeneeneeneeneeneeneene	Truth: abiurez
# Prediction: ent	Truth: oblige
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: robberoys
# Prediction: ent	Truth: gaste
# Prediction: ent	Truth: vuideront

# %% [markdown]
# ## 3.5 Experiment 3

# %% [markdown]
# ### Pointer Generator over characters and tags

# %%
# %matplotlib inline

from itertools import zip_longest
import os
import pickle
import time

import Levenshtein
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
def load_data(file_name):
    """Loads data.

    Args:
        file_name: path to file containing the data

    Returns:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form
    """

    with open(file_name, 'r', encoding='utf') as file:
        text = file.read()

    lemmas = []
    tags = []
    inflected_forms = []

    for line in text.split('\n')[:-1]:
        lemma, inflected_form, tag = line.split('\t')
        lemmas.append(lemma)
        inflected_forms.append(inflected_form)
        tags.append(tag) 

    return lemmas, tags, inflected_forms

def get_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char, tag2index

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps character to index
        index2char: a dictionary which maps index to character
        tag2index: a ditionary which maps morphological tag to index 
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR) # special start and end symbols
    unique_chars.update(UNKNOWN_CHAR) # special charcter for unknown word
    char2index = {}
    index2char = {}

    char2index[PAD_CHAR] = 0
    index2char[0] = PAD_CHAR
    
    for index, char in enumerate(unique_chars):
        char2index[char] = index + 1
        index2char[index + 1] = char

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.update(UNKNOWN_TAG)
    tag2index = {tag:index+1 for index, tag in enumerate(unique_tags)}
    tag2index[PAD_TAG] = 0

    return char2index, index2char, tag2index

def get_combined_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps inputs and  to index
        index2char: a dictionary which maps index to inputs
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR, UNKNOWN_CHAR) # special start and end symbols  
    
    input2index = {}
    index2input = {}
    
    input2index[PAD_CHAR] = 0
    index2input[0] = PAD_CHAR
        
    for index, char in enumerate(unique_chars, start=1):
        input2index[char] = index
        index2input[index] = char
        
    char_vocab_length = len(input2index.keys())

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.add(UNKNOWN_TAG) # special character for unknown tags
    
    for index, char in enumerate(unique_tags, start=char_vocab_length):
        input2index[char] = index
        index2input[index] = char

    return input2index, index2input, char_vocab_length

def words_to_indices(words, char2index, tensor=False, start_char=False, stop_char=False):
    """Converts list of words to a list with list containing indices

    Args:
        words: list of words
        char2index: dictionary which maps character to index
        tensor: if to return a list of tensor  

    Returns:
        tensor: list of list/tensor containing indices for a sequence of characters
    """

    list_indices = []
    for word in words:
        word_indices = []
        if start_char:
            word_indices.append(char2index[START_CHAR])
        for char in word:
            if char in char2index.keys():
                word_indices.append(char2index[char])
            else:
                word_indices.append(char2index[UNKNOWN_CHAR])
        if stop_char:
            word_indices.append(char2index[STOP_CHAR])
        if tensor:
            word_indices = torch.Tensor(word_indices)
        list_indices.append(word_indices)

    return list_indices

def tag_to_vector(tags, tag2index):
    """Returns one hot representation of tags given a tag.

    Args:
        tags: list of string representation of tag (eg, V;IND;PRS;2;PL)

    Returns:
        tag_vectors: list of 1D tensors with one hot representation of tags 
    """

    tag_vectors = []
    for tag in tags:
        tag_vector = torch.zeros(len(tag2index))
        for tag_feature in tag.split(';'):
            if tag_feature in tag2index:
                tag_vector[tag2index[tag_feature]] = 1
            else:
                tag_vector[tag2index[UNKNOWN_TAG]] = 1
        tag_vectors.append(tag_vector)
    return tag_vectors

def tag_to_indices(tags, tag2index):
    """Converts list of tags to a list of lists containing indices

    Args:
        words: list of tags

    Returns:
        tensor: list of list containing indices of sub_tags
    """
    
    list_indices = []
    for tag in tags:
        tag_indices = []
        for sub_tag in tag.split(';'):
            if sub_tag in tag2index.keys():
                tag_indices.append(tag2index[sub_tag])
            else:
                tag_indices.append(tag2index[UNKNOWN_TAG])
        list_indices.append(tag_indices)

    return list_indices
    

def indices_to_word(indices, index2char):
    """Returns a word given list contaning indices of words

    Args:
        indices: list containing indices

    Returns:
        word: a string
    """

    return ''.join([index2char[index] for index in indices])[:-1]

def pad_lists(lists, pad_int, pad_len=None):
    """Pads lists in a list to make them of equal size"""
    
    if pad_len is None:
        pad_len = max([len(lst) for lst in lists])
    new_list = []
    for lst in lists:
        if len(lst) < pad_len:
            new_list.append(torch.tensor(lst + [pad_int] * (pad_len-len(lst))))
        else:
            new_list.append(torch.tensor(lst[:pad_len]))
    return torch.stack(new_list)

def merge_lists(lists1, lists2):
    """Add two list of lists."""
    
    merged_lists = []
    for list1, list2 in zip(lists1, lists2):
        merged_lists.append(list1 + list2)
    return merged_lists

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def accuracy(predictions, targets):
    correct_count = 0
    for prediction, target in zip(predictions, targets):
        if prediction == target:
            correct_count += 1
    return correct_count / len(predictions)

def average_distance(predictions, targets):
    total_distance = 0
    for prediction, target in zip(predictions, targets):
        total_distance += Levenshtein.distance(prediction, target)
    return total_distance / len(predictions)

def evaluate(predictions, targets):
    return accuracy(predictions, targets), average_distance(predictions, targets)

# %%
language = 'middle-french'
dataset = 'high'

# %%
lemmas, tags, inflected_forms = load_data('./conll2018/task1/all/{}-train-{}'.format(language, dataset))

# %%
lemmas_train, lemmas_val, tags_train, tags_val, inflected_forms_train, inflected_forms_val = train_test_split(lemmas, tags, inflected_forms, test_size=0.2, random_state=42)

# %%
input2index, index2input, char_vocab_size = get_combined_index_dictionaries(lemmas_train, tags_train, inflected_forms_train)

# %% [markdown]
# ### Train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32
embedding_size = 300
hidden_size = 100
input_vocab_size = len(index2input.keys())

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size, p=0.3):
        # general scoring function - global attention 

        super(Attention, self).__init__()
        self.W_a = nn.Linear(2*hidden_size, hidden_size, bias=False)
        # self.dropout = nn.Dropout(p)

    def forward(self, encoded_input, hidden_state, input_mask):
        src_len = encoded_input.shape[1]
        attn_weights = torch.bmm(self.W_a(encoded_input), hidden_state.transpose(0, 1).transpose(1, 2)).squeeze()
        attn_weights.data.masked_fill_(input_mask, float('-inf'))
        # attn_weights = dropout(attn_weights)
        attn_weights = F.softmax(attn_weights, dim=1)
        return attn_weights

# %%
class GenerationProbability(nn.Module):
    def __init__(self, embedding_size, hidden_size):
        super(GenerationProbability, self).__init__()
        self.linear_context = nn.Linear(2*hidden_size, 1)
        self.linear_hidden = nn.Linear(hidden_size, 1)
        self.linear_input = nn.Linear(embedding_size, 1)
        
    def forward(self, context, hidden_state, decoder_input):
        return F.sigmoid(self.linear_context(context) + self.linear_hidden(hidden_state.squeeze()) + self.linear_input(decoder_input))

# %%
Embedder = nn.Embedding(input_vocab_size, embedding_size, padding_idx=input2index[PAD_CHAR]).to(device)
Encoder = nn.LSTM(embedding_size, hidden_size, batch_first=True, bidirectional=True).to(device)
attention = Attention(hidden_size).to(device)
Decoder = nn.LSTM(embedding_size + 2 * hidden_size, hidden_size, batch_first=True).to(device)
linear_vocab = nn.Linear(3 * hidden_size, char_vocab_size - 1).to(device) # remove pad character option
generation_prob = GenerationProbability(embedding_size, hidden_size).to(device)
log_softmax = nn.LogSoftmax(dim=2).to(device)
criterion = nn.NLLLoss(ignore_index=-1)
params = list(Embedder.parameters()) + list(Encoder.parameters()) + list(Decoder.parameters()) + \
        list(linear_vocab.parameters())+ list(attention.parameters()) + list(generation_prob.parameters())

# %%
def test(lemmas_val, tags_val, inflected_forms_val, batch_size=32, attn_debug=False, max_pred_len=25):
    max_pred_len = 25

    inflected_predicted = []
    inflected_forms_true = []
    if attn_debug:
        input_seq = []
        attn_weights_all = []
        p_gen_all = []
    output_indices = []

    for batch in grouper(zip(lemmas_val, tags_val, inflected_forms_val), batch_size):
        batch = list(filter(lambda x: x is not None, batch))
        lemmas, tags, inflected_forms = zip(*batch)

        lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
        tags_indices = tag_to_indices(tags, input2index)    
        input_indices = merge_lists(lemmas_indices, tags_indices)

        # Sort by length of input sequence
        input_indices, inflected_forms = zip(*sorted(zip(input_indices, inflected_forms), key=lambda x: len(x[0]), reverse=True))        
        if attn_debug:
            input_seq += [[index2input[index] for index in input_indices1] for input_indices1 in input_indices]
        input_indices = [torch.tensor(lst) for lst in input_indices]

        input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
        embedding = Embedder(input_tensor)
        lengths = [Tensor.shape[0] for Tensor in input_indices]
        packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
        encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
        encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]

        input_mask = input_tensor == 0
        # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 


        # Decode
        hidden_state = hidden[0,:,:] + hidden[1,:,:]
        hidden_state = hidden_state.unsqueeze(0)
        cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

        decoder_input = torch.tensor([input2index[START_CHAR]] * len(lengths)).to(device)
        decoder_input = Embedder(decoder_input)


        outputs = []
        attn_weights_sequence = []
        p_gen_seq = []
        for seq in range(0, max_pred_len):
            attn_weights = attention(encoded_input, hidden_state, input_mask)
            context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

            decoder_input_concat = torch.cat([context, decoder_input], dim=1)

            output, (hidden_state, cell_state) = Decoder(decoder_input_concat.unsqueeze(1), (hidden_state, cell_state))
            p_vocab = F.relu(linear_vocab(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))    
            p_vocab = F.softmax(p_vocab.squeeze(), dim=1)
            p_gen = generation_prob(context, hidden_state, decoder_input)
            p_atten = torch.zeros(attn_weights.shape[0], len(input2index)).to(device)
            p_atten.scatter_add_(1, input_tensor, attn_weights)
            p_w = p_gen * p_vocab + (1 - p_gen) * p_atten[:, 1:char_vocab_size]
            decoder_input = Embedder(p_w.argmax(dim=1) + 1)
            outputs.append(p_w)
            if attn_debug:
                attn_weights_sequence.append(attn_weights)
                p_gen_seq.append(p_gen)

        if attn_debug:
            attn_weights_sequence = torch.stack(attn_weights_sequence, dim=1)
            attn_weights_all.append(attn_weights_sequence)
            p_gen_all.append(torch.cat(p_gen_seq, dim=1))
        output_indices.append(torch.stack(outputs).argmax(dim=2))
        inflected_forms_true += inflected_forms

    output_indices = torch.cat(output_indices, dim=1).transpose(0, 1).cpu().numpy()
    for indices in output_indices:
        inflected_predicted.append(''.join([index2input[index + 1] for index in indices]).split(STOP_CHAR)[0])

    if attn_debug:
        max_src_len = max([x.shape[2] for x in attn_weights_all])
        for i in range(len(attn_weights_all)):
            attn_weights = attn_weights_all[i]
            batch_size = attn_weights.shape[0]
            src_len = attn_weights.shape[2]
            attn_weights_all[i] = torch.zeros(batch_size, max_pred_len, max_src_len)
            attn_weights_all[i][:,:,:src_len] = attn_weights
        attn_weights_all = torch.cat(attn_weights_all, dim=0)
        p_gen_all = torch.cat(p_gen_all, dim=0)
        return inflected_predicted, input_seq, attn_weights_all, p_gen_all
    else:
        return inflected_predicted, inflected_forms_true

# %%
def train(lemmas_train, tags_train, inflected_forms_train, epochs=1):
    start_time = time.time()
    
    for epoch in range(epochs):

        epoch_loss = 0

        for batch in grouper(zip(lemmas_train, tags_train, inflected_forms_train), batch_size):
            batch = list(filter(lambda x: x is not None, batch))
            lemmas, tags, inflected_forms = zip(*batch)


            lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
            tags_indices = tag_to_indices(tags, input2index)    
            inflected_forms_indices = words_to_indices(inflected_forms, input2index)
            input_indices = merge_lists(lemmas_indices, tags_indices)

            # Sort by length of input sequence
            input_indices, inflected_forms_indices = zip(*sorted(zip(input_indices, inflected_forms_indices), key=lambda x: len(x[0]), reverse=True))
            input_indices = [torch.tensor(lst) for lst in input_indices]

            optimiser.zero_grad()

            input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
            embedding = Embedder(input_tensor)
            lengths = [Tensor.shape[0] for Tensor in input_indices]
            packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
            encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
            encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]

            input_mask = input_tensor == 0
            # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 

            # Decode
            hidden_state = hidden[0,:,:] + hidden[1,:,:]
            hidden_state = hidden_state.unsqueeze(0)
            cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

            target = pad_lists([lst + [input2index[STOP_CHAR]] for lst in inflected_forms_indices], input2index[PAD_CHAR]).to(device)    
            target = target - 1

            decoder_input = pad_lists(inflected_forms_indices, input2index[PAD_CHAR]).to(device)
            decoder_input = torch.cat([torch.tensor([input2index[START_CHAR]] * len(lengths)).unsqueeze(1).to(device), decoder_input], dim=1)
            decoder_input = Embedder(decoder_input)

            loss = 0

            max_length = target.shape[1]
            for seq in range(0, max_length):
                attn_weights = attention(encoded_input, hidden_state, input_mask)
                context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

                decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input[:,seq,:].unsqueeze(1)], dim=2)

                output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
                p_vocab = F.relu(linear_vocab(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))
                p_vocab = F.softmax(p_vocab.squeeze(), dim=1)

                p_gen = generation_prob(context, hidden_state, decoder_input[:,seq,:])
                p_atten = torch.zeros(attn_weights.shape[0], len(input2index)).to(device)
                p_atten.scatter_add_(1, input_tensor, attn_weights)
                p_w = p_gen * p_vocab + (1 - p_gen) * p_atten[:, 1:char_vocab_size]

                p_w = torch.log(p_w)
                loss += criterion(p_w, target[:,seq])

                epoch_loss += loss.item()
            loss.backward()
            optimiser.step()
        print("Epoch: {}/{}\tTime: {:.2f}s\tLoss: {:.4f}\tAccuracy: {:.4f}\tDistance: {:.4f} ".format(epoch+1, epochs, time.time() - start_time, epoch_loss / len(lemmas_train), *evaluate(*test(lemmas_val, tags_val, inflected_forms_val))))

# %%
optimiser = optim.Adagrad(params, lr=0.1)

# %%
# %prun train(lemmas_train, tags_train, inflected_forms_train, epochs=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1/50	Time: 16.64s	Loss: 14.5957	Accuracy: 0.0000	Distance: 12.7390
# Epoch: 2/50	Time: 35.58s	Loss: 13.8855	Accuracy: 0.0000	Distance: 17.2985
# Epoch: 3/50	Time: 54.31s	Loss: 13.6634	Accuracy: 0.0000	Distance: 16.7880
# Epoch: 4/50	Time: 73.19s	Loss: 13.4057	Accuracy: 0.0000	Distance: 19.1180
# Epoch: 5/50	Time: 92.14s	Loss: 13.1169	Accuracy: 0.0000	Distance: 20.7965
# Epoch: 6/50	Time: 111.04s	Loss: 12.9084	Accuracy: 0.0000	Distance: 21.7560
# Epoch: 7/50	Time: 129.62s	Loss: 12.8018	Accuracy: 0.0000	Distance: 21.1950
# Epoch: 8/50	Time: 148.41s	Loss: 12.7310	Accuracy: 0.0000	Distance: 21.3260
# Epoch: 9/50	Time: 167.23s	Loss: 12.6687	Accuracy: 0.0000	Distance: 20.6375
# Epoch: 10/50	Time: 185.90s	Loss: 12.5775	Accuracy: 0.0000	Distance: 20.2160
# Epoch: 11/50	Time: 204.67s	Loss: 12.5116	Accuracy: 0.0000	Distance: 18.8285
# Epoch: 12/50	Time: 223.43s	Loss: 12.4269	Accuracy: 0.0000	Distance: 19.6920
# Epoch: 13/50	Time: 242.21s	Loss: 12.4159	Accuracy: 0.0000	Distance: 19.8855
# Epoch: 14/50	Time: 261.01s	Loss: 12.3729	Accuracy: 0.0000	Distance: 18.4350
# Epoch: 15/50	Time: 279.80s	Loss: 12.3264	Accuracy: 0.0000	Distance: 17.8750
# Epoch: 16/50	Time: 298.59s	Loss: 12.2996	Accuracy: 0.0000	Distance: 17.8235
# Epoch: 17/50	Time: 317.33s	Loss: 12.2882	Accuracy: 0.0000	Distance: 17.6640
# Epoch: 18/50	Time: 336.12s	Loss: 12.2757	Accuracy: 0.0000	Distance: 17.2950
# Epoch: 19/50	Time: 354.86s	Loss: 12.2526	Accuracy: 0.0000	Distance: 17.1170
# Epoch: 20/50	Time: 373.61s	Loss: 12.2271	Accuracy: 0.0000	Distance: 16.7610
# Epoch: 21/50	Time: 392.48s	Loss: 12.2547	Accuracy: 0.0000	Distance: 17.4850
# Epoch: 22/50	Time: 411.20s	Loss: 12.2328	Accuracy: 0.0000	Distance: 16.6645
# Epoch: 23/50	Time: 429.95s	Loss: 12.2462	Accuracy: 0.0000	Distance: 16.7500
# Epoch: 24/50	Time: 448.87s	Loss: 12.2277	Accuracy: 0.0000	Distance: 16.7530
# Epoch: 25/50	Time: 467.76s	Loss: 12.2567	Accuracy: 0.0000	Distance: 17.4500
# Epoch: 26/50	Time: 486.63s	Loss: 12.2960	Accuracy: 0.0000	Distance: 14.1500
# Epoch: 27/50	Time: 505.51s	Loss: 12.2380	Accuracy: 0.0000	Distance: 14.2775
# Epoch: 28/50	Time: 524.37s	Loss: 12.1945	Accuracy: 0.0000	Distance: 14.1130
# Epoch: 29/50	Time: 543.45s	Loss: 12.1372	Accuracy: 0.0000	Distance: 14.5345
# Epoch: 30/50	Time: 562.31s	Loss: 12.1362	Accuracy: 0.0000	Distance: 15.8540
# Epoch: 31/50	Time: 581.18s	Loss: 12.0567	Accuracy: 0.0000	Distance: 13.2550
# Epoch: 32/50	Time: 600.05s	Loss: 12.0116	Accuracy: 0.0000	Distance: 13.0630
# Epoch: 33/50	Time: 618.96s	Loss: 12.0274	Accuracy: 0.0000	Distance: 15.2060
# Epoch: 34/50	Time: 637.85s	Loss: 12.0242	Accuracy: 0.0000	Distance: 14.9385
# Epoch: 35/50	Time: 656.66s	Loss: 12.0119	Accuracy: 0.0000	Distance: 14.7895
# Epoch: 36/50	Time: 675.62s	Loss: 12.0087	Accuracy: 0.0000	Distance: 14.6810
# Epoch: 37/50	Time: 694.49s	Loss: 12.0166	Accuracy: 0.0000	Distance: 14.1425
# Epoch: 38/50	Time: 713.53s	Loss: 12.0117	Accuracy: 0.0000	Distance: 13.7605
# Epoch: 39/50	Time: 732.53s	Loss: 12.0132	Accuracy: 0.0000	Distance: 13.6090
# Epoch: 40/50	Time: 751.37s	Loss: 12.0215	Accuracy: 0.0000	Distance: 13.9525
# Epoch: 41/50	Time: 770.16s	Loss: 11.9942	Accuracy: 0.0000	Distance: 14.6240
# Epoch: 42/50	Time: 788.94s	Loss: 11.9903	Accuracy: 0.0000	Distance: 13.9715
# Epoch: 43/50	Time: 807.89s	Loss: 11.9857	Accuracy: 0.0000	Distance: 12.1575
# Epoch: 44/50	Time: 826.89s	Loss: 11.9866	Accuracy: 0.0000	Distance: 13.6580
# Epoch: 45/50	Time: 845.88s	Loss: 11.9798	Accuracy: 0.0000	Distance: 12.7550
# Epoch: 46/50	Time: 864.89s	Loss: 11.9742	Accuracy: 0.0000	Distance: 13.2775
# Epoch: 47/50	Time: 883.92s	Loss: 11.9643	Accuracy: 0.0000	Distance: 13.1220
# Epoch: 48/50	Time: 902.97s	Loss: 11.9576	Accuracy: 0.0000	Distance: 13.2700
# Epoch: 49/50	Time: 921.92s	Loss: 11.9534	Accuracy: 0.0000	Distance: 13.2400
# Epoch: 50/50	Time: 940.93s	Loss: 11.9497	Accuracy: 0.0000	Distance: 13.5315

# %%
optimiser = optim.Adagrad(params, lr=0.01)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1/30	Time: 16.17s	Loss: 11.9899	Accuracy: 0.0000	Distance: 13.5740
# Epoch: 2/30	Time: 34.56s	Loss: 11.9382	Accuracy: 0.0000	Distance: 13.2590
# Epoch: 3/30	Time: 52.93s	Loss: 11.9349	Accuracy: 0.0000	Distance: 13.0410
# Epoch: 4/30	Time: 71.16s	Loss: 11.9377	Accuracy: 0.0000	Distance: 13.0575
# Epoch: 5/30	Time: 89.43s	Loss: 11.9283	Accuracy: 0.0000	Distance: 13.0115
# Epoch: 6/30	Time: 107.73s	Loss: 11.9314	Accuracy: 0.0000	Distance: 13.5965
# Epoch: 7/30	Time: 125.95s	Loss: 11.9341	Accuracy: 0.0000	Distance: 12.8995
# Epoch: 8/30	Time: 144.26s	Loss: 11.9303	Accuracy: 0.0000	Distance: 12.9055
# Epoch: 9/30	Time: 162.65s	Loss: 11.9297	Accuracy: 0.0000	Distance: 13.2690
# Epoch: 10/30	Time: 180.99s	Loss: 11.9307	Accuracy: 0.0000	Distance: 13.1035
# Epoch: 11/30	Time: 199.32s	Loss: 11.9325	Accuracy: 0.0000	Distance: 13.1335
# Epoch: 12/30	Time: 217.65s	Loss: 11.9293	Accuracy: 0.0000	Distance: 13.2650
# Epoch: 13/30	Time: 235.89s	Loss: 11.9288	Accuracy: 0.0000	Distance: 13.2315
# Epoch: 14/30	Time: 254.18s	Loss: 11.9261	Accuracy: 0.0000	Distance: 13.1695
# Epoch: 15/30	Time: 272.58s	Loss: 11.9283	Accuracy: 0.0000	Distance: 13.4065
# Epoch: 16/30	Time: 290.92s	Loss: 11.9278	Accuracy: 0.0000	Distance: 13.4860
# Epoch: 17/30	Time: 309.10s	Loss: 11.9237	Accuracy: 0.0000	Distance: 12.9905
# Epoch: 18/30	Time: 327.33s	Loss: 11.9317	Accuracy: 0.0000	Distance: 13.3350
# Epoch: 19/30	Time: 345.63s	Loss: 11.9325	Accuracy: 0.0000	Distance: 12.9200
# Epoch: 20/30	Time: 363.97s	Loss: 11.9298	Accuracy: 0.0000	Distance: 12.9490
# Epoch: 21/30	Time: 382.19s	Loss: 11.9227	Accuracy: 0.0000	Distance: 13.0700
# Epoch: 22/30	Time: 400.52s	Loss: 11.9248	Accuracy: 0.0000	Distance: 12.9280
# Epoch: 23/30	Time: 418.71s	Loss: 11.9235	Accuracy: 0.0000	Distance: 12.9550
# Epoch: 24/30	Time: 436.89s	Loss: 11.9229	Accuracy: 0.0000	Distance: 12.9585
# Epoch: 25/30	Time: 455.16s	Loss: 11.9219	Accuracy: 0.0000	Distance: 13.0965
# Epoch: 26/30	Time: 473.50s	Loss: 11.9229	Accuracy: 0.0000	Distance: 12.9720
# Epoch: 27/30	Time: 491.72s	Loss: 11.9272	Accuracy: 0.0000	Distance: 12.8895
# Epoch: 28/30	Time: 509.98s	Loss: 11.9244	Accuracy: 0.0000	Distance: 13.0325
# Epoch: 29/30	Time: 528.25s	Loss: 11.9217	Accuracy: 0.0000	Distance: 12.8595
# Epoch: 30/30	Time: 546.53s	Loss: 11.9196	Accuracy: 0.0000	Distance: 13.0660

# %%
optimiser = optim.Adagrad(params, lr=0.01)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1/50	Time: 16.16s	Loss: 11.9580	Accuracy: 0.0000	Distance: 13.3305
# Epoch: 2/50	Time: 34.35s	Loss: 11.9596	Accuracy: 0.0000	Distance: 13.2535
# Epoch: 3/50	Time: 52.72s	Loss: 11.9609	Accuracy: 0.0000	Distance: 13.3145
# Epoch: 4/50	Time: 71.13s	Loss: 11.9617	Accuracy: 0.0000	Distance: 13.2490
# Epoch: 5/50	Time: 89.43s	Loss: 11.9596	Accuracy: 0.0000	Distance: 13.2190
# Epoch: 6/50	Time: 107.80s	Loss: 11.9578	Accuracy: 0.0000	Distance: 13.1185
# Epoch: 7/50	Time: 126.09s	Loss: 11.9569	Accuracy: 0.0000	Distance: 13.4665
# Epoch: 8/50	Time: 144.38s	Loss: 11.9554	Accuracy: 0.0000	Distance: 13.3335
# Epoch: 9/50	Time: 162.66s	Loss: 11.9560	Accuracy: 0.0000	Distance: 13.4140
# Epoch: 10/50	Time: 180.98s	Loss: 11.9548	Accuracy: 0.0000	Distance: 13.3595
# Epoch: 11/50	Time: 199.27s	Loss: 11.9554	Accuracy: 0.0000	Distance: 13.3915
# Epoch: 12/50	Time: 217.62s	Loss: 11.9545	Accuracy: 0.0000	Distance: 13.4610
# Epoch: 13/50	Time: 235.91s	Loss: 11.9527	Accuracy: 0.0000	Distance: 13.4385
# Epoch: 14/50	Time: 254.23s	Loss: 11.9539	Accuracy: 0.0000	Distance: 13.4960
# Epoch: 15/50	Time: 272.51s	Loss: 11.9558	Accuracy: 0.0000	Distance: 13.4165
# Epoch: 16/50	Time: 290.90s	Loss: 11.9595	Accuracy: 0.0000	Distance: 13.5815
# Epoch: 17/50	Time: 309.07s	Loss: 11.9577	Accuracy: 0.0000	Distance: 13.6810
# Epoch: 18/50	Time: 327.41s	Loss: 11.9569	Accuracy: 0.0000	Distance: 13.7045
# Epoch: 19/50	Time: 345.68s	Loss: 11.9598	Accuracy: 0.0000	Distance: 13.8290
# Epoch: 20/50	Time: 363.94s	Loss: 11.9598	Accuracy: 0.0000	Distance: 13.6780
# Epoch: 21/50	Time: 382.27s	Loss: 11.9637	Accuracy: 0.0000	Distance: 13.8535
# Epoch: 22/50	Time: 400.63s	Loss: 11.9660	Accuracy: 0.0000	Distance: 14.1570
# Epoch: 23/50	Time: 419.01s	Loss: 11.9666	Accuracy: 0.0000	Distance: 13.9985
# Epoch: 24/50	Time: 437.47s	Loss: 11.9611	Accuracy: 0.0000	Distance: 13.9505
# Epoch: 25/50	Time: 455.79s	Loss: 11.9638	Accuracy: 0.0000	Distance: 14.0195
# Epoch: 26/50	Time: 474.18s	Loss: 11.9612	Accuracy: 0.0000	Distance: 14.0485
# Epoch: 27/50	Time: 492.53s	Loss: 11.9615	Accuracy: 0.0000	Distance: 14.0335
# Epoch: 28/50	Time: 510.95s	Loss: 11.9627	Accuracy: 0.0000	Distance: 13.8965
# Epoch: 29/50	Time: 529.14s	Loss: 11.9622	Accuracy: 0.0000	Distance: 13.8415
# Epoch: 30/50	Time: 547.58s	Loss: 11.9649	Accuracy: 0.0000	Distance: 14.1565
# Epoch: 31/50	Time: 565.93s	Loss: 11.9680	Accuracy: 0.0000	Distance: 14.2850
# Epoch: 32/50	Time: 584.16s	Loss: 11.9641	Accuracy: 0.0000	Distance: 14.4090
# Epoch: 33/50	Time: 602.51s	Loss: 11.9641	Accuracy: 0.0000	Distance: 14.5205
# Epoch: 34/50	Time: 620.99s	Loss: 11.9710	Accuracy: 0.0000	Distance: 14.7295
# Epoch: 35/50	Time: 639.38s	Loss: 11.9721	Accuracy: 0.0000	Distance: 14.5280
# Epoch: 36/50	Time: 657.73s	Loss: 11.9729	Accuracy: 0.0000	Distance: 14.5525
# Epoch: 37/50	Time: 676.03s	Loss: 11.9701	Accuracy: 0.0000	Distance: 14.4095
# Epoch: 38/50	Time: 694.45s	Loss: 11.9705	Accuracy: 0.0000	Distance: 14.0600
# Epoch: 39/50	Time: 712.72s	Loss: 11.9686	Accuracy: 0.0000	Distance: 14.0975
# Epoch: 40/50	Time: 731.05s	Loss: 11.9696	Accuracy: 0.0000	Distance: 14.0465
# Epoch: 41/50	Time: 749.43s	Loss: 11.9705	Accuracy: 0.0000	Distance: 14.1485
# Epoch: 42/50	Time: 767.70s	Loss: 11.9710	Accuracy: 0.0000	Distance: 13.9915
# Epoch: 43/50	Time: 786.03s	Loss: 11.9697	Accuracy: 0.0000	Distance: 13.9855
# Epoch: 44/50	Time: 804.33s	Loss: 11.9701	Accuracy: 0.0000	Distance: 14.1195
# Epoch: 45/50	Time: 822.61s	Loss: 11.9721	Accuracy: 0.0000	Distance: 14.1010
# Epoch: 46/50	Time: 840.90s	Loss: 11.9707	Accuracy: 0.0000	Distance: 14.2105
# Epoch: 47/50	Time: 859.24s	Loss: 11.9739	Accuracy: 0.0000	Distance: 14.1420
# Epoch: 48/50	Time: 877.61s	Loss: 11.9761	Accuracy: 0.0000	Distance: 14.2235
# Epoch: 49/50	Time: 895.87s	Loss: 11.9755	Accuracy: 0.0000	Distance: 14.0755
# Epoch: 50/50	Time: 914.28s	Loss: 11.9756	Accuracy: 0.0000	Distance: 14.1925

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train accuracy: (0.0, 14.392875) Validation accuracy:  (0.0, 14.1925)

# %% [markdown]
# ### Development Dataset

# %%
lemmas_dev, tags_dev, inflected_forms_dev = load_data('./conll2018/task1/all/{}-dev'.format(language))

# %%
evaluate(*test(lemmas_dev, tags_dev, inflected_forms_dev))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# (0.0, 14.3528)

# %%
for prediction, truth in zip(*test(lemmas_dev, tags_dev, inflected_forms_dev)):
    if prediction != truth:
        print("Prediction: {}\tTruth: {}".format(prediction, truth))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Prediction: nee	Truth: desrisastes
# Prediction: oonoaent	Truth: proffiterions
# Prediction: esentesre	Truth: estoffassiez
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: surnommera
# Prediction: o	Truth: subiecteront
# Prediction: eoeleeeeeeeeeeeeeeeeeeeee	Truth: impugneront
# Prediction: orran	Truth: branslerions
# Prediction: nio	Truth: deslyast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pastureryez
# Prediction: ei	Truth: gaboient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esleves
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: enortes
# Prediction: eseentrentrentrentrentren	Truth: guarde
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: meslast
# Prediction: niez	Truth: flatterons
# Prediction: eesences	Truth: destablant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estourdir
# Prediction: eso	Truth: en esprouvant
# Prediction: esceeeeeeeeeeeeeeeeeeeeee	Truth: garde
# Prediction: eisen	Truth: aymerent
# Prediction: 	Truth: ayderont
# Prediction: e	Truth: guide
# Prediction: s	Truth: vont
# Prediction: eesent	Truth: eu
# Prediction: enes	Truth: entredemandoyent
# Prediction: oiieent	Truth: r'asseurions
# Prediction: escnescnescnescnescnescne	Truth: destourneray
# Prediction: esent	Truth: esloignasses
# Prediction: es	Truth: estudiyez
# Prediction: ne	Truth: engendrast
# Prediction: ese	Truth: accordoys
# Prediction: esentone	Truth: eslevois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: monstrassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desancreroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mortifiez
# Prediction: eesent	Truth: expellasmes
# Prediction: esentone	Truth: temprois
# Prediction: nesentea	Truth: desroberois
# Prediction: niez	Truth: baptizerons
# Prediction: ese	Truth: ployoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rouillez
# Prediction: e	Truth: depesche
# Prediction: ooooooooooooooooooooooooo	Truth: grappa
# Prediction: esoeios	Truth: en approuchant
# Prediction: eesieent	Truth: dançoys
# Prediction: eesences	Truth: tourmentant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aguyses
# Prediction: easeentsentsentsentsentse	Truth: guardez
# Prediction: esent	Truth: operassions
# Prediction: oonnoanease	Truth: faucerions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: vollerois
# Prediction: esentrents	Truth: passe
# Prediction: s	Truth: iolyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tyrassions
# Prediction: esiosnois	Truth: iolyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: oste
# Prediction: eesier	Truth: r'asseuriez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: souspira
# Prediction: etessent	Truth: confessasses
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gaspilleray
# Prediction: eesiose	Truth: eschappa
# Prediction: eesiosieroolloi	Truth: esguisions
# Prediction: nites	Truth: declairast
# Prediction: ese	Truth: invadois
# Prediction: oounoients	Truth: desrouteroyt
# Prediction: eeesenceronl	Truth: regretterons
# Prediction: edededededededededededede	Truth: infourmons
# Prediction: esent	Truth: tournois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escartent
# Prediction: io	Truth: inviterai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: devoureryez
# Prediction: oeoeoeoeoeosessens	Truth: desnoueryez
# Prediction: eesent	Truth: deffiassions
# Prediction: netaenesentseiessose	Truth: humilieroient
# Prediction: se	Truth: urinois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: verifierois
# Prediction: ononoioieente	Truth: toquoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estimez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mocques
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: effreons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: armoierois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pilla
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: leschons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: adaptons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esbaucher
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ferois
# Prediction: e	Truth: sois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: lurré
# Prediction: esene	Truth: enpoisonneriez
# Prediction: esencesencesencesencesenc	Truth: empoizonneryons
# Prediction: encys	Truth: espoventeray
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: accoustument
# Prediction: eeseent	Truth: cabassoyt
# Prediction: esencoree	Truth: recupererent
# Prediction: eese	Truth: esventoyent
# Prediction: esieztrsent	Truth: desployas
# Prediction: sueseenceeseseseseseseses	Truth: eschapperez
# Prediction: oeoeoeoeoeoeoeoeoeoeoeoeo	Truth: protestez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: baptisa
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deschireriez
# Prediction: ent	Truth: enferrassent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: fromente
# Prediction: e	Truth: enconcherois
# Prediction: estes	Truth: ronflyez
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: buchas
# Prediction: sue	Truth: empenseriez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: reiecte
# Prediction: ese	Truth: iettoyent
# Prediction: eseent	Truth: gardois
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: meritast
# Prediction: ele	Truth: soingneroit
# Prediction: ese	Truth: guidoyent
# Prediction: esentesre	Truth: cachassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nommeray
# Prediction: soe	Truth: heurteryez
# Prediction: esent	Truth: faisoyent
# Prediction: esentsentsentsentsentsent	Truth: gelleroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cessons
# Prediction: esent	Truth: alassions
# Prediction: eesences	Truth: trompant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: accoustumeray
# Prediction: e	Truth: conseillassions
# Prediction: eeesenceesenceesere	Truth: courouchierez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: praesentez
# Prediction: eneesentesre	Truth: surnommassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: empensassent
# Prediction: eesent	Truth: escoutasmes
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: soumecte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: espargnons
# Prediction: escoteosessresents	Truth: remercye
# Prediction: oreeeeeeeeeeeeeeeeeeeeeee	Truth: baptizerent
# Prediction: eesent	Truth: cerchassions
# Prediction: esesesssenceronononononon	Truth: bobelinerons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: soumectons
# Prediction: eesent	Truth: appellasmes
# Prediction: ese	Truth: heiloyent
# Prediction: eseient	Truth: soubhaitté
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nombrassent
# Prediction: esentrentrentrentrentrent	Truth: delivre
# Prediction: esent	Truth: tournasses
# Prediction: se	Truth: resides
# Prediction: suere	Truth: armoieriez
# Prediction: esesesesesesesesesesesese	Truth: soupperiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: soucyez
# Prediction: eesnez	Truth: en tesmoignant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: luitteras
# Prediction: eesentsentsentse	Truth: nommasse
# Prediction: oeeeeeeeeeeeeeeeeeeeeeeee	Truth: ieuneroyent
# Prediction: se	Truth: toqueroys
# Prediction: ooesse	Truth: hacherons
# Prediction: eesent	Truth: mortifié
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: aquitter
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: contrepoisoit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enconvenence
# Prediction: ese	Truth: traveilloys
# Prediction: esesentesrre	Truth: courouchassiez
# Prediction: esent	Truth: seiournoyt
# Prediction: ni	Truth: destournast
# Prediction: ese	Truth: bancqueta
# Prediction: ese	Truth: courrouça
# Prediction: sue	Truth: pourpense
# Prediction: eseoessents	Truth: contribueroys
# Prediction: esesesesesesesesesesesese	Truth: reiectassions
# Prediction: ose	Truth: trouvoys
# Prediction: ooonoas	Truth: destableroys
# Prediction: se	Truth: allaicteroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esprouveroys
# Prediction: o	Truth: mercyerai
# Prediction: eisen	Truth: arriverent
# Prediction: ne	Truth: arresterons
# Prediction: eesieses	Truth: deifias
# Prediction: eesecesepnio	Truth: volloyt
# Prediction: esent	Truth: escumassent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estachent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: arroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: arroieryez
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: operast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: retyreroys
# Prediction: eesconez	Truth: courrouçant
# Prediction: ese	Truth: mesla
# Prediction: senssenssents	Truth: opereroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: meslons
# Prediction: ne	Truth: declairé
# Prediction: ooooooooooooooooooooooooo	Truth: huasses
# Prediction: eesences	Truth: deshonnourasses
# Prediction: ei	Truth: esparpilloient
# Prediction: esentse	Truth: despucellasse
# Prediction: ese	Truth: desbaratoys
# Prediction: esecesecesecesecesecesece	Truth: contregarderiez
# Prediction: ese	Truth: fourageoys
# Prediction: eoea	Truth: aboschions
# Prediction: esent	Truth: fourageassent
# Prediction: eseseent	Truth: picquoys
# Prediction: esent	Truth: protestassent
# Prediction: e	Truth: confesseras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: verifia
# Prediction: se	Truth: iniurieryons
# Prediction: se	Truth: navroient
# Prediction: escnescnescnescnescnescne	Truth: invaderay
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: arresterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: asseures
# Prediction: s	Truth: recorderont
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: excusez
# Prediction: esenteise	Truth: pacques
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: veigleroit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: affamez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: lascheras
# Prediction: essentes	Truth: en sollicitant
# Prediction: s	Truth: guerpissent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: maschons
# Prediction: esenttreoeilllasenttreoei	Truth: ieune
# Prediction: eesent	Truth: fluismes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pense
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: houons
# Prediction: ess	Truth: en supposant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: donner
# Prediction: esec	Truth: contregardoyent
# Prediction: eeseseseseseseseseseseses	Truth: coniecturoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: conseilloys
# Prediction: esent	Truth: contribuasmes
# Prediction: ent	Truth: enclinois
# Prediction: eesent	Truth: desmontassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esplucha
# Prediction: ese	Truth: desistoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: participerois
# Prediction: eesient	Truth: mocquoit
# Prediction: esieses	Truth: escappas
# Prediction: nnesent	Truth: enhortast
# Prediction: estes	Truth: escriiez
# Prediction: esceseentse	Truth: celebre
# Prediction: s	Truth: arrestent
# Prediction: escones	Truth: plaiderai
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: escheverois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desbordons
# Prediction: eeseent	Truth: lurroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: negotieryons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desmeleriez
# Prediction: enele	Truth: vengiera
# Prediction: eescniez	Truth: bancquetant
# Prediction: eesieses	Truth: desvas
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ottroyez
# Prediction: sesesesssssssssssssssssss	Truth: buchieriez
# Prediction: ooooooooooooooooooooooooo	Truth: pochasses
# Prediction: ese	Truth: jecte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: perseras
# Prediction: e	Truth: reside
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: tyrast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: preteryez
# Prediction: eesesentse	Truth: communicquasse
# Prediction: encs	Truth: contrerollera
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: contregardes
# Prediction: ese	Truth: enpoisonna
# Prediction: eient	Truth: encommenceriez
# Prediction: ee	Truth: desarmiez
# Prediction: n	Truth: desbarateront
# Prediction: ee	Truth: acceptiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: quittoit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: abhorra
# Prediction: escones	Truth: essilieray
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: destache
# Prediction: e	Truth: seiourne
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: eschapperoit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tabustes
# Prediction: eesieenteses	Truth: nommiez
# Prediction: nesesente	Truth: detesterois
# Prediction: esent	Truth: chantassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: bucha
# Prediction: esentesre	Truth: prestassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desmele
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desmelent
# Prediction: oooesse	Truth: marcherons
# Prediction: 	Truth: advoueront
# Prediction: eiez	Truth: estoffez
# Prediction: e	Truth: herrie
# Prediction: soeoeoeoeosessrrn	Truth: poiseroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: bayseroyent
# Prediction: oonononononononononononon	Truth: poiserons
# Prediction: eesent	Truth: pasturé
# Prediction: soeeeeeeeeeeeeeeeeeeeeeee	Truth: plieryez
# Prediction: tesenconetsenescheerorree	Truth: tyrer
# Prediction: eesient	Truth: courrouchierent
# Prediction: e	Truth: approuvendasses
# Prediction: eneschrsre	Truth: endommaige
# Prediction: eueis	Truth: pourpensassiez
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: persuadast
# Prediction: eesent	Truth: desancrassions
# Prediction: eie	Truth: consydereryez
# Prediction: e	Truth: transporte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: suffocqueryons
# Prediction: e	Truth: seiourneray
# Prediction: esesesesesesesesesesesese	Truth: escappassent
# Prediction: esent	Truth: trempois
# Prediction: eoesessses	Truth: chocquasses
# Prediction: esene	Truth: condescendre
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: affermassions
# Prediction: reronses	Truth: debaraçons
# Prediction: esci	Truth: aboscheray
# Prediction: s	Truth: bransleroys
# Prediction: se	Truth: mouscheriez
# Prediction: eseieentesrre	Truth: bruslassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estirez
# Prediction: esenceesenceesenceesencee	Truth: deffierez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gousteras
# Prediction: eseieenteueoeoeeeeeeeeeee	Truth: mescleroys
# Prediction: eeseent	Truth: plioyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: parleroys
# Prediction: eoeosessreonos	Truth: espieroyt
# Prediction: ooeeoeeeeeeeeeeeeeeeeeeee	Truth: passez
# Prediction: ei	Truth: lyoient
# Prediction: sose	Truth: affieryons
# Prediction: nises	Truth: donné
# Prediction: eesences	Truth: faisant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: recommanderas
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: transportes
# Prediction: sene	Truth: representeriez
# Prediction: esent	Truth: esperonna
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: accoustumeroys
# Prediction: es	Truth: rappellyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: persuaderois
# Prediction: esieses	Truth: estoffas
# Prediction: ooeeeeeeeeeeeeeeeeeeeeeee	Truth: praeparerions
# Prediction: eesioise	Truth: abboyions
# Prediction: siezenis	Truth: laidengent
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: tocquassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: renommeroys
# Prediction: suenene	Truth: acquiteriez
# Prediction: eesieses	Truth: scellas
# Prediction: eese	Truth: baisa
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enhorte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: adviserois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deifie
# Prediction: esent	Truth: passassent
# Prediction: ooooooooooooooooooooooooo	Truth: deffieroyt
# Prediction: escron	Truth: meslerai
# Prediction: eesences	Truth: merveillant
# Prediction: es	Truth: aydyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aornes
# Prediction: se	Truth: monteront
# Prediction: s	Truth: ieunent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ploye
# Prediction: se	Truth: gaberoys
# Prediction: senssenssentea	Truth: ayderoit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: atacher
# Prediction: esessents	Truth: alé
# Prediction: eesionnses	Truth: tesmoignois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: communicquerois
# Prediction: oesonssent	Truth: desprisonnerons
# Prediction: es	Truth: redrechyez
# Prediction: enes	Truth: representerent
# Prediction: ese	Truth: possessoyent
# Prediction: ooooooooooooooooooooooooo	Truth: despucelleroys
# Prediction: esencoree	Truth: esperonnerent
# Prediction: es	Truth: verifiyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deslogeoit
# Prediction: e	Truth: conseillons
# Prediction: escesces	Truth: cabasserai
# Prediction: eseh	Truth: alteroyent
# Prediction: s	Truth: hebergieront
# Prediction: eesent	Truth: monstrast
# Prediction: escor	Truth: branslerai
# Prediction: eesieent	Truth: mangeoient
# Prediction: esents	Truth: escarte
# Prediction: nnesenttreosenttreosenttr	Truth: enferre
# Prediction: eoeoeosoioooooooooooooooo	Truth: iniuriez
# Prediction: esiesses	Truth: estacheroient
# Prediction: 	Truth: marcheront
# Prediction: soeoeoeoeoeoeoeoeoeoeoeoe	Truth: baysast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mesclez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: edifiez
# Prediction: esioses	Truth: affient
# Prediction: eseent	Truth: pliassions
# Prediction: s	Truth: frapent
# Prediction: 	Truth: delivrer
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tyre
# Prediction: eesoe	Truth: moderant
# Prediction: tesencrteionsuesesesenctt	Truth: celer
# Prediction: ese	Truth: descouchoys
# Prediction: eesieent	Truth: eschappions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tourmentes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: prattiques
# Prediction: ooeeeeeeeeeeeeeeeeeeeeeee	Truth: merveillerions
# Prediction: ssooooooooooonses	Truth: pourforce
# Prediction: eesieenteses	Truth: rebarbiez
# Prediction: oiis	Truth: tocquoient
# Prediction: neeeeeeeeeeeeeeeeeeeeeeee	Truth: querelasmes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: revencheroyent
# Prediction: escher	Truth: empesche
# Prediction: esene	Truth: possesseryez
# Prediction: se	Truth: avanches
# Prediction: encs	Truth: creance
# Prediction: oons	Truth: evaporerons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: songeois
# Prediction: sse	Truth: plaidasse
# Prediction: ese	Truth: cachoyent
# Prediction: esieceeeeeeeeeeeeeeeeeeee	Truth: esvante
# Prediction: esentrentstersre	Truth: devoure
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rouillons
# Prediction: tseceeeeeeeeeeeeeeeeeeeee	Truth: chargeryons
# Prediction: one	Truth: houyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: laisses
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: fauçast
# Prediction: ese	Truth: alosa
# Prediction: onssents	Truth: enorteroyt
# Prediction: e	Truth: pacqueront
# Prediction: ts	Truth: erige
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desirez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: guiderois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: lascher
# Prediction: oonoys	Truth: courouchoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tesmoignerai
# Prediction: oento	Truth: effrontoys
# Prediction: esentrentrentrentrentrent	Truth: acoustume
# Prediction: ese	Truth: desborda
# Prediction: eesent	Truth: esloignast
# Prediction: esionois	Truth: desadvoueroient
# Prediction: eisen	Truth: commencerent
# Prediction: nee	Truth: cerchiez
# Prediction: ese	Truth: expuysoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: combinois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: emboucherois
# Prediction: eesieses	Truth: raportas
# Prediction: esentesresentesresentesre	Truth: desrobassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rappelleras
# Prediction: niez	Truth: picquierons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: amadoue
# Prediction: eoesentess	Truth: exposasses
# Prediction: sne	Truth: enferreront
# Prediction: ese	Truth: hachoyent
# Prediction: esentrentsent	Truth: marche
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: saulvons
# Prediction: 	Truth: brusleront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: danceray
# Prediction: eesent	Truth: vuidasmes
# Prediction: esenceesche	Truth: demande
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: volle
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pisses
# Prediction: sse	Truth: haste
# Prediction: ronpiez	Truth: ausons
# Prediction: rsoessensensensensensense	Truth: aeres
# Prediction: soeln	Truth: aguysé
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: contrepoisons
# Prediction: ocsnons	Truth: contrerollerions
# Prediction: escescttes	Truth: desbaucherai
# Prediction: esent	Truth: retournois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: practicquons
# Prediction: es	Truth: preparyez
# Prediction: eeseseseseseseseseseseses	Truth: estoffyons
# Prediction: e	Truth: bransloient
# Prediction: eesieent	Truth: preparoit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deschaines
# Prediction: ent	Truth: revenchassent
# Prediction: onone	Truth: enterryons
# Prediction: siezeneseienesesesesesese	Truth: gaimentons
# Prediction: ne	Truth: protesterons
# Prediction: sueteneesent	Truth: emboucherez
# Prediction: oeiioeiioeiioeiioeiioeiio	Truth: desancrerions
# Prediction: eesies	Truth: reiectastes
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: escumoys
# Prediction: esencoree	Truth: espouserent
# Prediction: ee	Truth: gastiez
# Prediction: esentrare	Truth: cabasse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: detestes
# Prediction: sse	Truth: queste
# Prediction: ooooooooooooooooooooooooo	Truth: affamez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: apatissions
# Prediction: se	Truth: pilleroys
# Prediction: s	Truth: bastent
# Prediction: oureeeeeeeeeeeeeeeeeeeeee	Truth: gelleroient
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: jecteroit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: iecte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: baysez
# Prediction: tesencrnepiez	Truth: fiancer
# Prediction: esec	Truth: houssepille
# Prediction: ese	Truth: desbauchoys
# Prediction: e	Truth: enseignerai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: chevauchieryons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: allaictyons
# Prediction: esiose	Truth: estonnions
# Prediction: esencoree	Truth: possesserent
# Prediction: eese	Truth: avanchasses
# Prediction: esetessetessetessetessete	Truth: esclairasse
# Prediction: eesesesesesns	Truth: buchyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desieune
# Prediction: ese	Truth: recordassent
# Prediction: esent	Truth: arroioyent
# Prediction: esceie	Truth: presumerai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desgorgent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escappes
# Prediction: s	Truth: verifient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rouillerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: resisterez
# Prediction: esentsentse	Truth: vollasse
# Prediction: esent	Truth: tumbassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: advises
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pechons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: iolyes
# Prediction: eesieses	Truth: pesas
# Prediction: sesses	Truth: hasteroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aereras
# Prediction: enescheronrsoeeeeeeeeeeee	Truth: nommons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mulctant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: muçons
# Prediction: tstettetstetstotttttttttt	Truth: en evitant
# Prediction: esteronsesrrrrnleersester	Truth: en alant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: communicquois
# Prediction: eesionsentes	Truth: entreruynyez
# Prediction: ooooooooooooooooooooooooo	Truth: interpreteroys
# Prediction: neesnonse	Truth: entrefaisiez
# Prediction: estes	Truth: estoffois
# Prediction: se	Truth: gaspilleroys
# Prediction: e	Truth: sollicite
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: iniuriast
# Prediction: eesiose	Truth: arresta
# Prediction: enceeeeeeeeeeeeeeeeeeeeee	Truth: presenteras
# Prediction: osois	Truth: desploies
# Prediction: oueoeeeeeeeeeeeeeeeeeeeee	Truth: cachions
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enchargez
# Prediction: enescherossehents	Truth: enhorteroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: trampa
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cerche
# Prediction: ooooooooooooooooooooooooo	Truth: affermerions
# Prediction: se	Truth: essilieroyt
# Prediction: ooiis	Truth: rebarberions
# Prediction: es	Truth: cryyez
# Prediction: eesent	Truth: notoyt
# Prediction: esentrentrentrentrentrent	Truth: empire
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mescleryez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: operes
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: cache
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: eussions
# Prediction: eseceeeeeeeeeeeeeeeeeeeee	Truth: alloit
# Prediction: reer	Truth: desancrant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: porte
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escorner
# Prediction: ronl	Truth: en esgarant
# Prediction: soorreeeeeeeeeeeeeeeeeeee	Truth: baislé
# Prediction: on	Truth: s'entredemanderoient
# Prediction: ent	Truth: revenchoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: subiugua
# Prediction: e	Truth: seiournyons
# Prediction: eesieenteses	Truth: embouchiez
# Prediction: setaeea	Truth: esclaires
# Prediction: ese	Truth: reculla
# Prediction: es	Truth: mesclyez
# Prediction: treeeeeeeeeeeeeeeeeeeeeee	Truth: effronteryons
# Prediction: ooeeoeoeoeoeoeoeoeoeoeoeo	Truth: praesidez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gouvernons
# Prediction: ese	Truth: leschoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deslogent
# Prediction: ooooooooooooooooooooooooo	Truth: desferoyt
# Prediction: ei	Truth: pensyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esternuons
# Prediction: esent	Truth: galopasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desgorgez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: sceut
# Prediction: sonoane	Truth: impugneroyt
# Prediction: eie	Truth: pensoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: atournerois
# Prediction: eoeseent	Truth: misses
# Prediction: se	Truth: ieusneriez
# Prediction: eiesesess	Truth: pensa
# Prediction: ooooooooooooooooooooooooo	Truth: edifierions
# Prediction: esent	Truth: esvantons
# Prediction: encsencsencsencsencsencse	Truth: proffitant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: guerpissez
# Prediction: ooooooooooooooooooooooooo	Truth: robbez
# Prediction: soonse	Truth: yrions
# Prediction: eesesns	Truth: operé
# Prediction: esent	Truth: contregardasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: contregarde
# Prediction: ese	Truth: eschappois
# Prediction: esent	Truth: enfelonnasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: chevauchieryez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: translaterai
# Prediction: ee	Truth: desploiiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: suffocquez
# Prediction: ese	Truth: possessasse
# Prediction: eesieses	Truth: esternuas
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: ottroyast
# Prediction: onesseene	Truth: estourdiroient
# Prediction: ese	Truth: fiançoyent
# Prediction: iea	Truth: fomenterai
# Prediction: se	Truth: infourmeriez
# Prediction: ese	Truth: essilassiez
# Prediction: ceeeeeeeeeeeeeeeeeeeeeeee	Truth: desrobbes
# Prediction: esent	Truth: affioys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: arrestent
# Prediction: eese	Truth: urinoys
# Prediction: soeoeoeoeoeoeoeoeoeoeoeoe	Truth: amadoueriez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ymagine
# Prediction: treseoeoeoeoeoeoeoeoeoeoe	Truth: foetteroient
# Prediction: niezeuereeeeeeeeeeeeeeeee	Truth: meriterez
# Prediction: esent	Truth: cachassent
# Prediction: se	Truth: appuieriez
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: commençant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: frappez
# Prediction: eesent	Truth: raporté
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aornez
# Prediction: o	Truth: yroient
# Prediction: eesoea	Truth: iouant
# Prediction: e	Truth: merveillyons
# Prediction: senssenssens	Truth: s'entreruyneront
# Prediction: esent	Truth: supersedassent
# Prediction: ee	Truth: escornoient
# Prediction: ses	Truth: avanchastes
# Prediction: n	Truth: enchassastes
# Prediction: eiesent	Truth: commençasmes
# Prediction: eesent	Truth: atemptoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: soulaigeras
# Prediction: eesenconses	Truth: resignasmes
# Prediction: esent	Truth: temprois
# Prediction: se	Truth: fortifieroys
# Prediction: eeseseseseseseseseseseses	Truth: flottyons
# Prediction: oes	Truth: supposerent
# Prediction: esent	Truth: seelloys
# Prediction: ne	Truth: monstrerons
# Prediction: ne	Truth: accepterons
# Prediction: enescnaea	Truth: desinfectant
# Prediction: eesieneesenceesenceesence	Truth: precederez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aboscherois
# Prediction: ese	Truth: abayoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ymagineras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: atemptes
# Prediction: esesenconstreoesessns	Truth: intoxiquer
# Prediction: e	Truth: flattent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: effreerois
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: excuserois
# Prediction: sse	Truth: trampe
# Prediction: eoeneeeeeeeeeeeeeeeeeeeee	Truth: invitez
# Prediction: eoeletsesrrsorononononono	Truth: en iniuriant
# Prediction: tseneseoeeeeeeeeeeeeeeeee	Truth: matter
# Prediction: eesrrrsenrsenrsenrsenrnes	Truth: tyrant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esmerveille
# Prediction: ese	Truth: suffocquoyent
# Prediction: esent	Truth: sollicitoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deschainoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: s'entrehurtent
# Prediction: e	Truth: conseilleryez
# Prediction: s	Truth: acoustument
# Prediction: enesns	Truth: entrempesché
# Prediction: s	Truth: atemptyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desancre
# Prediction: tsenrentesnzonnez	Truth: en desprisonnant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: honnoureroit
# Prediction: enescraesent	Truth: enchargions
# Prediction: enescheronses	Truth: espoventons
# Prediction: oceeeeeeeeeeeeeeeeeeeeeee	Truth: esvantasmes
# Prediction: oononer	Truth: desrisierons
# Prediction: e	Truth: prepareroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: eschevons
# Prediction: eoesessrrrrrrre	Truth: baislasses
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: reiecteryez
# Prediction: esieneeeeeeeeeeeeeeeeeeee	Truth: trampent
# Prediction: ooonoas	Truth: veilleroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escryeras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: oublyerois
# Prediction: ese	Truth: oublyeriez
# Prediction: s	Truth: guardent
# Prediction: 	Truth: desancrer
# Prediction: esene	Truth: ruynez
# Prediction: eesieenteses	Truth: oziez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ayons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tumbons
# Prediction: eeseieent	Truth: macté
# Prediction: esentrentrentrentrentrent	Truth: recommande
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desbordoit
# Prediction: ones	Truth: executoys
# Prediction: ese	Truth: baptisois
# Prediction: nesenceseenteoeoeeeeeeeee	Truth: desadvouerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: subiuguions
# Prediction: ese	Truth: goustois
# Prediction: esene	Truth: conquestez
# Prediction: eesie	Truth: estiriez
# Prediction: rerononononononononononon	Truth: desploions
# Prediction: eaeeeeeeeeeeeeeeeeeeeeeee	Truth: gaimenterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: depescheryez
# Prediction: nee	Truth: detestastes
# Prediction: eseoeseossentes	Truth: branslast
# Prediction: esent	Truth: separasses
# Prediction: eesieenteses	Truth: gettiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: reiecte
# Prediction: esesesesesesesesesesesese	Truth: frappassent
# Prediction: e	Truth: renflastes
# Prediction: ese	Truth: modera
# Prediction: e	Truth: ottroyeroient
# Prediction: esent	Truth: escriassent
# Prediction: eleeeeeeeeeeeeeeeeeeeeeee	Truth: soingneras
# Prediction: o	Truth: veiglerai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: trouva
# Prediction: esents	Truth: tourneroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: fleschissions
# Prediction: eesieenteses	Truth: tiriez
# Prediction: s	Truth: possede
# Prediction: sesses	Truth: oublyera
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: enorteryez
# Prediction: senesencesencesencesences	Truth: rengeryons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: contrepoisa
# Prediction: oereeeeeeeeeeeeeeeeeeeeee	Truth: communicquerions
# Prediction: e	Truth: transgloutis
# Prediction: eneesentesronsentessonsen	Truth: vous entrehurtassiez
# Prediction: eesieentesentesentesentes	Truth: redoubtiez
# Prediction: esentesresentesresentesre	Truth: supersedassiez
# Prediction: eesent	Truth: exploroyt
# Prediction: eesesesesnsent	Truth: galopoyt
# Prediction: nio	Truth: desyryons
# Prediction: nites	Truth: depescheroit
# Prediction: ese	Truth: coustoys
# Prediction: ese	Truth: blessois
# Prediction: oeoeoeoeoeoeoeoeoeoeoeoeo	Truth: nettoya
# Prediction: enenescheronses	Truth: presentent
# Prediction: oolla	Truth: reguarderions
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: laschas
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: chanterai
# Prediction: oonoaeoeoeoeoeoeoeoeoeoeo	Truth: desroberoyt
# Prediction: nesenconts	Truth: coniures
# Prediction: escescs	Truth: picque
# Prediction: ese	Truth: passois
# Prediction: ouooooooooooooooooooooooo	Truth: hostoieroyent
# Prediction: eisient	Truth: pourpensé
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nombrez
# Prediction: esentoes	Truth: pliasmes
# Prediction: ese	Truth: lyoyent
# Prediction: ooooooooooooooooooooooooo	Truth: ietterions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pissons
# Prediction: eesent	Truth: cerchié
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tirez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: navrez
# Prediction: ooooooooooooooooooooooooo	Truth: alois
# Prediction: ese	Truth: courrouchoyent
# Prediction: e	Truth: transgloutirez
# Prediction: ooase	Truth: manouvroys
# Prediction: esent	Truth: esvertuois
# Prediction: sse	Truth: prattiquasse
# Prediction: esent	Truth: courrouçassions
# Prediction: eseent	Truth: asseurois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rappellassions
# Prediction: es	Truth: regardyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: descharge
# Prediction: se	Truth: maschoient
# Prediction: eesec	Truth: nombroyent
# Prediction: ese	Truth: leichoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: recuperez
# Prediction: eieeee	Truth: apuyoient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: separasmes
# Prediction: encs	Truth: enterre
# Prediction: sens	Truth: eslanceriez
# Prediction: e	Truth: tranche
# Prediction: esent	Truth: mettoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: lascherois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nombres
# Prediction: esesesesessense	Truth: galoperyez
# Prediction: e	Truth: pausmeront
# Prediction: soooooooooooooooooooooooo	Truth: portast
# Prediction: oreeeeeeeeeeeeeeeeeeeeeee	Truth: bayserent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mectes
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: venge
# Prediction: soelent	Truth: guideriez
# Prediction: ele	Truth: finirois
# Prediction: enteeillosleesrooonsestes	Truth: en luittant
# Prediction: eesconez	Truth: saluant
# Prediction: ent	Truth: enconvenença
# Prediction: oonoientes	Truth: courrouchoys
# Prediction: eesent	Truth: raenchonnassions
# Prediction: esenceeeeeeeeeeeeeeeeeeee	Truth: condescent
# Prediction: ese	Truth: recouvrois
# Prediction: eesenceesenceesenceesence	Truth: esgratignerez
# Prediction: seents	Truth: importuneroys
# Prediction: orreeeeeeeeeeeeeeeeeeeeee	Truth: desployasmes
# Prediction: enesenesenesenesenesenese	Truth: enterrassions
# Prediction: neneseseseseseseseseseses	Truth: traittions
# Prediction: esessentrersre	Truth: exstirpe
# Prediction: esesesssenceronononononon	Truth: redoubterons
# Prediction: ieessentoeea	Truth: desancre
# Prediction: esieses	Truth: tranchas
# Prediction: esensenconses	Truth: advanceroyent
# Prediction: eesieses	Truth: grappas
# Prediction: esene	Truth: esprouvez
# Prediction: oese	Truth: fomentes
# Prediction: ose	Truth: vuidois
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: creance
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: delivreryez
# Prediction: esene	Truth: pausmeroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: dampne
# Prediction: esio	Truth: desyreroient
# Prediction: s	Truth: accuseront
# Prediction: sensse	Truth: galoperont
# Prediction: eseieentesraessoonses	Truth: mactassiez
# Prediction: 	Truth: revereryez
# Prediction: enesencesenesenesenconses	Truth: enortez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: scelle
# Prediction: sentsresentsresentsresent	Truth: baislera
# Prediction: e	Truth: mectroient
# Prediction: eneesentesronsentesscones	Truth: vous entredemandassiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: houssepilles
# Prediction: one	Truth: supersedions
# Prediction: eesient	Truth: descouchierent
# Prediction: ne	Truth: desieunyons
# Prediction: ooooooooooooooooooooooooo	Truth: esveilloys
# Prediction: ei	Truth: empeschoient
# Prediction: esentrentsei	Truth: desbauche
# Prediction: escher	Truth: debaracerai
# Prediction: esenttne	Truth: importunerois
# Prediction: eesent	Truth: esternuast
# Prediction: niereeessnio	Truth: consyderes
# Prediction: eesient	Truth: desgorgerent
# Prediction: e	Truth: esquacheroient
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: souspirerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esveilleras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esternuent
# Prediction: s	Truth: recouvreront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escapperois
# Prediction: esencoree	Truth: escumerent
# Prediction: orre	Truth: alongea
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: trompa
# Prediction: onone	Truth: guidyons
# Prediction: se	Truth: lascheriez
# Prediction: resns	Truth: saluasmes
# Prediction: ese	Truth: muçoyent
# Prediction: ei	Truth: iouoient
# Prediction: ooooooooooooooooooooooooo	Truth: seelleroys
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: assiste
# Prediction: niez	Truth: preterons
# Prediction: esencesenteoeoeeeeeeeeeee	Truth: ruynerois
# Prediction: teueoeeeeeeeeeeeeeeeeeeee	Truth: iecter
# Prediction: e	Truth: practicqueroient
# Prediction: ee	Truth: depeschiez
# Prediction: eills	Truth: considerasse
# Prediction: eesesesesns	Truth: recuperyons
# Prediction: ese	Truth: seiournoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mortifiassions
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: subiuguieroit
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desheritent
# Prediction: ese	Truth: arrestoyent
# Prediction: ese	Truth: abhorroys
# Prediction: orr	Truth: effronterai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: descouchiez
# Prediction: nee	Truth: arrestastes
# Prediction: ose	Truth: riffloys
# Prediction: eleeeeeeeeeeeeeeeeeeeeeee	Truth: soingneroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: espousons
# Prediction: enesencsenesene	Truth: penetreroient
# Prediction: seents	Truth: arresteroyt
# Prediction: esene	Truth: retournez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: foullez
# Prediction: escotes	Truth: soucye
# Prediction: oea	Truth: nouoyt
# Prediction: eesientes	Truth: notois
# Prediction: senssenssenssenssenssenss	Truth: porteroys
# Prediction: enteu	Truth: en estouffant
# Prediction: eesose	Truth: aloserons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: iolyeroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mangeroys
# Prediction: eoellzeea	Truth: en esveiglant
# Prediction: esent	Truth: capasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gaberyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: loueryez
# Prediction: enease	Truth: enconvenencierions
# Prediction: eesieent	Truth: embouchoit
# Prediction: es	Truth: esguaryez
# Prediction: ese	Truth: eslançois
# Prediction: escescher	Truth: destacherai
# Prediction: easessens	Truth: cauterizerez
# Prediction: 	Truth: alimenteront
# Prediction: nio	Truth: accordast
# Prediction: ss	Truth: oublyois
# Prediction: eteillos	Truth: conferment
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: embausmons
# Prediction: se	Truth: arrengieriez
# Prediction: enesences	Truth: seiournez
# Prediction: ese	Truth: obligeois
# Prediction: esent	Truth: soucyassent
# Prediction: ene	Truth: enhorterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estachera
# Prediction: escnescnescnescnescnescne	Truth: ronfleray
# Prediction: ese	Truth: obligeassiez
# Prediction: 	Truth: achapteront
# Prediction: ooooooooooooooooooooooooo	Truth: vuidois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: divinerois
# Prediction: ooooooooooooooooooooooooo	Truth: affamerez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: occurrez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: residera
# Prediction: esencesencesencesencesenc	Truth: invadons
# Prediction: esente	Truth: quittes
# Prediction: ese	Truth: affia
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: sembleroys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: armoient
# Prediction: tnzonnessesse	Truth: tournoyer
# Prediction: ooane	Truth: aurez
# Prediction: escher	Truth: contregarderay
# Prediction: eseent	Truth: esparpilloys
# Prediction: es	Truth: remerquyez
# Prediction: eese	Truth: blasphema
# Prediction: nio	Truth: desrobbions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: participa
# Prediction: es	Truth: praesidyez
# Prediction: ese	Truth: subiugeoys
# Prediction: e	Truth: cauterizeront
# Prediction: t	Truth: enchasseroient
# Prediction: tse	Truth: desrouteryons
# Prediction: e	Truth: escielle
# Prediction: siezeeeeeeeeeeeeeeeeeeeee	Truth: laidenge
# Prediction: eese	Truth: haitta
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cabasseryez
# Prediction: ronsnes	Truth: expellons
# Prediction: s	Truth: estacheront
# Prediction: eesesesesns	Truth: aornyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: verifiera
# Prediction: ooooooooonses	Truth: raporterions
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: entredonner
# Prediction: nises	Truth: descouchié
# Prediction: e	Truth: esguiseroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: iectoit
# Prediction: esent	Truth: retyrassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: essaye
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: accusez
# Prediction: 	Truth: fascheront
# Prediction: oueoeeeeeeeeeeeeeeeeeeeee	Truth: separeroyent
# Prediction: ooooooooooooooooooooooooo	Truth: altererions
# Prediction: eese	Truth: ozoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: salues
# Prediction: ent	Truth: endommaigeoyt
# Prediction: esene	Truth: contrepoiseroyent
# Prediction: eesent	Truth: desroutoyt
# Prediction: esent	Truth: fortiffiassent
# Prediction: escher	Truth: importuneray
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: provocqua
# Prediction: eseses	Truth: preparois
# Prediction: ese	Truth: eslançois
# Prediction: eesient	Truth: expuyserent
# Prediction: esene	Truth: racointeroyent
# Prediction: eesies	Truth: rebarbastes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: effectues
# Prediction: eoeases	Truth: manouvrera
# Prediction: eesiose	Truth: comptions
# Prediction: ooooooooooooooooooooooooo	Truth: desrobberoyt
# Prediction: oueea	Truth: empenserai
# Prediction: ese	Truth: espouseryons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: haittes
# Prediction: esent	Truth: cerchassent
# Prediction: s	Truth: bruslent
# Prediction: soes	Truth: hastassions
# Prediction: se	Truth: mocqueryons
# Prediction: esencons	Truth: conquester
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mocque
# Prediction: ne	Truth: ployerons
# Prediction: onnsse	Truth: rincez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: guideras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: en honnourant
# Prediction: esentesronese	Truth: ostassiez
# Prediction: sonoleeeeeeeeeeeeeeeeeeee	Truth: paye
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ordonner
# Prediction: eeesi	Truth: note
# Prediction: e	Truth: approuvendois
# Prediction: ese	Truth: traveilloys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: enpoisonnoyent
# Prediction: eoesssons	Truth: interpretasses
# Prediction: s	Truth: transgloutissent
# Prediction: esent	Truth: bobelinoyt
# Prediction: esent	Truth: suffocquasses
# Prediction: niez	Truth: arrengeastes
# Prediction: esent	Truth: respiroys
# Prediction: esene	Truth: courroucez
# Prediction: oueoeeeeeeeeeeeeeeeeeeeee	Truth: marchions
# Prediction: eleeeeeeeeeeeeeeeeeeeeeee	Truth: besoigneras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: racomptez
# Prediction: e	Truth: enconcheryez
# Prediction: eesieses	Truth: alongeas
# Prediction: ooooooooooooooooooooooooo	Truth: goustas
# Prediction: eseieneeseieneeseieneesei	Truth: traitterez
# Prediction: ese	Truth: deifia
# Prediction: enesenconses	Truth: vengeasmes
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: cerchieroit
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: alterast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: respirerois
# Prediction: ei	Truth: marioient
# Prediction: rerer	Truth: seellons
# Prediction: encses	Truth: engroissant
# Prediction: ooeeeeeeeeeeeeeeeeeeeeeee	Truth: alosez
# Prediction: eesec	Truth: allaictant
# Prediction: eeeesi	Truth: ieune
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nouons
# Prediction: esenceescheo	Truth: ruyne
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: poisons
# Prediction: esnsensensensensensensens	Truth: dampnant
# Prediction: o	Truth: desconseilleroyt
# Prediction: esec	Truth: contregarderont
# Prediction: nis	Truth: consyderast
# Prediction: enesenesencesenesenesenes	Truth: vous entrefrapez
# Prediction: eesese	Truth: combinoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: importuneras
# Prediction: eesieses	Truth: escartas
# Prediction: ese	Truth: acquita
# Prediction: esencesesenteions	Truth: cointoierois
# Prediction: eese	Truth: pastura
# Prediction: soeoeeeeeeeeeeeeeeeeeeeee	Truth: esbaucheryons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desplaceras
# Prediction: oonio	Truth: escumions
# Prediction: ooooooooooooooooooooooooo	Truth: picquas
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escheves
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: humilions
# Prediction: e	Truth: demoureroyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aguyseray
# Prediction: eesieent	Truth: meslions
# Prediction: eesesesesns	Truth: raliyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: visiteroyent
# Prediction: oonio	Truth: aerions
# Prediction: s	Truth: moderent
# Prediction: spezeueeeeeeeeeeeeeeeeeee	Truth: scelleriez
# Prediction: esentesressentesresentesr	Truth: pesassiez
# Prediction: nis	Truth: desveroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: urine
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: resvent
# Prediction: ooonses	Truth: pochez
# Prediction: ronpionpasoeoea	Truth: huons
# Prediction: s	Truth: lyeront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tirez
# Prediction: e	Truth: desconseilloys
# Prediction: esencs	Truth: contrepoiseront
# Prediction: nio	Truth: depeschyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pourforça
# Prediction: escnescnescnescnescnescne	Truth: r'asseureray
# Prediction: oea	Truth: gouverneroyent
# Prediction: sene	Truth: remercyes
# Prediction: oeeeeeeeeeeeeeeeeeeeeeeee	Truth: desieunerions
# Prediction: ese	Truth: regarda
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: regretteryons
# Prediction: eesies	Truth: blessastes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: empiegent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: reiectez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estachez
# Prediction: eeesins	Truth: honnoure
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: precede
# Prediction: nesencesentes	Truth: demanderois
# Prediction: ourononononononononononon	Truth: ottroyerez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: employons
# Prediction: eoeosessesses	Truth: luitteroyt
# Prediction: esent	Truth: atournons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: faschent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: arrestez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: picqueroys
# Prediction: e	Truth: mesleroyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cesseroys
# Prediction: se	Truth: ieuneroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: exstirper
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aie
# Prediction: eesentsent	Truth: essilié
# Prediction: esesessses	Truth: preparé
# Prediction: tesent	Truth: aurois
# Prediction: se	Truth: melancholieryons
# Prediction: enteses	Truth: revenchyez
# Prediction: sue	Truth: pourpensasse
# Prediction: enteses	Truth: surnommyez
# Prediction: esconses	Truth: enpoisonneras
# Prediction: ei	Truth: desrobboient
# Prediction: esesesesesesesesesesesese	Truth: praeparassions
# Prediction: esencesencesencesencesenc	Truth: esperonneryons
# Prediction: ent	Truth: creançois
# Prediction: eoesessesses	Truth: hebergeasses
# Prediction: oosses	Truth: prattiquez
# Prediction: ei	Truth: desroboient
# Prediction: onuoeeent	Truth: enclinions
# Prediction: r	Truth: desroberai
# Prediction: e	Truth: escorcheroient
# Prediction: noi	Truth: tranches
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: supposes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: monstres
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escumeroys
# Prediction: teoeosoeoeoeoeoeoeoeoeoeo	Truth: foetteryez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: occupe
# Prediction: se	Truth: montasse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gasteray
# Prediction: e	Truth: hucheroient
# Prediction: nenesesesi	Truth: cuydons
# Prediction: eoesesssentessent	Truth: aydasses
# Prediction: estes	Truth: tuyez
# Prediction: tstet	Truth: evite
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: veiglons
# Prediction: oeeeeeeeeeeeeeeeeeeeeeeee	Truth: disnez
# Prediction: eeescheerrzou	Truth: empensant
# Prediction: eesent	Truth: gousté
# Prediction: esene	Truth: condescendriez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desancroys
# Prediction: sse	Truth: abhorrois
# Prediction: ooueeeeeeeeeeeeeeeeeeeeee	Truth: acoustumerions
# ...
# Prediction: esesessentse	Truth: rappellasse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: suffocquera
# Prediction: ocseoeseoeseoessoonseosso	Truth: contribuerions
# Prediction: ese	Truth: delaçois
# Prediction: niereeessnions	Truth: consideres
# Prediction: esent	Truth: delaissassent
# Prediction: eesieenteses	Truth: advouiez
# Prediction: esietentes	Truth: desregles
# Prediction: esieztree	Truth: amadouas
# Prediction: sse	Truth: luittois
# Prediction: ese	Truth: raportasses
# Prediction: eesientes	Truth: heurtiez
# Prediction: ent	Truth: enyvroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: bastyons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: revenchez
# Prediction: ese	Truth: occupasse
# Prediction: ooueoeoeoeoeoeoeoeoeoeoeo	Truth: cousteroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tramperoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: trouve
# Prediction: o	Truth: abiureroyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: houa
# Prediction: neeeeeeeeeeeeeeeeeeeeeeee	Truth: besoinger
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mectrions
# Prediction: eesent	Truth: monstré
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: songe
# Prediction: eoeletsentonses	Truth: en seellant
# Prediction: es	Truth: desprisonnoient
# Prediction: e	Truth: desconseillons
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: melancholierois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: nous entredonnons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: engendroit
# Prediction: ese	Truth: racomptoyent
# Prediction: eseent	Truth: estourdissoys
# Prediction: eesesessse	Truth: arrengeasse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: translateroient
# Prediction: ese	Truth: supposoyent
# Prediction: esent	Truth: empruntassent
# Prediction: ooooooooooooooooooooooooo	Truth: desfaisois
# Prediction: eneschasse	Truth: enchargeroys
# Prediction: ooooooooooooooooooooooooo	Truth: tabusta
# Prediction: ei	Truth: meritoient
# Prediction: ei	Truth: souppoient
# Prediction: esesesse	Truth: escappasse
# Prediction: esceeeeeeeeeeeeeeeeeeeeee	Truth: pastureray
# Prediction: enceeeeeeeeeeeeeeeeeeeeee	Truth: esventeras
# Prediction: ooooooooooooooooooooooooo	Truth: marioys
# Prediction: sentoaea	Truth: essayasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: espargnons
# Prediction: ese	Truth: reigla
# Prediction: reeeeeeeeeeeeeeeeeeeeeeee	Truth: delivre
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: montois
# Prediction: eesent	Truth: portoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: atempterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: couste
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: navrerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: celeray
# Prediction: niez	Truth: huerons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: fumons
# Prediction: e	Truth: desinfectyez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: deshonnoureras
# Prediction: ee	Truth: declairiez
# Prediction: eesent	Truth: deschargeassions
# Prediction: eesieses	Truth: remonstras
# Prediction: escnescnescnescnescnescne	Truth: enfelonneray
# Prediction: rnoients	Truth: encommence
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: approuchions
# Prediction: es	Truth: arrestyez
# Prediction: es	Truth: accusyez
# Prediction: se	Truth: adiousteroit
# Prediction: eesicotes	Truth: reveroit
# Prediction: eesent	Truth: operoyt
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: celebreroit
# Prediction: se	Truth: esguareroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: eschevera
# Prediction: esenconstres	Truth: fiancerent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: picquierois
# Prediction: nites	Truth: empirast
# Prediction: eesioise	Truth: vollions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: baisleray
# Prediction: esent	Truth: couchasmes
# Prediction: ooooooooooooooooooooooooo	Truth: aboschez
# Prediction: ese	Truth: cessoyent
# Prediction: esientrersre	Truth: esgare
# Prediction: se	Truth: invaderoys
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: avallerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aymyons
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: herrieroit
# Prediction: e	Truth: opereront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: finissent
# Prediction: senssetes	Truth: tyreroyt
# Prediction: nites	Truth: courouchast
# Prediction: esent	Truth: souspiroys
# Prediction: esent	Truth: mortifiassent
# Prediction: eesesesesesns	Truth: escoutyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: praesenteront
# Prediction: eesieent	Truth: scellions
# Prediction: oueeeeeeeeeeeeeeeeeeeeeee	Truth: soumectrez
# Prediction: e	Truth: seiourneryons
# Prediction: esent	Truth: esperoyent
# Prediction: enesencs	Truth: revenchez
# Prediction: s	Truth: gaspillent
# Prediction: sse	Truth: atournasse
# Prediction: nesenconses	Truth: effrontes
# Prediction: eesent	Truth: estudiassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mensongiez
# Prediction: ei	Truth: advisoient
# Prediction: niezeneeeeeeeeeeeeeeeeeee	Truth: estoufferyons
# Prediction: eesent	Truth: ottroyasmes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: racompterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: delaçons
# Prediction: nee	Truth: arroiastes
# Prediction: nee	Truth: trempastes
# Prediction: ese	Truth: escrya
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: precederoit
# Prediction: enesent	Truth: entrefait
# Prediction: es	Truth: cachyez
# Prediction: eoeosenteroeosenteroeosen	Truth: modereroys
# Prediction: esenttrleersenttrleersent	Truth: tourne
# Prediction: treesnezt	Truth: en effrontant
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: levez
# Prediction: se	Truth: ames
# Prediction: eosteo	Truth: reverant
# Prediction: enesesesesesesesesesesese	Truth: enconvenenciez
# Prediction: esent	Truth: raenchonna
# Prediction: ese	Truth: accointoys
# Prediction: eieeeeeeeeeeeeeeeeeeeeeee	Truth: laidengyons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: represente
# Prediction: eesent	Truth: haittoyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desieunassent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pourforceroys
# Prediction: ss	Truth: picquasse
# Prediction: ne	Truth: cointoieroyent
# Prediction: rrseenceseentts	Truth: encharge
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: provocquons
# Prediction: sesesses	Truth: traittieroys
# Prediction: ei	Truth: baptiserent
# Prediction: esencoree	Truth: estacherent
# Prediction: eese	Truth: jectoyt
# Prediction: ooronoaionoaionoaionoaion	Truth: employeroyt
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: accordez
# Prediction: eesent	Truth: couchassions
# Prediction: escnescnescnescnescnescne	Truth: plaideray
# Prediction: esios	Truth: deslogeroient
# Prediction: eeseseseseseseseseseseses	Truth: aboscherons
# Prediction: ese	Truth: mascha
# Prediction: tesnotes	Truth: fortiffier
# Prediction: soeoeoeoeoeoeoeoeoeoeoeoe	Truth: abboyerez
# Prediction: treieeeeeeeeeeeeeeeeeeeee	Truth: erigeroient
# Prediction: e	Truth: altere
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aorne
# Prediction: s	Truth: pilleront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: operons
# Prediction: sonnoaio	Truth: quiteryons
# Prediction: esnsentesnez	Truth: en ruynant
# Prediction: eesent	Truth: entrencontroyent
# Prediction: eesio	Truth: renouvelliez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: prattiquassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: cauterizerois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: acoustreray
# Prediction: esent	Truth: respiroyent
# Prediction: esenceescnescnneescneescn	Truth: empoizonne
# Prediction: ene	Truth: espoventera
# Prediction: ent	Truth: creancerent
# Prediction: ese	Truth: coustoyent
# Prediction: esenconesenttre	Truth: bobelinerois
# Prediction: ooooooooooooooooooooooooo	Truth: effreoys
# Prediction: s	Truth: mortifient
# Prediction: escnses	Truth: picquieray
# Prediction: esesesesesesesesesesesese	Truth: appellassent
# Prediction: senssents	Truth: regretteroys
# Prediction: e	Truth: soulaigent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esvantons
# Prediction: oeec	Truth: baptiserons
# Prediction: esent	Truth: eslevasses
# Prediction: onessene	Truth: enterreroyent
# Prediction: ese	Truth: desyra
# Prediction: ese	Truth: fleschiroys
# Prediction: eesient	Truth: urinerent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: scelleras
# Prediction: ooueoeoeoeoeeeeeeeeeeeeee	Truth: coucheroys
# Prediction: ese	Truth: aymoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gasterois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: poches
# Prediction: e	Truth: mocque
# Prediction: ooa	Truth: vuiderions
# Prediction: enesne	Truth: executé
# Prediction: e	Truth: transporterai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: renouvellerai
# Prediction: escoeeeeeeeeeeeeeeeeeeeee	Truth: accoustumerai
# Prediction: eneesentesrre	Truth: engroissassiez
# Prediction: nee	Truth: esciellastes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esciellez
# Prediction: esesesesesesesesesesesese	Truth: desreglassiez
# Prediction: ese	Truth: supposois
# Prediction: esciuses	Truth: eschapperai
# Prediction: eesiose	Truth: escappa
# Prediction: eesio	Truth: enortoys
# Prediction: ese	Truth: subiugeassiez
# Prediction: e	Truth: renfloyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: chocqua
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: remerquez
# Prediction: ss	Truth: iolyois
# Prediction: esceiereier	Truth: tournerai
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: mesclast
# Prediction: o	Truth: foetterai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: subiuge
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pryyons
# Prediction: ese	Truth: muçois
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: frappe
# Prediction: ese	Truth: fluis
# Prediction: oon	Truth: resvez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ayda
# Prediction: neneseseseseseseseseseses	Truth: guidons
# Prediction: eesesns	Truth: escorché
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: achevons
# Prediction: e	Truth: cryeroient
# Prediction: eoent	Truth: en armoiant
# Prediction: eesent	Truth: payé
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: contrepoises
# Prediction: ooooooooooooooooooooooooo	Truth: rappellois
# Prediction: eesieent	Truth: esquachions
# Prediction: onoieenteueoeoeeeeeeeeeee	Truth: desinfecteroit
# Prediction: ese	Truth: esvertua
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: estrangleroyt
# Prediction: soises	Truth: participeryez
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: explicqueroit
# Prediction: ooooooooooooooooooooooooo	Truth: delibereroyt
# Prediction: edededededededededededede	Truth: infourment
# Prediction: eesions	Truth: desrobbera
# Prediction: 	Truth: reguardes
# Prediction: oeoeoeoeoeoeoeoeoeoeoeoeo	Truth: nettoyerions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: delacera
# Prediction: esioes	Truth: supposent
# Prediction: ne	Truth: desnoueront
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: saulta
# Prediction: ssonollsreseosessses	Truth: humilie
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: temprent
# Prediction: n	Truth: sçauront
# Prediction: nis	Truth: flottons
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: brusles
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tramperois
# Prediction: reronses	Truth: pausmons
# Prediction: e	Truth: rebarbe
# Prediction: ooa	Truth: picquez
# Prediction: tsent	Truth: erigerions
# Prediction: ennez	Truth: en proffitant
# Prediction: oreeeeeeeeeeeeeeeeeeeeeee	Truth: houerent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: ployeras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: sera
# Prediction: eesent	Truth: aymé
# Prediction: eesieses	Truth: traveillas
# Prediction: eeseseseseseseseseseseses	Truth: mehaignoyt
# Prediction: n	Truth: courouchieront
# Prediction: netases	Truth: representeroient
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: nous entrehurtons
# Prediction: onone	Truth: embausmyons
# Prediction: onsensensensensensensense	Truth: entrefraperoyent
# Prediction: resies	Truth: suffocquastes
# Prediction: eesiuoieenescneesenceesen	Truth: accoustumerez
# Prediction: etes	Truth: confermoit
# Prediction: eses	Truth: buchoyent
# Prediction: eesent	Truth: coniurassions
# Prediction: se	Truth: besoignent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: debarace
# Prediction: enenescherrsnaeeeeeeeeeee	Truth: revenchent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: hebergions
# Prediction: ee	Truth: tombiez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: preferera
# Prediction: esentesrn	Truth: exposassiez
# Prediction: nee	Truth: apuyastes
# Prediction: sents	Truth: laissera
# Prediction: ese	Truth: louoyent
# Prediction: eesent	Truth: donnassions
# Prediction: onoittrasents	Truth: essayeroient
# Prediction: oueoeleeeeeeeeeeeeeeeeeee	Truth: soupperoyent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: herriez
# Prediction: se	Truth: nombreroys
# Prediction: eesnionse	Truth: en fromentant
# Prediction: esentsentsentsentsentsent	Truth: fusse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: erigerois
# Prediction: esencoree	Truth: alerent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: resister
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: communicque
# Prediction: eesentesrre	Truth: desbaratassiez
# Prediction: nerssencses	Truth: raenchonneroient
# Prediction: ounierononos	Truth: destournerons
# Prediction: esent	Truth: retournast
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: manouvreray
# Prediction: nee	Truth: destachastes
# Prediction: esioons	Truth: contribuent
# Prediction: nt	Truth: confessast
# Prediction: eesent	Truth: escorchassions
# Prediction: e	Truth: seiourna
# Prediction: sueene	Truth: cauterizeriez
# Prediction: esent	Truth: presumassions
# Prediction: esentsentsentsentsentsent	Truth: precedasse
# Prediction: esentrentsei	Truth: regratie
# Prediction: esencses	Truth: retournera
# Prediction: es	Truth: couchyez
# Prediction: esentseieentses	Truth: quittasse
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: esguareras
# Prediction: se	Truth: mouscheroys
# Prediction: niez	Truth: devoures
# Prediction: sse	Truth: adaptassions
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: aboschent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: rengeois
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: flattas
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: accepteroit
# Prediction: eoeeeeeeeeeeeeeeeeeeeeeee	Truth: reserveroit
# Prediction: eoeoeoeoeoeoeoeoeoeoeoeoe	Truth: esgarast
# Prediction: e	Truth: humilie
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: pillent
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: mectiez
# Prediction: estieerreesnio	Truth: en ozant
# Prediction: eesicelerereeeeeeeeeeeeee	Truth: repraesentoit
# Prediction: eneeeeeeeeeeeeeeeeeeeeeee	Truth: endommaigeryez
# Prediction: enenesconesents	Truth: s'entreruynent
# Prediction: reronsnes	Truth: raenchonnons
# Prediction: escnescnescnescnescnescne	Truth: possesseray
# Prediction: ese	Truth: recordoys
# Prediction: escher	Truth: persuaderai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: gouverneroys
# Prediction: nill	Truth: esternueroyent
# Prediction: eleeeeeeeeeeeeeeeeeeeeeee	Truth: besoignerois
# Prediction: enesenesenesenesenesenese	Truth: enterrasse
# Prediction: nio	Truth: esgarions
# Prediction: eese	Truth: plaida
# Prediction: oosse	Truth: supposerions
# Prediction: eoeosessesses	Truth: estacheroys
# Prediction: esentes	Truth: delaces
# Prediction: escher	Truth: altereray
# Prediction: enesenesencesenesenesenes	Truth: enterrez
# Prediction: esec	Truth: abhorres
# Prediction: esentrents	Truth: protege
# Prediction: sse	Truth: maschasse
# Prediction: eeeseieeneseieeneseieenes	Truth: delaceriez
# Prediction: t	Truth: eviterai
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: escryent
# Prediction: suenene	Truth: heurteriez
# Prediction: eoesent	Truth: lurrasses
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: armoieras
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: goustes
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: tumbez
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: erigera
# Prediction: oose	Truth: peserons
# Prediction: soeoesesesezeeiilerererer	Truth: lyons
# Prediction: ese	Truth: presupposois
# Prediction: esent	Truth: destournassent
# Prediction: ese	Truth: fouragea
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: desadvoues
# Prediction: ne	Truth: contribueroient
# Prediction: eeeeeeeeeeeeeeeeeeeeeeeee	Truth: galopyons
# Prediction: ns	Truth: traittierons
# Prediction: eese	Truth: gastoyt
# Prediction: ese	Truth: cercha
# Prediction: oiee	Truth: toquoient
# Prediction: eseent	Truth: pissois
# Prediction: oorr	Truth: abiurez
# Prediction: e	Truth: oblige
# Prediction: sessesses	Truth: robberoys
# Prediction: esentrieentrieentrieentri	Truth: gaste
# Prediction: e	Truth: vuideront

# %% [markdown]
# ## 3.6 Experiment 4

# %% [markdown]
# ### Simple Attention over characters and tags with Attention layer trained

# %%
aligner_path = './m2m-aligner/m2m-aligner'

# %%
# %matplotlib inline

from itertools import zip_longest
import os
import pickle
import time
import subprocess

import Levenshtein
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
def load_data(file_name):
    """Loads data.

    Args:
        file_name: path to file containing the data

    Returns:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form
    """

    with open(file_name, 'r', encoding='utf') as file:
        text = file.read()

    lemmas = []
    tags = []
    inflected_forms = []

    for line in text.split('\n')[:-1]:
        lemma, inflected_form, tag = line.split('\t')
        lemmas.append(lemma)
        inflected_forms.append(inflected_form)
        tags.append(tag) 

    return lemmas, tags, inflected_forms

def get_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char, tag2index

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps character to index
        index2char: a dictionary which maps index to character
        tag2index: a ditionary which maps morphological tag to index 
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR) # special start and end symbols
    unique_chars.update(UNKNOWN_CHAR) # special charcter for unknown word
    char2index = {}
    index2char = {}

    char2index[PAD_CHAR] = 0
    index2char[0] = PAD_CHAR
    
    for index, char in enumerate(unique_chars):
        char2index[char] = index + 1
        index2char[index + 1] = char

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.update(UNKNOWN_TAG)
    tag2index = {tag:index+1 for index, tag in enumerate(unique_tags)}
    tag2index[PAD_TAG] = 0

    return char2index, index2char, tag2index

def get_combined_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps inputs and  to index
        index2char: a dictionary which maps index to inputs
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR, UNKNOWN_CHAR) # special start and end symbols  
    
    input2index = {}
    index2input = {}
    
    input2index[PAD_CHAR] = 0
    index2input[0] = PAD_CHAR
        
    for index, char in enumerate(unique_chars, start=1):
        input2index[char] = index
        index2input[index] = char
        
    char_vocab_length = len(input2index.keys())

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.add(UNKNOWN_TAG) # special character for unknown tags
    
    for index, char in enumerate(unique_tags, start=char_vocab_length):
        input2index[char] = index
        index2input[index] = char

    return input2index, index2input, char_vocab_length

def words_to_indices(words, char2index, tensor=False, start_char=False, stop_char=False):
    """Converts list of words to a list with list containing indices

    Args:
        words: list of words
        char2index: dictionary which maps character to index
        tensor: if to return a list of tensor  

    Returns:
        tensor: list of list/tensor containing indices for a sequence of characters
    """

    list_indices = []
    for word in words:
        word_indices = []
        if start_char:
            word_indices.append(char2index[START_CHAR])
        for char in word:
            if char in char2index.keys():
                word_indices.append(char2index[char])
            else:
                word_indices.append(char2index[UNKNOWN_CHAR])
        if stop_char:
            word_indices.append(char2index[STOP_CHAR])
        if tensor:
            word_indices = torch.Tensor(word_indices)
        list_indices.append(word_indices)

    return list_indices

def tag_to_vector(tags, tag2index):
    """Returns one hot representation of tags given a tag.

    Args:
        tags: list of string representation of tag (eg, V;IND;PRS;2;PL)

    Returns:
        tag_vectors: list of 1D tensors with one hot representation of tags 
    """

    tag_vectors = []
    for tag in tags:
        tag_vector = torch.zeros(len(tag2index))
        for tag_feature in tag.split(';'):
            if tag_feature in tag2index:
                tag_vector[tag2index[tag_feature]] = 1
            else:
                tag_vector[tag2index[UNKNOWN_TAG]] = 1
        tag_vectors.append(tag_vector)
    return tag_vectors

def tag_to_indices(tags, tag2index):
    """Converts list of tags to a list of lists containing indices

    Args:
        words: list of tags

    Returns:
        tensor: list of list containing indices of sub_tags
    """
    
    list_indices = []
    for tag in tags:
        tag_indices = []
        for sub_tag in tag.split(';'):
            if sub_tag in tag2index.keys():
                tag_indices.append(tag2index[sub_tag])
            else:
                tag_indices.append(tag2index[UNKNOWN_TAG])
        list_indices.append(tag_indices)

    return list_indices
    

def indices_to_word(indices, index2char):
    """Returns a word given list contaning indices of words

    Args:
        indices: list containing indices

    Returns:
        word: a string
    """

    return ''.join([index2char[index] for index in indices])[:-1]

def pad_lists(lists, pad_int, pad_len=None):
    """Pads lists in a list to make them of equal size"""
    
    if pad_len is None:
        pad_len = max([len(lst) for lst in lists])
    new_list = []
    for lst in lists:
        if len(lst) < pad_len:
            new_list.append(torch.tensor(lst + [pad_int] * (pad_len-len(lst))))
        else:
            new_list.append(torch.tensor(lst[:pad_len]))
    return torch.stack(new_list)

def merge_lists(lists1, lists2):
    """Add two list of lists."""
    
    merged_lists = []
    for list1, list2 in zip(lists1, lists2):
        merged_lists.append(list1 + list2)
    return merged_lists

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def accuracy(predictions, targets):
    correct_count = 0
    for prediction, target in zip(predictions, targets):
        if prediction == target:
            correct_count += 1
    return correct_count / len(predictions)

def average_distance(predictions, targets):
    total_distance = 0
    for prediction, target in zip(predictions, targets):
        total_distance += Levenshtein.distance(prediction, target)
    return total_distance / len(predictions)

def evaluate(predictions, targets):
    return accuracy(predictions, targets), average_distance(predictions, targets)

def showAttention(input_sentence, output_words, attentions, font=None):
        
    # Set up figure with colorbar
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions, cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    font = FontProperties(fname=font, size=24)
    ax.set_xticklabels([''] + input_sentence, rotation=90, fontproperties=font)
    ax.set_yticklabels([''] + output_words, fontproperties=font)
    ax.tick_params(axis='both', which='major', pad=15)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    
def get_alignments(lemmas, inflected_forms, tags=None, normalise=False, maxX=1):
    """Gets alignments
    
    Args:
        training_data: path to training data
    """
    
    aligner_dir = os.path.split(aligner_path)[0]
    processed_file = open(os.path.join(aligner_dir, 'processed'), 'w', encoding='utf8')

    for lemma, inflected_form in zip(lemmas, inflected_forms):
        lemma = lemma.replace(' ', '*') + STOP_CHAR
        inflected_form = inflected_form.replace(' ', '*') + STOP_CHAR
        processed_file.write(' '.join(lemma) + '\t' + ' '.join(inflected_form) + '\n')

    processed_file.close()
    
    subprocess.run(aligner_path + ' --errorInFile --delY --maxX '+ str(maxX) + ' --maxY 1 -i ./m2m-aligner/processed -o ./m2m-aligner/output', shell=True)
    
    aligner_output = open(os.path.join(aligner_dir, 'output'), 'r', encoding='utf8')
    
    alignments = []

    for i, line in enumerate(aligner_output):
        if 'NO ALIGNMENT' in line:
            if tags is not None:
                word_alignment = np.zeros((len(inflected_forms[i]) + 1, len(lemmas[i]) + 2 + len(tags[i].split(';'))))
            else:
                word_alignment = np.zeros((len(inflected_forms[i]) + 1, len(lemmas[i]) + 2))
                
            if normalise:
                word_alignment = 1 / word_alignment.shape[1]
            alignments.append(word_alignment)
            continue

        aligned_lemma, aligned_inflected_form = line.split()
        index = 1
        lemma = START_CHAR + ''.join(aligned_lemma.split('|')[:-1]).replace('_', '').replace(':', '')
        inflected_form = ''.join(aligned_inflected_form.split('|')[:-1])
        if tags is not None:
            word_alignment = np.zeros((len(inflected_form), len(lemma) + len(tags[i].split(';'))))
        else:
            word_alignment = np.zeros((len(inflected_form), len(lemma)))

        for i, (lemma_char, word_char) in enumerate(zip(aligned_lemma.split('|')[:-1], aligned_inflected_form.split('|')[:-1])):
            if ':' in lemma_char:
                chars = len(lemma_char.split(':'))
                word_alignment[i, index:(index+chars)] = 1 / chars
                index += chars
            elif lemma_char != '_':
                word_alignment[i, index] = 1
                index += 1 
            else:
                if normalise:
                    word_alignment[i, :] = 1 / word_alignment.shape[1]
        alignments.append(word_alignment)    
        
    aligner_output.close()
            
    return alignments

# %%
language = 'middle-french'
dataset = 'low'

# %%
lemmas, tags, inflected_forms = load_data('./conll2018/task1/all/{}-train-{}'.format(language, dataset))

# %%
lemmas_train,lemmas_val, tags_train, tags_val, inflected_forms_train, inflected_forms_val = train_test_split(lemmas, tags, inflected_forms, test_size=0.2, random_state=42)

# %%
# %time alignments_train = get_alignments(lemmas_train, inflected_forms_train, tags_train, normalise=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-b48febabba83> in <module>()
# ----> 1 get_ipython().magic('time alignments_train = get_alignments(lemmas_train, inflected_forms_train, tags_train, normalise=False)')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-6-43f508d3df06> in get_alignments(lemmas, inflected_forms, tags, normalise, maxX)
#     255
#     256     aligner_dir = os.path.split(aligner_path)[0]
# --> 257     processed_file = open(os.path.join(aligner_dir, 'processed'), 'w', encoding='utf8')
#     258
#     259     for lemma, inflected_form in zip(lemmas, inflected_forms):
#
# FileNotFoundError: [Errno 2] No such file or directory: './m2m-aligner/processed'

# %%
input2index, index2input, char_vocab_size = get_combined_index_dictionaries(lemmas_train, tags_train, inflected_forms_train)

# %% [markdown]
# ### Train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32
embedding_size = 300
hidden_size = 100
input_vocab_size = len(index2input.keys())

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size, p=0.3):
        # general scoring function - global attention 

        super(Attention, self).__init__()
        self.W_a = nn.Linear(2*hidden_size, hidden_size, bias=False)
        # self.dropout = nn.Dropout(p)

    def forward(self, encoded_input, hidden_state, input_mask):
        src_len = encoded_input.shape[1]
        attn_weights = torch.bmm(self.W_a(encoded_input), hidden_state.transpose(0, 1).transpose(1, 2)).squeeze()
        attn_weights.data.masked_fill_(input_mask, float('-inf'))
        # attn_weights = dropout(attn_weights)
        attn_weights = F.softmax(attn_weights, dim=1)
        return attn_weights

# %%
Embedder = nn.Embedding(input_vocab_size, embedding_size, padding_idx=input2index[PAD_CHAR]).to(device)
Encoder = nn.LSTM(embedding_size, hidden_size, batch_first=True, bidirectional=True).to(device)
attention = Attention(hidden_size).to(device)
Decoder = nn.LSTM(embedding_size + 2 * hidden_size, hidden_size, batch_first=True).to(device)
linear1 = nn.Linear(3 * hidden_size, char_vocab_size - 1, ).to(device) # remove pad character option
dropout1 = torch.nn.Dropout(p=0)
log_softmax = nn.LogSoftmax(dim=2).to(device)
# attention_criterion = nn.MSELoss(size_average=False)
attention_criterion = nn.CrossEntropyLoss(ignore_index=-1)
criterion = nn.NLLLoss(ignore_index=-1)
params = list(Embedder.parameters()) + list(Encoder.parameters()) + list(Decoder.parameters()) + list(linear1.parameters()) + list(attention.parameters())

# %%
def test(lemmas_val, tags_val, inflected_forms_val, batch_size=32, attn_debug=False, max_pred_len=25):

    inflected_predicted = []
    inflected_forms_true = []
    if attn_debug:
        input_seq = []
        attn_weights_all = []
    output_indices = []

    for batch in grouper(zip(lemmas_val, tags_val, inflected_forms_val), batch_size):
        batch = list(filter(lambda x: x is not None, batch))
        lemmas, tags, inflected_forms = zip(*batch)

        lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
        tags_indices = tag_to_indices(tags, input2index)    
        input_indices = merge_lists(lemmas_indices, tags_indices)

        # Sort by length of input sequence
        input_indices, inflected_forms = zip(*sorted(zip(input_indices, inflected_forms), key=lambda x: len(x[0]), reverse=True))        
        if attn_debug:
            input_seq += [[index2input[index] for index in input_indices1] for input_indices1 in input_indices]
        input_indices = [torch.tensor(lst) for lst in input_indices]

        input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
        embedding = Embedder(input_tensor)
        lengths = [Tensor.shape[0] for Tensor in input_indices]
        packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
        encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
        encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]
        
        input_mask = input_tensor == 0
        # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 


        # Decode
        hidden_state = hidden[0,:,:] + hidden[1,:,:]
        hidden_state = hidden_state.unsqueeze(0)
        cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

        decoder_input = torch.tensor([input2index[START_CHAR]] * len(lengths)).to(device)
        decoder_input = Embedder(decoder_input).unsqueeze(1)


        outputs = []
        attn_weights_sequence = []
        for seq in range(0, max_pred_len):
            attn_weights = attention(encoded_input, hidden_state, input_mask)
            if attn_debug:
                attn_weights_sequence.append(attn_weights)
            context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

            decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input], dim=2)

            output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
            output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))            
            decoder_input = Embedder(output.argmax(dim=2) + 1).transpose(0, 1)
            outputs.append(output.squeeze())

        if attn_debug:
            attn_weights_sequence = torch.stack(attn_weights_sequence, dim=1)
            attn_weights_all.append(attn_weights_sequence)
        output_indices.append(torch.stack(outputs).argmax(dim=2))
        inflected_forms_true += inflected_forms

    output_indices = torch.cat(output_indices, dim=1).transpose(0, 1).cpu().numpy()
    for indices in output_indices:
        inflected_predicted.append(''.join([index2input[index + 1] for index in indices]).split(STOP_CHAR)[0])
            
    if attn_debug:
        max_src_len = max([x.shape[2] for x in attn_weights_all])
        for i in range(len(attn_weights_all)):
            attn_weights = attn_weights_all[i]
            batch_size = attn_weights.shape[0]
            src_len = attn_weights.shape[2]
            attn_weights_all[i] = torch.zeros(batch_size, max_pred_len, max_src_len)
            attn_weights_all[i][:,:,:src_len] = attn_weights
        attn_weights_all = torch.cat(attn_weights_all, dim=0)
        return inflected_predicted, input_seq, attn_weights_all
    else:
        return inflected_predicted, inflected_forms_true

# %%
def train(lemmas_train, tags_train, inflected_forms_train, epochs=1, lamda=1):
    
    start_time = time.time()

    for epoch in range(epochs):

        epoch_loss = 0
        epoch_char_loss = 0
        epoch_attention_loss = 0

        for batch in grouper(zip(lemmas_train, tags_train, inflected_forms_train, alignments_train), batch_size):
            batch = list(filter(lambda x: x is not None, batch))
            lemmas, tags, inflected_forms, alignments = zip(*batch)


            lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
            tags_indices = tag_to_indices(tags, input2index)    
            inflected_forms_indices = words_to_indices(inflected_forms, input2index)
            input_indices = merge_lists(lemmas_indices, tags_indices)

            # Sort by length of input sequence
            input_indices, inflected_forms_indices, alignments = zip(*sorted(zip(input_indices, inflected_forms_indices, alignments), key=lambda x: len(x[0]), reverse=True))
            input_indices = [torch.tensor(lst) for lst in input_indices]

            optimiser.zero_grad()

            input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
            embedding = Embedder(input_tensor)
            lengths = [Tensor.shape[0] for Tensor in input_indices]
            packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
            encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
            encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]

            input_mask = input_tensor == 0
            # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 

            # Decode
            hidden_state = hidden[0,:,:] + hidden[1,:,:]
            hidden_state = hidden_state.unsqueeze(0)
            cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

            target = pad_lists([lst + [input2index[STOP_CHAR]] for lst in inflected_forms_indices], input2index[PAD_CHAR]).to(device)    
            target = target - 1

            decoder_input = pad_lists(inflected_forms_indices, input2index[PAD_CHAR]).to(device)
            decoder_input = torch.cat([torch.tensor([input2index[START_CHAR]] * len(lengths)).unsqueeze(1).to(device), decoder_input], dim=1)
            decoder_input = Embedder(decoder_input)

            char_loss = 0
            attention_loss = 0

            max_length = target.shape[1]
            
            # get alignment matrix
            max_src_len = lengths[0]
            bsz = len(alignments)
            alignments_batched = np.zeros((bsz, max_length, max_src_len))
            for i, alignment in enumerate(alignments):
                alignments_batched[i, :alignment.shape[0], :alignment.shape[1]] = alignment
            alignments_batched = torch.from_numpy(alignments_batched).float().to(device)            
            
            for seq in range(0, max_length):
                attn_weights = attention(encoded_input, hidden_state, input_mask)
                attention_target = alignments_batched[:, seq, :].argmax(dim=1).detach().masked_fill(alignments_batched[:, seq, :].sum(dim=1) == 0, -1)
                # loss += lamda * attention_criterion(attn_weights, alignments_batched[:, seq, :]) MSE
                attention_loss += attention_criterion(attn_weights, attention_target)
                context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

                decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input[:,seq,:].unsqueeze(1)], dim=2)

                output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
                output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))
                output = dropout1(output)
                output = log_softmax(output).squeeze()
                char_loss += criterion(output, target[:,seq])

            loss = char_loss + lamda * attention_loss
            epoch_loss += loss.item()
            epoch_attention_loss += attention_loss.item() 
            epoch_char_loss += char_loss.item()
            loss.backward()
            optimiser.step()

        print("Epoch: {}/{}\tTime: {:.2f}s\tLoss: {:.4f}\tALoss: {:.4f}\tCLoss: {:.4f}\tAcc: {:.4f}\tLD: {:.4f} ".format(epoch+1, epochs, time.time() - start_time, epoch_loss / len(lemmas_train), epoch_attention_loss / len(lemmas_train), epoch_char_loss / len(lemmas_train), *evaluate(*test(lemmas_val, tags_val, inflected_forms_val))))

# %%
optimiser = optim.Adagrad(params, lr=0.01)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=20, lamda=2)

# %%
optimiser = optim.Adagrad(params, lr=0.001)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=1000, lamda=0)

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))

# %% [markdown]
# ### Development Dataset

# %%
lemmas_dev, tags_dev, inflected_forms_dev = load_data('./conll2018/task1/all/{}-dev'.format(language))

# %%
evaluate(*test(lemmas_dev, tags_dev, inflected_forms_dev))

# %%
for prediction, truth in zip(*test(lemmas_dev, tags_dev, inflected_forms_dev)):
    print("Prediction: {}\tTruth: {}".format(prediction, truth))
